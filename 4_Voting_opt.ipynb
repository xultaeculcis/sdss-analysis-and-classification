# %% [markdown]
# # Optimization of Voting classifier for the SDSS data

# %% [markdown]
# ## Load data

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals
import warnings
import helpers
from helpers import DataSet
import matplotlib as mpl
import os
import random

# Common imports
import pandas as pd
import numpy as np
import seaborn as sns

# Imports for ML
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, BaggingClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier, PassiveAggressiveClassifier, RidgeClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import RobustScaler, StandardScaler, MaxAbsScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.decomposition import PCA

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
sns.set_style('whitegrid')

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "results"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)

# Helper functioins and structures
# Ignore useless warnings (see SciPy issue #5998)
warnings.filterwarnings(action="ignore", message="^internal gelsd")

DATA_PATH = "Skyserver_SQL2_27_2018 6_51_39 PM.csv"
RESULTS_FOLDER = "results"

# We load the data. Those that have nothing to do with the features of the objects are ignored.
sdss_data = pd.read_csv(DATA_PATH)

# We have a general look at the features
sdss_data.head(3)

print(sdss_data.columns.values)
sdss_data.drop(['objid', 'run', 'rerun', 'camcol', 'field',
                'specobjid', 'fiberid', 'mjd', 'plate'], axis=1, inplace=True)
sdss_data.head(1)

sdss_df_fe = sdss_data

# Principal Component Analysis
pca = PCA(n_components=3)
ugriz = pca.fit_transform(sdss_df_fe[['u', 'g', 'r', 'i', 'z']])

# update dataframe
sdss_df_fe = pd.concat((sdss_df_fe, pd.DataFrame(ugriz)), axis=1)
sdss_df_fe.rename({0: 'PCA_1', 1: 'PCA_2', 2: 'PCA_3'}, axis=1, inplace=True)
sdss_df_fe.drop(['u', 'g', 'r', 'i', 'z'], axis=1, inplace=True)
sdss_df_fe.head()

X = sdss_data.drop(['class'], axis=1)
y = sdss_data['class']

class_names = ["GALAXY", "QSO", "STAR"]

std_scaler = StandardScaler()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

X_test = std_scaler.fit_transform(X_test.astype(np.float64))
X_train = std_scaler.fit_transform(X_train.astype(np.float64))
# Out:
# ['objid' 'ra' 'dec' 'u' 'g' 'r' 'i' 'z' 'run' 'rerun' 'camcol' 'field'
#  'specobjid' 'class' 'redshift' 'plate' 'mjd' 'fiberid']

# %% [markdown]
# ## Optimize

# %%
def prepare_clfs():
    knn_clf = KNeighborsClassifier(n_neighbors=3,
                                  weights='distance', 
                                  algorithm='auto',
                                  leaf_size=23, 
                                  p=2,
                                  metric='manhattan', 
                                  n_jobs=4)

    lsvm_clf = LinearSVC(penalty='l2',
                       loss='squared_hinge',
                       dual=False,
                       C=303919.53823132074,
                       multi_class='ovr',
                       fit_intercept=True,
                       intercept_scaling=1.0,
                       class_weight='balanced',
                       verbose=False,
                       max_iter=10000,
                       random_state=42)
    
    nusvm_clf = NuSVC(nu=0.01743328822199991,
                   kernel="rbf",
                   gamma=0.01743328822199991, 
                   degree=7,
                   coef0=4.5203536563602496e-05, 
                   shrinking=True,
                   probability=True,
                   tol=0.001,
                   cache_size=20, 
                   class_weight="balanced",
                   verbose=False,
                   max_iter=100000,
                   random_state=42)

    rbf_svm_clf = SVC(kernel="rbf",
                      C=18329.8071083243,
                      gamma=0.004281332398719387,
                      degree=8,
                      coef0=0.0007847599703514606,
                      shrinking=True,
                      probability=True,
                      tol=0.001,
                      cache_size=100,
                      class_weight=None,
                      verbose=False,
                      max_iter=-1,
                      random_state=42)

    poly_svm_clf = SVC(kernel='poly',
                 C=788.0462815669937,
                 gamma=0.0004893900918477499, 
                 degree=4,
                 coef0=22.122162910704503, 
                 shrinking=False,
                 probability=True, 
                 tol=0.001, 
                 cache_size=50,
                 class_weight=None, 
                 verbose=False, 
                 max_iter=100000, 
                 random_state=42)

    tree_clf = DecisionTreeClassifier(criterion="entropy",
                                      splitter="best",
                                      max_depth=3,
                                      min_weight_fraction_leaf=0.0014384498882876629,
                                      max_leaf_nodes=9,
                                      presort=True,
                                      min_samples_split=6,
                                      min_samples_leaf=4,
                                      max_features=None,
                                      random_state=42)

    rnd_clf = RandomForestClassifier(n_estimators=100,
                                     criterion="entropy",
                                     min_samples_split=4,
                                     min_samples_leaf=2,
                                     max_features=None,
                                     bootstrap=True,
                                     oob_score=True,
                                     random_state=42)

    log_clf = LogisticRegression(penalty='l1',
                                 dual=False,
                                 C=31.622776601683793,
                                 fit_intercept=True,
                                 intercept_scaling=0.5878016072274912,
                                 class_weight='balanced',
                                 solver='saga',
                                 multi_class='multinomial',
                                 warm_start=False,
                                 n_jobs=4,
                                 max_iter=1000,
                                 random_state=42)

    gb_clf = GradientBoostingClassifier(loss="deviance",
                                        learning_rate=0.18329807108324356,
                                        n_estimators=83,
                                        criterion="friedman_mse",
                                        min_samples_split=3,
                                        min_samples_leaf=7,
                                        max_depth=7,
                                        random_state=42)

    xgb_clf = XGBClassifier(eta=0.01778279410038923,
                            gamma=0.01,
                            max_depth=4,
                            min_child_weight=0.03831186849557289,
                            max_delta_step=0.35938136638046275,
                            subsample=1.0,
                            reg_lambda=5.994842503189409,
                            alpha=1.7782794100389228e-08,
                            colsample_bytree=0.9,
                            objective="multi:softprob",
                            seed=42,
                            n_estimators=4216,
                            nthread=4)

    bag_df_clf = BaggingClassifier(n_estimators=261,
                                   max_samples=46,
                                   max_features=6,
                                   bootstrap=False,
                                   bootstrap_features=False,
                                   oob_score=False,
                                   n_jobs=4,
                                   random_state=42)

    ada_clf = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=3),
                                 n_estimators=825,
                                 learning_rate=0.19573417814876617,
                                 algorithm='SAMME',
                                 random_state=42)

    sgd_clf = SGDClassifier(loss='perceptron',
                            penalty='l1',
                            alpha=0.00510896977450693,
                            l1_ratio=0.014677992676220698,
                            fit_intercept=True,
                            shuffle=True,
                            epsilon=0.4216965034285822,
                            n_jobs=4,
                            random_state=42,
                            learning_rate='optimal',
                            eta0=0.2,
                            power_t=0.014677992676220698,
                            early_stopping=True,
                            n_iter_no_change=5,
                            class_weight=None,
                            average=False)

    mlp_clf = MLPClassifier(hidden_layer_sizes=(20, 20),
                           activation='relu',
                           solver='sgd', 
                           alpha=1e-05, 
                           batch_size=3, 
                           learning_rate='adaptive',
                           learning_rate_init=0.1333521432163324, 
                           power_t=0.004216965034285823, 
                           max_iter=1000,
                           random_state=42,
                           momentum=0.1,
                           nesterovs_momentum=True, 
                           early_stopping=True,
                           beta_1=0.7, 
                           beta_2=0.4210900698456838, 
                           epsilon=1e-08,
                           n_iter_no_change=5)

    xtree_clf = ExtraTreesClassifier(n_estimators=2154,
                                     criterion="gini",
                                     min_samples_split=2,
                                     min_samples_leaf=1,
                                     max_features=None,
                                     bootstrap=False,
                                     oob_score=False,
                                     random_state=42)

    pa_clf = PassiveAggressiveClassifier(loss='hinge',
                                         shuffle=False,
                                         n_jobs=4,
                                         random_state=42,
                                         early_stopping=True,
                                         warm_start=False,
                                         class_weight='balanced',
                                         average=False)

    r_clf = RidgeClassifier(alpha=0.11006941712522103,
                            fit_intercept=False,
                            normalize=False,
                            copy_X=True,
                            max_iter=3000,
                            class_weight=None,
                            solver='cholesky',
                            random_state=42)

    nb_clf = GaussianNB(var_smoothing=3.727593720314938e-11)

    lda_clf = LinearDiscriminantAnalysis(
        solver="svd", shrinkage=None, n_components=None, store_covariance=False)

    qda_clf = QuadraticDiscriminantAnalysis(
        reg_param=2.1544346900318867e-07, store_covariance=False)

    clf_names = ["KNN",
                 "LinearSVM",
                 "NuSVC",
                 "RbfKernelSVM",
                 "PolyKernelSVM",
                 "DecisionTreeClassifier",
                 "RandomForestClassifier",
                 "LogisticRegression",
                 "GradientBoostingClassifier",
                 "XGBClassifier",
                 "BaggingClassifier",
                 "AdaBoostClassifier",
                 "SGDClassifier",
                 "MLPClassifier",
                 "ExtraTreesClassifier",
                 "PassiveAggressiveClassifier",
                 "RidgeClassifier",
                 "GaussianNB",
                 "LinearDiscriminantAnalysis",
                 "QuadraticDiscriminantAnalysis"
                 ]

    clfs = [knn_clf,
            lsvm_clf,
            nusvm_clf,
            rbf_svm_clf,
            poly_svm_clf,
            tree_clf,
            rnd_clf,
            log_clf,
            gb_clf,
            xgb_clf,
            bag_df_clf,
            ada_clf,
            sgd_clf,
            mlp_clf,
            xtree_clf,
            pa_clf,
            r_clf,
            nb_clf,
            lda_clf,
            qda_clf
            ]

    return list(zip(clf_names, clfs))

# %%
def get_random_clf_sets(clfs, num=5):
    clf_sets = []

    for i in range(0, num):
        clf_num = random.randint(3, len(clfs))
        clf_list = random.sample(clfs, clf_num)
        clf_sets.append(clf_list)
    
    return clf_sets

all_clfs = prepare_clfs()
clf_choices = get_random_clf_sets(all_clfs, 300)

# %%
def print_choices(clf_choices):
    i = 0
    for clf_tuple in clf_choices:
        print("=======Choice " + str(i) + "=======")
        clfnames = []
        for clf in clf_tuple:
            clfnames.append(clf[0])
        i = i + 1
        print(clfnames)
        
def print_choices_single(choice, i=None):
    if (i is None): 
        print("=======Choice=======")
    else:
        print("=======Choice " + str(i) + "=======")
    clfnames = []
    for clf in choice:
        clfnames.append(clf[0])
    print(clfnames)
    return str(clfnames)

    
print_choices(clf_choices)
# Out:
# =======Choice 0=======
# ['LinearDiscriminantAnalysis', 'AdaBoostClassifier', 'RbfKernelSVM', 'RidgeClassifier', 'SGDClassifier', 'RandomForestClassifier', 'BaggingClassifier', 'PassiveAggressiveClassifier', 'XGBClassifier', 'MLPClassifier', 'KNN', 'LogisticRegression', 'GradientBoostingClassifier', 'LinearSVM', 'NuSVC', 'DecisionTreeClassifier', 'ExtraTreesClassifier', 'PolyKernelSVM']
# =======Choice 1=======
# ['RbfKernelSVM', 'NuSVC', 'PolyKernelSVM', 'KNN', 'GaussianNB', 'DecisionTreeClassifier', 'LinearDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'RidgeClassifier', 'AdaBoostClassifier', 'XGBClassifier', 'LinearSVM', 'RandomForestClassifier', 'LogisticRegression', 'GradientBoostingClassifier', 'ExtraTreesClassifier', 'MLPClassifier', 'QuadraticDiscriminantAnalysis', 'BaggingClassifier']
# =======Choice 2=======
# ['PassiveAggressiveClassifier', 'LinearSVM', 'GradientBoostingClassifier', 'MLPClassifier', 'RbfKernelSVM', 'LogisticRegression', 'RidgeClassifier', 'GaussianNB', 'SGDClassifier']
# =======Choice 3=======
# ['LinearDiscriminantAnalysis', 'RbfKernelSVM', 'DecisionTreeClassifier', 'LogisticRegression', 'QuadraticDiscriminantAnalysis', 'KNN', 'LinearSVM', 'GaussianNB', 'NuSVC', 'MLPClassifier', 'PolyKernelSVM', 'SGDClassifier', 'PassiveAggressiveClassifier', 'GradientBoostingClassifier', 'XGBClassifier', 'BaggingClassifier', 'ExtraTreesClassifier', 'RandomForestClassifier', 'AdaBoostClassifier']
# =======Choice 4=======
# ['XGBClassifier', 'SGDClassifier', 'PassiveAggressiveClassifier', 'AdaBoostClassifier', 'LogisticRegression', 'GaussianNB']
# =======Choice 5=======
# ['DecisionTreeClassifier', 'RandomForestClassifier', 'GaussianNB', 'RidgeClassifier', 'NuSVC', 'MLPClassifier', 'SGDClassifier', 'LogisticRegression', 'GradientBoostingClassifier', 'QuadraticDiscriminantAnalysis', 'AdaBoostClassifier', 'LinearDiscriminantAnalysis', 'PolyKernelSVM', 'KNN']
# =======Choice 6=======
# ['PolyKernelSVM', 'ExtraTreesClassifier', 'RandomForestClassifier', 'XGBClassifier', 'AdaBoostClassifier', 'QuadraticDiscriminantAnalysis', 'NuSVC', 'PassiveAggressiveClassifier', 'GaussianNB', 'RidgeClassifier', 'GradientBoostingClassifier', 'DecisionTreeClassifier', 'SGDClassifier', 'LogisticRegression', 'MLPClassifier', 'RbfKernelSVM', 'BaggingClassifier', 'KNN', 'LinearDiscriminantAnalysis', 'LinearSVM']
# =======Choice 7=======
# ['RbfKernelSVM', 'SGDClassifier', 'LinearDiscriminantAnalysis', 'KNN', 'GradientBoostingClassifier', 'BaggingClassifier', 'RidgeClassifier', 'DecisionTreeClassifier', 'RandomForestClassifier', 'PolyKernelSVM', 'PassiveAggressiveClassifier', 'MLPClassifier', 'NuSVC', 'LinearSVM', 'ExtraTreesClassifier', 'XGBClassifier', 'GaussianNB', 'QuadraticDiscriminantAnalysis']
# =======Choice 8=======
# ['RidgeClassifier', 'AdaBoostClassifier', 'ExtraTreesClassifier', 'KNN', 'GaussianNB', 'LinearDiscriminantAnalysis', 'NuSVC', 'PolyKernelSVM', 'BaggingClassifier', 'MLPClassifier']
# =======Choice 9=======
# ['RidgeClassifier', 'RbfKernelSVM', 'LogisticRegression']
# =======Choice 10=======
# ['LinearDiscriminantAnalysis', 'GaussianNB', 'GradientBoostingClassifier', 'DecisionTreeClassifier', 'RandomForestClassifier', 'RbfKernelSVM', 'ExtraTreesClassifier', 'QuadraticDiscriminantAnalysis', 'LinearSVM', 'PassiveAggressiveClassifier', 'PolyKernelSVM', 'SGDClassifier', 'LogisticRegression', 'NuSVC', 'XGBClassifier', 'KNN', 'AdaBoostClassifier']
# =======Choice 11=======
# ['LogisticRegression', 'PassiveAggressiveClassifier', 'RidgeClassifier', 'RandomForestClassifier', 'LinearSVM', 'AdaBoostClassifier', 'KNN', 'RbfKernelSVM', 'GaussianNB', 'MLPClassifier', 'SGDClassifier', 'XGBClassifier']
# =======Choice 12=======
# ['BaggingClassifier', 'LinearSVM', 'NuSVC', 'PassiveAggressiveClassifier', 'GaussianNB', 'LinearDiscriminantAnalysis', 'SGDClassifier']
# =======Choice 13=======
# ['RbfKernelSVM', 'LinearDiscriminantAnalysis', 'XGBClassifier', 'LogisticRegression', 'AdaBoostClassifier', 'MLPClassifier', 'SGDClassifier', 'GradientBoostingClassifier', 'ExtraTreesClassifier', 'KNN', 'PolyKernelSVM', 'QuadraticDiscriminantAnalysis', 'NuSVC']
# =======Choice 14=======
# ['XGBClassifier', 'LinearSVM', 'KNN', 'RandomForestClassifier', 'AdaBoostClassifier', 'LinearDiscriminantAnalysis', 'QuadraticDiscriminantAnalysis', 'GaussianNB', 'PassiveAggressiveClassifier', 'NuSVC', 'DecisionTreeClassifier', 'PolyKernelSVM', 'BaggingClassifier', 'RidgeClassifier', 'GradientBoostingClassifier', 'ExtraTreesClassifier', 'SGDClassifier', 'MLPClassifier', 'LogisticRegression']
# =======Choice 15=======
# ['AdaBoostClassifier', 'XGBClassifier', 'LinearDiscriminantAnalysis', 'MLPClassifier', 'LogisticRegression', 'DecisionTreeClassifier', 'LinearSVM', 'PolyKernelSVM', 'GradientBoostingClassifier', 'ExtraTreesClassifier', 'SGDClassifier', 'KNN', 'PassiveAggressiveClassifier', 'NuSVC', 'RandomForestClassifier', 'QuadraticDiscriminantAnalysis', 'BaggingClassifier', 'GaussianNB', 'RbfKernelSVM', 'RidgeClassifier']
# =======Choice 16=======
# ['SGDClassifier', 'AdaBoostClassifier', 'RandomForestClassifier', 'LinearDiscriminantAnalysis', 'LogisticRegression', 'XGBClassifier', 'GradientBoostingClassifier', 'BaggingClassifier', 'MLPClassifier', 'KNN', 'NuSVC', 'RbfKernelSVM', 'GaussianNB', 'PassiveAggressiveClassifier', 'LinearSVM', 'DecisionTreeClassifier', 'RidgeClassifier', 'ExtraTreesClassifier']
# =======Choice 17=======
# ['DecisionTreeClassifier', 'GaussianNB', 'XGBClassifier', 'LogisticRegression', 'NuSVC', 'LinearSVM', 'AdaBoostClassifier', 'PassiveAggressiveClassifier', 'GradientBoostingClassifier', 'LinearDiscriminantAnalysis', 'QuadraticDiscriminantAnalysis', 'RbfKernelSVM', 'MLPClassifier', 'RandomForestClassifier', 'PolyKernelSVM', 'KNN', 'RidgeClassifier', 'ExtraTreesClassifier', 'SGDClassifier']
# =======Choice 18=======
# ['LinearDiscriminantAnalysis', 'XGBClassifier', 'RandomForestClassifier', 'NuSVC', 'LinearSVM', 'PolyKernelSVM', 'ExtraTreesClassifier', 'GaussianNB', 'DecisionTreeClassifier', 'GradientBoostingClassifier', 'PassiveAggressiveClassifier']
# =======Choice 19=======
# ['SGDClassifier', 'PassiveAggressiveClassifier', 'RandomForestClassifier', 'XGBClassifier', 'GradientBoostingClassifier', 'PolyKernelSVM', 'LinearDiscriminantAnalysis', 'DecisionTreeClassifier', 'ExtraTreesClassifier', 'RidgeClassifier']
# =======Choice 20=======
# ['GradientBoostingClassifier', 'BaggingClassifier', 'MLPClassifier', 'AdaBoostClassifier', 'DecisionTreeClassifier', 'PolyKernelSVM', 'RandomForestClassifier', 'LinearDiscriminantAnalysis', 'LinearSVM', 'XGBClassifier', 'PassiveAggressiveClassifier', 'RbfKernelSVM', 'LogisticRegression', 'NuSVC', 'GaussianNB']
# =======Choice 21=======
# ['SGDClassifier', 'PolyKernelSVM', 'RbfKernelSVM', 'RidgeClassifier', 'DecisionTreeClassifier', 'KNN', 'AdaBoostClassifier', 'GaussianNB', 'XGBClassifier', 'RandomForestClassifier', 'GradientBoostingClassifier', 'PassiveAggressiveClassifier', 'LogisticRegression', 'LinearDiscriminantAnalysis', 'LinearSVM', 'ExtraTreesClassifier', 'NuSVC', 'QuadraticDiscriminantAnalysis', 'MLPClassifier', 'BaggingClassifier']
# =======Choice 22=======
# ['LogisticRegression', 'LinearDiscriminantAnalysis', 'RbfKernelSVM', 'RandomForestClassifier', 'NuSVC', 'ExtraTreesClassifier', 'RidgeClassifier', 'MLPClassifier', 'BaggingClassifier', 'AdaBoostClassifier', 'PassiveAggressiveClassifier', 'LinearSVM', 'GaussianNB', 'KNN']
# =======Choice 23=======
# ['GaussianNB', 'MLPClassifier', 'NuSVC', 'QuadraticDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'RandomForestClassifier', 'AdaBoostClassifier', 'PolyKernelSVM', 'LinearSVM', 'RidgeClassifier']
# =======Choice 24=======
# ['RidgeClassifier', 'AdaBoostClassifier', 'PolyKernelSVM', 'QuadraticDiscriminantAnalysis', 'DecisionTreeClassifier', 'KNN', 'RbfKernelSVM', 'GradientBoostingClassifier', 'SGDClassifier', 'GaussianNB', 'BaggingClassifier', 'ExtraTreesClassifier', 'RandomForestClassifier', 'MLPClassifier', 'PassiveAggressiveClassifier', 'LinearDiscriminantAnalysis', 'NuSVC', 'LinearSVM', 'XGBClassifier', 'LogisticRegression']
# =======Choice 25=======
# ['RidgeClassifier', 'AdaBoostClassifier', 'PolyKernelSVM', 'PassiveAggressiveClassifier', 'DecisionTreeClassifier', 'SGDClassifier']
# =======Choice 26=======
# ['LinearDiscriminantAnalysis', 'XGBClassifier', 'RandomForestClassifier', 'GradientBoostingClassifier', 'PolyKernelSVM', 'RbfKernelSVM', 'AdaBoostClassifier', 'NuSVC']
# =======Choice 27=======
# ['KNN', 'RandomForestClassifier', 'QuadraticDiscriminantAnalysis', 'SGDClassifier', 'LogisticRegression', 'LinearDiscriminantAnalysis', 'GradientBoostingClassifier', 'NuSVC', 'PassiveAggressiveClassifier', 'PolyKernelSVM', 'ExtraTreesClassifier', 'AdaBoostClassifier', 'BaggingClassifier', 'MLPClassifier', 'RidgeClassifier', 'RbfKernelSVM', 'LinearSVM', 'DecisionTreeClassifier', 'GaussianNB']
# =======Choice 28=======
# ['AdaBoostClassifier', 'GaussianNB', 'MLPClassifier', 'LinearDiscriminantAnalysis']
# =======Choice 29=======
# ['XGBClassifier', 'NuSVC', 'QuadraticDiscriminantAnalysis', 'KNN', 'GradientBoostingClassifier', 'SGDClassifier', 'RandomForestClassifier', 'PolyKernelSVM', 'MLPClassifier', 'ExtraTreesClassifier', 'RidgeClassifier', 'LinearDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'LogisticRegression', 'LinearSVM', 'DecisionTreeClassifier', 'RbfKernelSVM', 'BaggingClassifier', 'GaussianNB']
# =======Choice 30=======
# ['LinearDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'LinearSVM', 'GaussianNB', 'ExtraTreesClassifier', 'RandomForestClassifier', 'NuSVC', 'GradientBoostingClassifier', 'PolyKernelSVM', 'QuadraticDiscriminantAnalysis', 'RbfKernelSVM', 'MLPClassifier', 'RidgeClassifier', 'KNN', 'BaggingClassifier', 'AdaBoostClassifier']
# =======Choice 31=======
# ['ExtraTreesClassifier', 'QuadraticDiscriminantAnalysis', 'LinearDiscriminantAnalysis', 'RidgeClassifier', 'PassiveAggressiveClassifier', 'PolyKernelSVM']
# =======Choice 32=======
# ['GradientBoostingClassifier', 'XGBClassifier', 'PolyKernelSVM', 'MLPClassifier', 'LogisticRegression', 'LinearDiscriminantAnalysis', 'AdaBoostClassifier', 'SGDClassifier', 'KNN', 'DecisionTreeClassifier', 'NuSVC', 'RidgeClassifier']
# =======Choice 33=======
# ['RbfKernelSVM', 'LinearDiscriminantAnalysis', 'KNN', 'NuSVC', 'BaggingClassifier', 'PassiveAggressiveClassifier', 'AdaBoostClassifier', 'LogisticRegression', 'XGBClassifier', 'GaussianNB', 'PolyKernelSVM', 'SGDClassifier', 'QuadraticDiscriminantAnalysis', 'LinearSVM', 'MLPClassifier', 'RandomForestClassifier', 'RidgeClassifier', 'GradientBoostingClassifier', 'ExtraTreesClassifier']
# =======Choice 34=======
# ['PassiveAggressiveClassifier', 'KNN', 'BaggingClassifier', 'RbfKernelSVM', 'DecisionTreeClassifier', 'XGBClassifier', 'QuadraticDiscriminantAnalysis', 'GradientBoostingClassifier', 'LogisticRegression']
# =======Choice 35=======
# ['LinearDiscriminantAnalysis', 'RidgeClassifier', 'NuSVC', 'XGBClassifier', 'ExtraTreesClassifier', 'GradientBoostingClassifier', 'RbfKernelSVM', 'LinearSVM', 'SGDClassifier', 'KNN', 'BaggingClassifier', 'DecisionTreeClassifier']
# =======Choice 36=======
# ['DecisionTreeClassifier', 'KNN', 'GradientBoostingClassifier', 'BaggingClassifier', 'LogisticRegression', 'PolyKernelSVM', 'RandomForestClassifier', 'ExtraTreesClassifier', 'MLPClassifier', 'NuSVC', 'LinearDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'XGBClassifier', 'AdaBoostClassifier', 'LinearSVM']
# =======Choice 37=======
# ['PolyKernelSVM', 'PassiveAggressiveClassifier', 'BaggingClassifier', 'RbfKernelSVM', 'NuSVC', 'LogisticRegression', 'LinearSVM']
# =======Choice 38=======
# ['NuSVC', 'LinearDiscriminantAnalysis', 'RidgeClassifier']
# =======Choice 39=======
# ['RbfKernelSVM', 'AdaBoostClassifier', 'PassiveAggressiveClassifier', 'RidgeClassifier', 'DecisionTreeClassifier', 'BaggingClassifier', 'MLPClassifier', 'LogisticRegression', 'LinearSVM', 'GradientBoostingClassifier', 'SGDClassifier', 'GaussianNB', 'QuadraticDiscriminantAnalysis', 'LinearDiscriminantAnalysis']
# =======Choice 40=======
# ['PassiveAggressiveClassifier', 'DecisionTreeClassifier', 'RandomForestClassifier', 'GaussianNB', 'MLPClassifier', 'SGDClassifier', 'QuadraticDiscriminantAnalysis', 'AdaBoostClassifier', 'RidgeClassifier', 'XGBClassifier', 'LinearSVM', 'LinearDiscriminantAnalysis', 'GradientBoostingClassifier', 'PolyKernelSVM']
# =======Choice 41=======
# ['PassiveAggressiveClassifier', 'LogisticRegression', 'QuadraticDiscriminantAnalysis', 'GaussianNB', 'GradientBoostingClassifier', 'XGBClassifier']
# =======Choice 42=======
# ['LinearSVM', 'NuSVC', 'RbfKernelSVM', 'PassiveAggressiveClassifier', 'KNN']
# =======Choice 43=======
# ['RidgeClassifier', 'RbfKernelSVM', 'DecisionTreeClassifier']
# =======Choice 44=======
# ['NuSVC', 'KNN', 'GradientBoostingClassifier', 'XGBClassifier', 'SGDClassifier', 'LinearSVM', 'BaggingClassifier', 'LinearDiscriminantAnalysis', 'RbfKernelSVM', 'QuadraticDiscriminantAnalysis', 'AdaBoostClassifier', 'LogisticRegression', 'DecisionTreeClassifier', 'RidgeClassifier', 'GaussianNB', 'ExtraTreesClassifier', 'PolyKernelSVM', 'MLPClassifier', 'PassiveAggressiveClassifier']
# =======Choice 45=======
# ['LogisticRegression', 'NuSVC', 'PolyKernelSVM', 'LinearSVM', 'GaussianNB', 'LinearDiscriminantAnalysis', 'MLPClassifier', 'BaggingClassifier', 'PassiveAggressiveClassifier', 'XGBClassifier', 'GradientBoostingClassifier', 'KNN', 'AdaBoostClassifier', 'DecisionTreeClassifier']
# =======Choice 46=======
# ['PassiveAggressiveClassifier', 'BaggingClassifier', 'PolyKernelSVM', 'RidgeClassifier', 'XGBClassifier', 'MLPClassifier', 'QuadraticDiscriminantAnalysis', 'KNN', 'NuSVC', 'SGDClassifier', 'RbfKernelSVM', 'GaussianNB', 'RandomForestClassifier', 'GradientBoostingClassifier']
# =======Choice 47=======
# ['DecisionTreeClassifier', 'GaussianNB', 'PassiveAggressiveClassifier', 'BaggingClassifier', 'PolyKernelSVM', 'NuSVC', 'LogisticRegression', 'GradientBoostingClassifier', 'RbfKernelSVM', 'MLPClassifier', 'RidgeClassifier', 'KNN', 'RandomForestClassifier', 'XGBClassifier', 'LinearDiscriminantAnalysis', 'SGDClassifier', 'ExtraTreesClassifier', 'QuadraticDiscriminantAnalysis']
# =======Choice 48=======
# ['MLPClassifier', 'DecisionTreeClassifier', 'NuSVC', 'QuadraticDiscriminantAnalysis', 'PolyKernelSVM']
# =======Choice 49=======
# ['RandomForestClassifier', 'RbfKernelSVM', 'KNN', 'GradientBoostingClassifier', 'ExtraTreesClassifier', 'QuadraticDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'LogisticRegression', 'SGDClassifier', 'XGBClassifier']
# =======Choice 50=======
# ['DecisionTreeClassifier', 'GaussianNB', 'RbfKernelSVM', 'LinearSVM', 'MLPClassifier', 'KNN', 'NuSVC', 'LinearDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'QuadraticDiscriminantAnalysis', 'GradientBoostingClassifier', 'BaggingClassifier', 'XGBClassifier', 'LogisticRegression', 'AdaBoostClassifier', 'PolyKernelSVM', 'SGDClassifier', 'ExtraTreesClassifier', 'RidgeClassifier', 'RandomForestClassifier']
# =======Choice 51=======
# ['GradientBoostingClassifier', 'ExtraTreesClassifier', 'XGBClassifier', 'PassiveAggressiveClassifier', 'DecisionTreeClassifier', 'RidgeClassifier', 'LogisticRegression', 'BaggingClassifier', 'QuadraticDiscriminantAnalysis', 'RbfKernelSVM', 'GaussianNB', 'MLPClassifier', 'SGDClassifier']
# =======Choice 52=======
# ['MLPClassifier', 'LinearDiscriminantAnalysis', 'SGDClassifier', 'GaussianNB', 'RbfKernelSVM', 'GradientBoostingClassifier', 'DecisionTreeClassifier', 'NuSVC', 'QuadraticDiscriminantAnalysis']
# =======Choice 53=======
# ['XGBClassifier', 'KNN', 'SGDClassifier', 'QuadraticDiscriminantAnalysis', 'NuSVC']
# =======Choice 54=======
# ['RidgeClassifier', 'PolyKernelSVM', 'GradientBoostingClassifier', 'GaussianNB', 'SGDClassifier', 'PassiveAggressiveClassifier', 'BaggingClassifier', 'AdaBoostClassifier', 'LinearSVM']
# =======Choice 55=======
# ['PassiveAggressiveClassifier', 'RbfKernelSVM', 'QuadraticDiscriminantAnalysis', 'GaussianNB', 'GradientBoostingClassifier', 'MLPClassifier', 'LinearSVM', 'KNN', 'NuSVC', 'RidgeClassifier', 'RandomForestClassifier', 'BaggingClassifier', 'LogisticRegression', 'PolyKernelSVM', 'AdaBoostClassifier', 'SGDClassifier', 'ExtraTreesClassifier', 'DecisionTreeClassifier']
# =======Choice 56=======
# ['LinearSVM', 'PassiveAggressiveClassifier', 'BaggingClassifier', 'GradientBoostingClassifier', 'SGDClassifier', 'LinearDiscriminantAnalysis', 'XGBClassifier', 'LogisticRegression', 'RidgeClassifier', 'PolyKernelSVM', 'QuadraticDiscriminantAnalysis']
# =======Choice 57=======
# ['RbfKernelSVM', 'DecisionTreeClassifier', 'GradientBoostingClassifier', 'GaussianNB', 'LogisticRegression', 'NuSVC', 'PassiveAggressiveClassifier', 'LinearSVM', 'LinearDiscriminantAnalysis', 'KNN', 'BaggingClassifier', 'PolyKernelSVM', 'RandomForestClassifier', 'MLPClassifier', 'ExtraTreesClassifier']
# =======Choice 58=======
# ['LinearSVM', 'DecisionTreeClassifier', 'QuadraticDiscriminantAnalysis', 'NuSVC', 'BaggingClassifier', 'AdaBoostClassifier', 'PolyKernelSVM', 'LinearDiscriminantAnalysis', 'KNN', 'RandomForestClassifier', 'RidgeClassifier', 'GaussianNB', 'XGBClassifier', 'RbfKernelSVM', 'ExtraTreesClassifier', 'PassiveAggressiveClassifier']
# =======Choice 59=======
# ['MLPClassifier', 'RandomForestClassifier', 'RbfKernelSVM', 'SGDClassifier', 'LinearSVM', 'NuSVC', 'LogisticRegression', 'AdaBoostClassifier', 'BaggingClassifier', 'PolyKernelSVM', 'DecisionTreeClassifier', 'PassiveAggressiveClassifier', 'QuadraticDiscriminantAnalysis', 'RidgeClassifier']
# =======Choice 60=======
# ['RbfKernelSVM', 'PassiveAggressiveClassifier', 'PolyKernelSVM', 'LinearDiscriminantAnalysis', 'QuadraticDiscriminantAnalysis', 'RidgeClassifier', 'DecisionTreeClassifier', 'LinearSVM', 'GradientBoostingClassifier', 'GaussianNB', 'BaggingClassifier', 'NuSVC', 'LogisticRegression', 'SGDClassifier']
# =======Choice 61=======
# ['QuadraticDiscriminantAnalysis', 'XGBClassifier', 'RandomForestClassifier', 'PolyKernelSVM', 'PassiveAggressiveClassifier', 'RbfKernelSVM', 'AdaBoostClassifier', 'GaussianNB', 'LinearDiscriminantAnalysis', 'LinearSVM', 'KNN', 'SGDClassifier', 'MLPClassifier', 'RidgeClassifier', 'DecisionTreeClassifier', 'ExtraTreesClassifier', 'LogisticRegression', 'NuSVC', 'BaggingClassifier']
# =======Choice 62=======
# ['NuSVC', 'GradientBoostingClassifier', 'MLPClassifier', 'BaggingClassifier', 'LinearDiscriminantAnalysis', 'LinearSVM', 'ExtraTreesClassifier', 'SGDClassifier', 'AdaBoostClassifier', 'XGBClassifier', 'GaussianNB', 'PolyKernelSVM', 'RandomForestClassifier', 'KNN', 'PassiveAggressiveClassifier', 'QuadraticDiscriminantAnalysis', 'RbfKernelSVM', 'RidgeClassifier']
# =======Choice 63=======
# ['RidgeClassifier', 'PolyKernelSVM', 'PassiveAggressiveClassifier', 'LinearSVM', 'RbfKernelSVM', 'KNN', 'GradientBoostingClassifier', 'NuSVC', 'DecisionTreeClassifier', 'BaggingClassifier', 'SGDClassifier', 'MLPClassifier', 'QuadraticDiscriminantAnalysis']
# =======Choice 64=======
# ['LogisticRegression', 'ExtraTreesClassifier', 'GaussianNB', 'RbfKernelSVM', 'PassiveAggressiveClassifier', 'NuSVC', 'SGDClassifier']
# =======Choice 65=======
# ['LinearSVM', 'RandomForestClassifier', 'NuSVC', 'AdaBoostClassifier', 'SGDClassifier', 'GaussianNB', 'PassiveAggressiveClassifier', 'BaggingClassifier', 'PolyKernelSVM', 'LogisticRegression', 'XGBClassifier', 'KNN', 'QuadraticDiscriminantAnalysis', 'LinearDiscriminantAnalysis', 'DecisionTreeClassifier', 'RidgeClassifier', 'RbfKernelSVM', 'GradientBoostingClassifier', 'MLPClassifier']
# =======Choice 66=======
# ['RbfKernelSVM', 'PolyKernelSVM', 'AdaBoostClassifier', 'NuSVC', 'RandomForestClassifier', 'XGBClassifier', 'GradientBoostingClassifier', 'LinearDiscriminantAnalysis', 'SGDClassifier', 'LogisticRegression', 'GaussianNB', 'QuadraticDiscriminantAnalysis', 'ExtraTreesClassifier', 'DecisionTreeClassifier', 'KNN', 'BaggingClassifier', 'RidgeClassifier', 'PassiveAggressiveClassifier']
# =======Choice 67=======
# ['LinearDiscriminantAnalysis', 'AdaBoostClassifier', 'DecisionTreeClassifier', 'LinearSVM', 'GaussianNB', 'PassiveAggressiveClassifier', 'NuSVC', 'BaggingClassifier', 'PolyKernelSVM', 'SGDClassifier', 'RbfKernelSVM', 'MLPClassifier', 'RidgeClassifier', 'GradientBoostingClassifier', 'QuadraticDiscriminantAnalysis', 'XGBClassifier']
# =======Choice 68=======
# ['PolyKernelSVM', 'LogisticRegression', 'LinearSVM', 'QuadraticDiscriminantAnalysis', 'GaussianNB', 'AdaBoostClassifier', 'PassiveAggressiveClassifier', 'LinearDiscriminantAnalysis', 'NuSVC', 'GradientBoostingClassifier', 'RidgeClassifier', 'RbfKernelSVM', 'RandomForestClassifier', 'XGBClassifier', 'KNN', 'SGDClassifier', 'ExtraTreesClassifier']
# =======Choice 69=======
# ['AdaBoostClassifier', 'PolyKernelSVM', 'PassiveAggressiveClassifier', 'SGDClassifier', 'QuadraticDiscriminantAnalysis', 'RandomForestClassifier']
# =======Choice 70=======
# ['RidgeClassifier', 'RbfKernelSVM', 'PolyKernelSVM', 'DecisionTreeClassifier', 'SGDClassifier', 'XGBClassifier', 'MLPClassifier', 'LinearSVM', 'QuadraticDiscriminantAnalysis', 'LogisticRegression', 'PassiveAggressiveClassifier', 'ExtraTreesClassifier', 'LinearDiscriminantAnalysis', 'GradientBoostingClassifier', 'KNN', 'BaggingClassifier', 'GaussianNB', 'NuSVC']
# =======Choice 71=======
# ['LinearDiscriminantAnalysis', 'AdaBoostClassifier', 'DecisionTreeClassifier', 'RidgeClassifier', 'MLPClassifier', 'GaussianNB', 'BaggingClassifier', 'SGDClassifier', 'RbfKernelSVM', 'PassiveAggressiveClassifier', 'LogisticRegression', 'XGBClassifier', 'ExtraTreesClassifier', 'PolyKernelSVM', 'QuadraticDiscriminantAnalysis', 'RandomForestClassifier', 'LinearSVM']
# =======Choice 72=======
# ['PassiveAggressiveClassifier', 'LinearSVM', 'DecisionTreeClassifier']
# =======Choice 73=======
# ['GaussianNB', 'PassiveAggressiveClassifier', 'MLPClassifier', 'NuSVC', 'SGDClassifier', 'KNN', 'LinearSVM', 'RidgeClassifier', 'ExtraTreesClassifier', 'RbfKernelSVM', 'BaggingClassifier', 'XGBClassifier', 'GradientBoostingClassifier', 'LogisticRegression', 'DecisionTreeClassifier', 'AdaBoostClassifier', 'RandomForestClassifier', 'QuadraticDiscriminantAnalysis', 'PolyKernelSVM']
# =======Choice 74=======
# ['XGBClassifier', 'BaggingClassifier', 'KNN', 'RbfKernelSVM', 'QuadraticDiscriminantAnalysis']
# =======Choice 75=======
# ['GradientBoostingClassifier', 'BaggingClassifier', 'AdaBoostClassifier', 'RidgeClassifier', 'RbfKernelSVM', 'LogisticRegression', 'LinearDiscriminantAnalysis', 'LinearSVM', 'DecisionTreeClassifier', 'KNN', 'SGDClassifier', 'MLPClassifier', 'XGBClassifier', 'QuadraticDiscriminantAnalysis', 'NuSVC', 'ExtraTreesClassifier', 'RandomForestClassifier', 'PassiveAggressiveClassifier', 'PolyKernelSVM']
# =======Choice 76=======
# ['PassiveAggressiveClassifier', 'LinearSVM', 'GradientBoostingClassifier', 'QuadraticDiscriminantAnalysis', 'PolyKernelSVM']
# =======Choice 77=======
# ['QuadraticDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'GradientBoostingClassifier', 'DecisionTreeClassifier', 'RidgeClassifier', 'AdaBoostClassifier', 'SGDClassifier', 'ExtraTreesClassifier', 'KNN', 'PolyKernelSVM', 'GaussianNB', 'MLPClassifier', 'RbfKernelSVM']
# =======Choice 78=======
# ['RandomForestClassifier', 'GradientBoostingClassifier', 'RbfKernelSVM', 'MLPClassifier', 'RidgeClassifier', 'LinearSVM', 'XGBClassifier', 'PolyKernelSVM', 'PassiveAggressiveClassifier', 'QuadraticDiscriminantAnalysis']
# =======Choice 79=======
# ['RandomForestClassifier', 'RbfKernelSVM', 'BaggingClassifier', 'NuSVC', 'LinearDiscriminantAnalysis', 'ExtraTreesClassifier', 'AdaBoostClassifier', 'RidgeClassifier', 'XGBClassifier', 'QuadraticDiscriminantAnalysis', 'LinearSVM', 'KNN', 'DecisionTreeClassifier', 'SGDClassifier', 'PassiveAggressiveClassifier', 'MLPClassifier']
# =======Choice 80=======
# ['SGDClassifier', 'LogisticRegression', 'RandomForestClassifier', 'GradientBoostingClassifier', 'NuSVC', 'MLPClassifier']
# =======Choice 81=======
# ['XGBClassifier', 'LogisticRegression', 'DecisionTreeClassifier', 'ExtraTreesClassifier', 'LinearSVM', 'MLPClassifier', 'KNN', 'BaggingClassifier', 'NuSVC', 'RandomForestClassifier', 'SGDClassifier', 'LinearDiscriminantAnalysis', 'GaussianNB', 'RbfKernelSVM', 'AdaBoostClassifier', 'QuadraticDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'PolyKernelSVM', 'RidgeClassifier', 'GradientBoostingClassifier']
# =======Choice 82=======
# ['SGDClassifier', 'AdaBoostClassifier', 'PolyKernelSVM', 'PassiveAggressiveClassifier', 'LogisticRegression', 'QuadraticDiscriminantAnalysis', 'KNN', 'RandomForestClassifier', 'LinearDiscriminantAnalysis', 'DecisionTreeClassifier', 'GaussianNB', 'NuSVC', 'ExtraTreesClassifier', 'BaggingClassifier', 'RbfKernelSVM', 'MLPClassifier', 'LinearSVM', 'XGBClassifier', 'RidgeClassifier']
# =======Choice 83=======
# ['GradientBoostingClassifier', 'LinearDiscriminantAnalysis', 'NuSVC', 'SGDClassifier', 'PolyKernelSVM', 'MLPClassifier', 'LinearSVM']
# =======Choice 84=======
# ['LinearSVM', 'SGDClassifier', 'LogisticRegression', 'GradientBoostingClassifier']
# =======Choice 85=======
# ['NuSVC', 'BaggingClassifier', 'LinearDiscriminantAnalysis']
# =======Choice 86=======
# ['LogisticRegression', 'DecisionTreeClassifier', 'GaussianNB', 'SGDClassifier', 'LinearSVM', 'LinearDiscriminantAnalysis', 'BaggingClassifier', 'RidgeClassifier', 'MLPClassifier', 'PassiveAggressiveClassifier']
# =======Choice 87=======
# ['KNN', 'RidgeClassifier', 'XGBClassifier', 'ExtraTreesClassifier', 'RbfKernelSVM', 'GradientBoostingClassifier', 'PolyKernelSVM', 'MLPClassifier', 'BaggingClassifier', 'SGDClassifier', 'PassiveAggressiveClassifier']
# =======Choice 88=======
# ['AdaBoostClassifier', 'NuSVC', 'GradientBoostingClassifier', 'DecisionTreeClassifier', 'ExtraTreesClassifier', 'BaggingClassifier', 'LinearSVM', 'RbfKernelSVM', 'LinearDiscriminantAnalysis', 'SGDClassifier', 'QuadraticDiscriminantAnalysis', 'RandomForestClassifier', 'MLPClassifier', 'PolyKernelSVM', 'RidgeClassifier', 'XGBClassifier', 'LogisticRegression', 'PassiveAggressiveClassifier', 'GaussianNB', 'KNN']
# =======Choice 89=======
# ['GaussianNB', 'MLPClassifier', 'GradientBoostingClassifier', 'PolyKernelSVM', 'BaggingClassifier', 'NuSVC', 'SGDClassifier', 'KNN', 'DecisionTreeClassifier', 'LogisticRegression', 'LinearDiscriminantAnalysis']
# =======Choice 90=======
# ['SGDClassifier', 'GradientBoostingClassifier', 'NuSVC', 'LinearDiscriminantAnalysis', 'DecisionTreeClassifier']
# =======Choice 91=======
# ['RandomForestClassifier', 'AdaBoostClassifier', 'KNN', 'QuadraticDiscriminantAnalysis', 'GaussianNB', 'BaggingClassifier', 'RidgeClassifier', 'LogisticRegression', 'NuSVC', 'PassiveAggressiveClassifier', 'LinearDiscriminantAnalysis', 'SGDClassifier', 'LinearSVM', 'XGBClassifier']
# =======Choice 92=======
# ['SGDClassifier', 'AdaBoostClassifier', 'KNN', 'RidgeClassifier', 'BaggingClassifier', 'PolyKernelSVM', 'PassiveAggressiveClassifier', 'LogisticRegression', 'LinearDiscriminantAnalysis', 'QuadraticDiscriminantAnalysis', 'LinearSVM', 'DecisionTreeClassifier', 'ExtraTreesClassifier', 'MLPClassifier', 'GradientBoostingClassifier', 'NuSVC', 'RbfKernelSVM', 'GaussianNB', 'XGBClassifier', 'RandomForestClassifier']
# =======Choice 93=======
# ['GaussianNB', 'DecisionTreeClassifier', 'XGBClassifier', 'RbfKernelSVM']
# =======Choice 94=======
# ['ExtraTreesClassifier', 'XGBClassifier', 'KNN']
# =======Choice 95=======
# ['LinearSVM', 'RidgeClassifier', 'MLPClassifier', 'LogisticRegression', 'PassiveAggressiveClassifier', 'AdaBoostClassifier', 'GradientBoostingClassifier', 'RandomForestClassifier', 'BaggingClassifier', 'LinearDiscriminantAnalysis', 'SGDClassifier', 'PolyKernelSVM', 'XGBClassifier']
# =======Choice 96=======
# ['PolyKernelSVM', 'NuSVC', 'BaggingClassifier', 'RidgeClassifier', 'QuadraticDiscriminantAnalysis', 'DecisionTreeClassifier', 'XGBClassifier', 'SGDClassifier', 'LinearDiscriminantAnalysis', 'MLPClassifier', 'LogisticRegression', 'LinearSVM', 'PassiveAggressiveClassifier', 'GradientBoostingClassifier', 'RbfKernelSVM', 'RandomForestClassifier', 'GaussianNB']
# =======Choice 97=======
# ['PassiveAggressiveClassifier', 'SGDClassifier', 'LogisticRegression', 'AdaBoostClassifier', 'GradientBoostingClassifier', 'RbfKernelSVM']
# =======Choice 98=======
# ['AdaBoostClassifier', 'SGDClassifier', 'ExtraTreesClassifier', 'BaggingClassifier', 'DecisionTreeClassifier', 'RbfKernelSVM', 'GaussianNB', 'XGBClassifier', 'PassiveAggressiveClassifier', 'PolyKernelSVM', 'NuSVC', 'RandomForestClassifier', 'MLPClassifier', 'GradientBoostingClassifier', 'QuadraticDiscriminantAnalysis']
# =======Choice 99=======
# ['LogisticRegression', 'RidgeClassifier', 'LinearSVM', 'QuadraticDiscriminantAnalysis', 'XGBClassifier', 'KNN', 'PassiveAggressiveClassifier', 'ExtraTreesClassifier', 'AdaBoostClassifier', 'LinearDiscriminantAnalysis', 'PolyKernelSVM']
# =======Choice 100=======
# ['RbfKernelSVM', 'GaussianNB', 'PassiveAggressiveClassifier', 'SGDClassifier', 'BaggingClassifier', 'GradientBoostingClassifier', 'LinearDiscriminantAnalysis', 'DecisionTreeClassifier', 'MLPClassifier']
# =======Choice 101=======
# ['LogisticRegression', 'DecisionTreeClassifier', 'LinearSVM', 'RandomForestClassifier', 'PolyKernelSVM', 'BaggingClassifier', 'XGBClassifier', 'NuSVC', 'ExtraTreesClassifier', 'PassiveAggressiveClassifier', 'KNN', 'LinearDiscriminantAnalysis', 'MLPClassifier', 'RbfKernelSVM', 'QuadraticDiscriminantAnalysis', 'AdaBoostClassifier', 'SGDClassifier', 'RidgeClassifier', 'GaussianNB', 'GradientBoostingClassifier']
# =======Choice 102=======
# ['AdaBoostClassifier', 'PolyKernelSVM', 'KNN', 'RbfKernelSVM', 'DecisionTreeClassifier', 'RidgeClassifier']
# =======Choice 103=======
# ['XGBClassifier', 'GradientBoostingClassifier', 'LinearDiscriminantAnalysis']
# =======Choice 104=======
# ['QuadraticDiscriminantAnalysis', 'XGBClassifier', 'PolyKernelSVM', 'NuSVC']
# =======Choice 105=======
# ['GradientBoostingClassifier', 'RandomForestClassifier', 'ExtraTreesClassifier', 'GaussianNB', 'DecisionTreeClassifier', 'BaggingClassifier', 'AdaBoostClassifier', 'PolyKernelSVM', 'LinearDiscriminantAnalysis', 'LinearSVM', 'RbfKernelSVM', 'XGBClassifier', 'LogisticRegression', 'SGDClassifier', 'QuadraticDiscriminantAnalysis']
# =======Choice 106=======
# ['XGBClassifier', 'LinearSVM', 'BaggingClassifier', 'RidgeClassifier', 'GaussianNB', 'DecisionTreeClassifier', 'RandomForestClassifier', 'NuSVC', 'ExtraTreesClassifier', 'KNN', 'SGDClassifier', 'LinearDiscriminantAnalysis', 'PolyKernelSVM', 'QuadraticDiscriminantAnalysis', 'AdaBoostClassifier', 'RbfKernelSVM', 'MLPClassifier', 'PassiveAggressiveClassifier']
# =======Choice 107=======
# ['GradientBoostingClassifier', 'RandomForestClassifier', 'LogisticRegression']
# =======Choice 108=======
# ['BaggingClassifier', 'KNN', 'RbfKernelSVM', 'LinearDiscriminantAnalysis', 'XGBClassifier', 'SGDClassifier', 'RidgeClassifier', 'GradientBoostingClassifier', 'PassiveAggressiveClassifier']
# =======Choice 109=======
# ['GradientBoostingClassifier', 'LinearSVM', 'MLPClassifier', 'PassiveAggressiveClassifier', 'RidgeClassifier', 'LogisticRegression']
# =======Choice 110=======
# ['KNN', 'RbfKernelSVM', 'MLPClassifier', 'NuSVC', 'PassiveAggressiveClassifier', 'BaggingClassifier', 'PolyKernelSVM', 'GradientBoostingClassifier', 'LogisticRegression', 'RidgeClassifier', 'AdaBoostClassifier', 'RandomForestClassifier', 'QuadraticDiscriminantAnalysis', 'XGBClassifier', 'LinearDiscriminantAnalysis', 'GaussianNB', 'SGDClassifier', 'LinearSVM']
# =======Choice 111=======
# ['LinearDiscriminantAnalysis', 'NuSVC', 'LinearSVM', 'LogisticRegression', 'GaussianNB', 'PolyKernelSVM', 'DecisionTreeClassifier', 'XGBClassifier', 'ExtraTreesClassifier']
# =======Choice 112=======
# ['PolyKernelSVM', 'RandomForestClassifier', 'RidgeClassifier', 'SGDClassifier', 'KNN', 'LogisticRegression', 'RbfKernelSVM', 'BaggingClassifier', 'XGBClassifier', 'DecisionTreeClassifier', 'PassiveAggressiveClassifier']
# =======Choice 113=======
# ['GaussianNB', 'ExtraTreesClassifier', 'RandomForestClassifier']
# =======Choice 114=======
# ['KNN', 'LinearSVM', 'GradientBoostingClassifier', 'BaggingClassifier', 'SGDClassifier', 'DecisionTreeClassifier', 'GaussianNB', 'RandomForestClassifier']
# =======Choice 115=======
# ['DecisionTreeClassifier', 'LogisticRegression', 'KNN', 'NuSVC', 'QuadraticDiscriminantAnalysis', 'SGDClassifier', 'GaussianNB', 'GradientBoostingClassifier', 'LinearSVM', 'RbfKernelSVM', 'PolyKernelSVM', 'ExtraTreesClassifier', 'BaggingClassifier', 'MLPClassifier', 'XGBClassifier', 'LinearDiscriminantAnalysis', 'AdaBoostClassifier', 'RandomForestClassifier', 'PassiveAggressiveClassifier']
# =======Choice 116=======
# ['QuadraticDiscriminantAnalysis', 'GradientBoostingClassifier', 'LinearSVM']
# =======Choice 117=======
# ['PolyKernelSVM', 'LinearSVM', 'KNN', 'RbfKernelSVM', 'XGBClassifier', 'GradientBoostingClassifier', 'AdaBoostClassifier', 'LinearDiscriminantAnalysis']
# =======Choice 118=======
# ['PassiveAggressiveClassifier', 'PolyKernelSVM', 'KNN', 'RbfKernelSVM', 'BaggingClassifier', 'RandomForestClassifier', 'MLPClassifier', 'GradientBoostingClassifier', 'QuadraticDiscriminantAnalysis', 'ExtraTreesClassifier']
# =======Choice 119=======
# ['GaussianNB', 'SGDClassifier', 'GradientBoostingClassifier', 'LogisticRegression']
# =======Choice 120=======
# ['XGBClassifier', 'MLPClassifier', 'SGDClassifier', 'PolyKernelSVM', 'ExtraTreesClassifier', 'GradientBoostingClassifier', 'RbfKernelSVM', 'AdaBoostClassifier', 'GaussianNB', 'RandomForestClassifier', 'LinearDiscriminantAnalysis', 'LinearSVM', 'BaggingClassifier', 'DecisionTreeClassifier']
# =======Choice 121=======
# ['GaussianNB', 'PolyKernelSVM', 'RandomForestClassifier', 'AdaBoostClassifier', 'PassiveAggressiveClassifier', 'QuadraticDiscriminantAnalysis', 'LinearSVM', 'GradientBoostingClassifier', 'ExtraTreesClassifier', 'DecisionTreeClassifier', 'NuSVC', 'RbfKernelSVM', 'RidgeClassifier', 'SGDClassifier', 'LinearDiscriminantAnalysis', 'XGBClassifier']
# =======Choice 122=======
# ['AdaBoostClassifier', 'NuSVC', 'DecisionTreeClassifier', 'LinearDiscriminantAnalysis']
# =======Choice 123=======
# ['LinearDiscriminantAnalysis', 'LinearSVM', 'RbfKernelSVM', 'QuadraticDiscriminantAnalysis', 'AdaBoostClassifier', 'BaggingClassifier', 'DecisionTreeClassifier']
# =======Choice 124=======
# ['QuadraticDiscriminantAnalysis', 'NuSVC', 'GaussianNB', 'LinearDiscriminantAnalysis', 'RandomForestClassifier']
# =======Choice 125=======
# ['AdaBoostClassifier', 'DecisionTreeClassifier', 'MLPClassifier', 'LinearSVM', 'PassiveAggressiveClassifier', 'NuSVC', 'LinearDiscriminantAnalysis', 'GaussianNB', 'RbfKernelSVM', 'PolyKernelSVM']
# =======Choice 126=======
# ['PassiveAggressiveClassifier', 'PolyKernelSVM', 'RidgeClassifier', 'NuSVC', 'LogisticRegression', 'GradientBoostingClassifier']
# =======Choice 127=======
# ['RbfKernelSVM', 'LinearDiscriminantAnalysis', 'SGDClassifier', 'PassiveAggressiveClassifier', 'RidgeClassifier', 'DecisionTreeClassifier', 'ExtraTreesClassifier', 'XGBClassifier', 'KNN', 'PolyKernelSVM', 'QuadraticDiscriminantAnalysis', 'GaussianNB', 'LogisticRegression']
# =======Choice 128=======
# ['SGDClassifier', 'XGBClassifier', 'DecisionTreeClassifier', 'LinearDiscriminantAnalysis', 'RandomForestClassifier', 'GradientBoostingClassifier', 'KNN', 'LogisticRegression', 'BaggingClassifier', 'RidgeClassifier', 'GaussianNB', 'PassiveAggressiveClassifier']
# =======Choice 129=======
# ['XGBClassifier', 'LinearSVM', 'LinearDiscriminantAnalysis', 'RidgeClassifier', 'ExtraTreesClassifier', 'PolyKernelSVM', 'LogisticRegression']
# =======Choice 130=======
# ['SGDClassifier', 'PassiveAggressiveClassifier', 'ExtraTreesClassifier', 'GradientBoostingClassifier', 'LinearSVM', 'XGBClassifier', 'AdaBoostClassifier', 'PolyKernelSVM', 'RbfKernelSVM', 'DecisionTreeClassifier', 'NuSVC', 'GaussianNB', 'LogisticRegression', 'RidgeClassifier', 'BaggingClassifier', 'KNN']
# =======Choice 131=======
# ['PassiveAggressiveClassifier', 'NuSVC', 'GradientBoostingClassifier', 'LinearDiscriminantAnalysis', 'MLPClassifier', 'LogisticRegression', 'KNN', 'GaussianNB', 'DecisionTreeClassifier', 'RbfKernelSVM', 'RandomForestClassifier']
# =======Choice 132=======
# ['LinearDiscriminantAnalysis', 'KNN', 'RidgeClassifier', 'RbfKernelSVM', 'LinearSVM', 'XGBClassifier', 'QuadraticDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'SGDClassifier']
# =======Choice 133=======
# ['RidgeClassifier', 'NuSVC', 'RandomForestClassifier', 'RbfKernelSVM', 'GradientBoostingClassifier', 'LogisticRegression', 'BaggingClassifier', 'GaussianNB', 'XGBClassifier']
# =======Choice 134=======
# ['SGDClassifier', 'PolyKernelSVM', 'LogisticRegression', 'BaggingClassifier', 'MLPClassifier', 'LinearDiscriminantAnalysis', 'ExtraTreesClassifier', 'PassiveAggressiveClassifier', 'GaussianNB', 'GradientBoostingClassifier', 'KNN', 'NuSVC', 'XGBClassifier', 'QuadraticDiscriminantAnalysis']
# =======Choice 135=======
# ['GaussianNB', 'LogisticRegression', 'QuadraticDiscriminantAnalysis', 'GradientBoostingClassifier', 'KNN', 'RidgeClassifier', 'MLPClassifier', 'RbfKernelSVM']
# =======Choice 136=======
# ['GaussianNB', 'LogisticRegression', 'GradientBoostingClassifier', 'MLPClassifier', 'KNN', 'LinearDiscriminantAnalysis', 'RbfKernelSVM', 'RidgeClassifier', 'ExtraTreesClassifier', 'PolyKernelSVM', 'PassiveAggressiveClassifier', 'BaggingClassifier', 'DecisionTreeClassifier', 'QuadraticDiscriminantAnalysis', 'XGBClassifier', 'AdaBoostClassifier', 'RandomForestClassifier', 'SGDClassifier', 'LinearSVM', 'NuSVC']
# =======Choice 137=======
# ['QuadraticDiscriminantAnalysis', 'LogisticRegression', 'PassiveAggressiveClassifier']
# =======Choice 138=======
# ['MLPClassifier', 'QuadraticDiscriminantAnalysis', 'LinearSVM', 'AdaBoostClassifier', 'NuSVC', 'GaussianNB', 'ExtraTreesClassifier', 'LogisticRegression', 'PassiveAggressiveClassifier', 'BaggingClassifier']
# =======Choice 139=======
# ['BaggingClassifier', 'RidgeClassifier', 'NuSVC', 'AdaBoostClassifier', 'SGDClassifier', 'LinearSVM', 'DecisionTreeClassifier', 'LogisticRegression', 'PolyKernelSVM', 'ExtraTreesClassifier', 'RandomForestClassifier', 'MLPClassifier', 'GradientBoostingClassifier', 'GaussianNB', 'PassiveAggressiveClassifier', 'RbfKernelSVM']
# =======Choice 140=======
# ['ExtraTreesClassifier', 'NuSVC', 'QuadraticDiscriminantAnalysis', 'AdaBoostClassifier', 'RandomForestClassifier', 'LogisticRegression', 'DecisionTreeClassifier', 'LinearDiscriminantAnalysis', 'RidgeClassifier', 'SGDClassifier', 'PolyKernelSVM', 'MLPClassifier']
# =======Choice 141=======
# ['XGBClassifier', 'MLPClassifier', 'QuadraticDiscriminantAnalysis', 'GradientBoostingClassifier', 'SGDClassifier', 'AdaBoostClassifier', 'DecisionTreeClassifier']
# =======Choice 142=======
# ['LinearDiscriminantAnalysis', 'GaussianNB', 'LinearSVM', 'RandomForestClassifier', 'SGDClassifier', 'QuadraticDiscriminantAnalysis', 'RbfKernelSVM', 'BaggingClassifier', 'NuSVC', 'PassiveAggressiveClassifier', 'DecisionTreeClassifier', 'ExtraTreesClassifier', 'PolyKernelSVM', 'KNN', 'LogisticRegression', 'XGBClassifier', 'AdaBoostClassifier', 'RidgeClassifier', 'GradientBoostingClassifier']
# =======Choice 143=======
# ['RandomForestClassifier', 'XGBClassifier', 'ExtraTreesClassifier', 'PassiveAggressiveClassifier', 'GradientBoostingClassifier', 'NuSVC', 'DecisionTreeClassifier', 'MLPClassifier', 'BaggingClassifier', 'AdaBoostClassifier']
# =======Choice 144=======
# ['GradientBoostingClassifier', 'RidgeClassifier', 'SGDClassifier', 'GaussianNB', 'RbfKernelSVM', 'PassiveAggressiveClassifier', 'MLPClassifier', 'LogisticRegression', 'BaggingClassifier', 'RandomForestClassifier', 'AdaBoostClassifier', 'LinearDiscriminantAnalysis']
# =======Choice 145=======
# ['SGDClassifier', 'AdaBoostClassifier', 'PassiveAggressiveClassifier', 'XGBClassifier', 'NuSVC', 'PolyKernelSVM', 'QuadraticDiscriminantAnalysis', 'RandomForestClassifier', 'LogisticRegression', 'RidgeClassifier', 'BaggingClassifier', 'GaussianNB', 'LinearSVM', 'LinearDiscriminantAnalysis', 'RbfKernelSVM', 'MLPClassifier', 'GradientBoostingClassifier', 'DecisionTreeClassifier', 'ExtraTreesClassifier']
# =======Choice 146=======
# ['PassiveAggressiveClassifier', 'RbfKernelSVM', 'SGDClassifier', 'KNN', 'RidgeClassifier', 'BaggingClassifier', 'AdaBoostClassifier', 'GaussianNB', 'QuadraticDiscriminantAnalysis', 'PolyKernelSVM', 'DecisionTreeClassifier', 'MLPClassifier', 'LogisticRegression', 'XGBClassifier']
# =======Choice 147=======
# ['AdaBoostClassifier', 'RandomForestClassifier', 'RbfKernelSVM', 'ExtraTreesClassifier', 'NuSVC', 'MLPClassifier', 'XGBClassifier', 'LinearDiscriminantAnalysis', 'PolyKernelSVM', 'BaggingClassifier', 'LogisticRegression']
# =======Choice 148=======
# ['PassiveAggressiveClassifier', 'BaggingClassifier', 'LinearSVM', 'RandomForestClassifier', 'MLPClassifier', 'DecisionTreeClassifier', 'RbfKernelSVM', 'GradientBoostingClassifier', 'SGDClassifier', 'GaussianNB', 'XGBClassifier', 'RidgeClassifier', 'ExtraTreesClassifier']
# =======Choice 149=======
# ['DecisionTreeClassifier', 'RbfKernelSVM', 'BaggingClassifier', 'GradientBoostingClassifier', 'PassiveAggressiveClassifier', 'NuSVC', 'QuadraticDiscriminantAnalysis', 'SGDClassifier']
# =======Choice 150=======
# ['RandomForestClassifier', 'XGBClassifier', 'PassiveAggressiveClassifier', 'PolyKernelSVM', 'ExtraTreesClassifier', 'QuadraticDiscriminantAnalysis', 'SGDClassifier', 'DecisionTreeClassifier', 'AdaBoostClassifier', 'NuSVC', 'RbfKernelSVM', 'MLPClassifier', 'RidgeClassifier', 'LinearSVM', 'GradientBoostingClassifier', 'GaussianNB', 'KNN', 'LinearDiscriminantAnalysis', 'BaggingClassifier', 'LogisticRegression']
# =======Choice 151=======
# ['ExtraTreesClassifier', 'LinearDiscriminantAnalysis', 'LogisticRegression']
# =======Choice 152=======
# ['LinearSVM', 'PolyKernelSVM', 'XGBClassifier', 'AdaBoostClassifier', 'DecisionTreeClassifier', 'LinearDiscriminantAnalysis', 'RidgeClassifier', 'QuadraticDiscriminantAnalysis', 'SGDClassifier', 'ExtraTreesClassifier']
# =======Choice 153=======
# ['KNN', 'GradientBoostingClassifier', 'PolyKernelSVM', 'MLPClassifier', 'BaggingClassifier', 'LinearSVM']
# =======Choice 154=======
# ['PolyKernelSVM', 'LogisticRegression', 'GradientBoostingClassifier', 'DecisionTreeClassifier']
# =======Choice 155=======
# ['RandomForestClassifier', 'RbfKernelSVM', 'DecisionTreeClassifier', 'SGDClassifier', 'KNN', 'AdaBoostClassifier', 'PassiveAggressiveClassifier', 'GradientBoostingClassifier', 'BaggingClassifier', 'QuadraticDiscriminantAnalysis']
# =======Choice 156=======
# ['LogisticRegression', 'AdaBoostClassifier', 'RbfKernelSVM', 'NuSVC', 'DecisionTreeClassifier', 'GaussianNB', 'PolyKernelSVM', 'LinearDiscriminantAnalysis', 'RidgeClassifier', 'GradientBoostingClassifier', 'LinearSVM', 'QuadraticDiscriminantAnalysis', 'SGDClassifier', 'PassiveAggressiveClassifier', 'ExtraTreesClassifier', 'KNN', 'RandomForestClassifier']
# =======Choice 157=======
# ['XGBClassifier', 'ExtraTreesClassifier', 'QuadraticDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'LogisticRegression', 'LinearDiscriminantAnalysis', 'BaggingClassifier', 'GaussianNB', 'RidgeClassifier', 'NuSVC', 'RandomForestClassifier', 'SGDClassifier', 'KNN', 'GradientBoostingClassifier', 'AdaBoostClassifier', 'DecisionTreeClassifier']
# =======Choice 158=======
# ['MLPClassifier', 'LinearSVM', 'DecisionTreeClassifier', 'AdaBoostClassifier', 'GaussianNB', 'GradientBoostingClassifier', 'RbfKernelSVM', 'LinearDiscriminantAnalysis', 'BaggingClassifier', 'PassiveAggressiveClassifier', 'RandomForestClassifier', 'NuSVC', 'ExtraTreesClassifier', 'LogisticRegression', 'QuadraticDiscriminantAnalysis', 'KNN', 'PolyKernelSVM', 'RidgeClassifier']
# =======Choice 159=======
# ['KNN', 'LogisticRegression', 'MLPClassifier', 'XGBClassifier', 'RidgeClassifier', 'ExtraTreesClassifier', 'AdaBoostClassifier', 'QuadraticDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'RandomForestClassifier', 'GradientBoostingClassifier']
# =======Choice 160=======
# ['GradientBoostingClassifier', 'GaussianNB', 'SGDClassifier']
# =======Choice 161=======
# ['GradientBoostingClassifier', 'DecisionTreeClassifier', 'RandomForestClassifier', 'LinearDiscriminantAnalysis', 'SGDClassifier', 'XGBClassifier']
# =======Choice 162=======
# ['DecisionTreeClassifier', 'ExtraTreesClassifier', 'BaggingClassifier', 'LinearDiscriminantAnalysis', 'RandomForestClassifier', 'PolyKernelSVM', 'MLPClassifier', 'LogisticRegression', 'XGBClassifier', 'SGDClassifier', 'AdaBoostClassifier', 'GaussianNB', 'QuadraticDiscriminantAnalysis', 'LinearSVM']
# =======Choice 163=======
# ['GradientBoostingClassifier', 'NuSVC', 'PolyKernelSVM', 'RidgeClassifier', 'DecisionTreeClassifier', 'PassiveAggressiveClassifier', 'RbfKernelSVM']
# =======Choice 164=======
# ['GradientBoostingClassifier', 'KNN', 'NuSVC', 'LogisticRegression', 'LinearDiscriminantAnalysis', 'RbfKernelSVM', 'BaggingClassifier', 'SGDClassifier', 'RandomForestClassifier', 'DecisionTreeClassifier', 'LinearSVM']
# =======Choice 165=======
# ['RbfKernelSVM', 'GaussianNB', 'AdaBoostClassifier', 'ExtraTreesClassifier', 'LinearDiscriminantAnalysis', 'DecisionTreeClassifier', 'NuSVC', 'QuadraticDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'MLPClassifier', 'XGBClassifier', 'PolyKernelSVM', 'LinearSVM', 'LogisticRegression', 'KNN', 'SGDClassifier', 'RidgeClassifier', 'GradientBoostingClassifier', 'BaggingClassifier', 'RandomForestClassifier']
# =======Choice 166=======
# ['ExtraTreesClassifier', 'BaggingClassifier', 'XGBClassifier', 'MLPClassifier', 'DecisionTreeClassifier', 'NuSVC', 'SGDClassifier', 'RidgeClassifier', 'LinearDiscriminantAnalysis', 'RbfKernelSVM', 'QuadraticDiscriminantAnalysis', 'RandomForestClassifier', 'KNN', 'LogisticRegression']
# =======Choice 167=======
# ['ExtraTreesClassifier', 'LogisticRegression', 'LinearDiscriminantAnalysis', 'DecisionTreeClassifier', 'RidgeClassifier']
# =======Choice 168=======
# ['PassiveAggressiveClassifier', 'RandomForestClassifier', 'PolyKernelSVM', 'BaggingClassifier', 'QuadraticDiscriminantAnalysis', 'RbfKernelSVM', 'KNN', 'LogisticRegression']
# =======Choice 169=======
# ['QuadraticDiscriminantAnalysis', 'SGDClassifier', 'KNN', 'NuSVC', 'RidgeClassifier', 'ExtraTreesClassifier', 'GradientBoostingClassifier', 'RbfKernelSVM', 'PassiveAggressiveClassifier', 'GaussianNB', 'LogisticRegression', 'DecisionTreeClassifier', 'BaggingClassifier', 'LinearSVM', 'AdaBoostClassifier', 'MLPClassifier', 'RandomForestClassifier', 'PolyKernelSVM']
# =======Choice 170=======
# ['LogisticRegression', 'RandomForestClassifier', 'DecisionTreeClassifier', 'NuSVC', 'ExtraTreesClassifier', 'BaggingClassifier', 'QuadraticDiscriminantAnalysis', 'PassiveAggressiveClassifier']
# =======Choice 171=======
# ['BaggingClassifier', 'LinearSVM', 'RbfKernelSVM', 'RidgeClassifier', 'PassiveAggressiveClassifier', 'NuSVC', 'ExtraTreesClassifier', 'QuadraticDiscriminantAnalysis', 'XGBClassifier', 'MLPClassifier', 'LogisticRegression', 'AdaBoostClassifier']
# =======Choice 172=======
# ['BaggingClassifier', 'ExtraTreesClassifier', 'LinearDiscriminantAnalysis', 'SGDClassifier', 'AdaBoostClassifier', 'RidgeClassifier', 'PolyKernelSVM', 'GaussianNB', 'RbfKernelSVM', 'MLPClassifier', 'LinearSVM', 'KNN', 'NuSVC', 'DecisionTreeClassifier', 'PassiveAggressiveClassifier', 'XGBClassifier', 'GradientBoostingClassifier', 'QuadraticDiscriminantAnalysis']
# =======Choice 173=======
# ['KNN', 'QuadraticDiscriminantAnalysis', 'GradientBoostingClassifier', 'LogisticRegression', 'AdaBoostClassifier', 'DecisionTreeClassifier', 'XGBClassifier', 'BaggingClassifier', 'LinearDiscriminantAnalysis', 'ExtraTreesClassifier', 'PassiveAggressiveClassifier', 'NuSVC', 'RandomForestClassifier']
# =======Choice 174=======
# ['DecisionTreeClassifier', 'SGDClassifier', 'KNN', 'BaggingClassifier', 'LogisticRegression', 'LinearDiscriminantAnalysis', 'LinearSVM']
# =======Choice 175=======
# ['LogisticRegression', 'KNN', 'SGDClassifier', 'RandomForestClassifier', 'LinearDiscriminantAnalysis', 'XGBClassifier', 'RidgeClassifier', 'PassiveAggressiveClassifier', 'LinearSVM', 'GradientBoostingClassifier', 'MLPClassifier', 'GaussianNB', 'DecisionTreeClassifier', 'BaggingClassifier', 'AdaBoostClassifier', 'RbfKernelSVM']
# =======Choice 176=======
# ['RandomForestClassifier', 'SGDClassifier', 'BaggingClassifier', 'KNN', 'DecisionTreeClassifier']
# =======Choice 177=======
# ...
# =======Choice 239=======
# ['SGDClassifier', 'RidgeClassifier', 'GaussianNB', 'MLPClassifier', 'AdaBoostClassifier', 'PassiveAggressiveClassifier']
# =======Choice 240=======
# ['ExtraTreesClassifier', 'LinearSVM', 'XGBClassifier']
# =======Choice 241=======
# ['RandomForestClassifier', 'NuSVC', 'SGDClassifier', 'LinearSVM', 'LinearDiscriminantAnalysis', 'PolyKernelSVM', 'QuadraticDiscriminantAnalysis', 'LogisticRegression', 'ExtraTreesClassifier', 'AdaBoostClassifier', 'DecisionTreeClassifier', 'GaussianNB', 'GradientBoostingClassifier', 'RbfKernelSVM']
# =======Choice 242=======
# ['XGBClassifier', 'LinearDiscriminantAnalysis', 'LinearSVM', 'QuadraticDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'ExtraTreesClassifier', 'NuSVC', 'SGDClassifier', 'RandomForestClassifier']
# =======Choice 243=======
# ['XGBClassifier', 'RbfKernelSVM', 'KNN', 'AdaBoostClassifier', 'LinearDiscriminantAnalysis', 'LinearSVM', 'LogisticRegression', 'PolyKernelSVM', 'MLPClassifier', 'GradientBoostingClassifier', 'RidgeClassifier', 'ExtraTreesClassifier', 'BaggingClassifier', 'NuSVC', 'RandomForestClassifier', 'GaussianNB']
# =======Choice 244=======
# ['AdaBoostClassifier', 'KNN', 'GaussianNB', 'LogisticRegression', 'XGBClassifier', 'LinearSVM', 'NuSVC', 'ExtraTreesClassifier', 'SGDClassifier']
# =======Choice 245=======
# ['QuadraticDiscriminantAnalysis', 'RandomForestClassifier', 'XGBClassifier', 'RbfKernelSVM', 'DecisionTreeClassifier', 'GaussianNB', 'KNN', 'LinearDiscriminantAnalysis', 'MLPClassifier', 'PolyKernelSVM', 'LogisticRegression', 'RidgeClassifier', 'NuSVC', 'SGDClassifier', 'GradientBoostingClassifier']
# =======Choice 246=======
# ['RbfKernelSVM', 'RidgeClassifier', 'PassiveAggressiveClassifier', 'ExtraTreesClassifier', 'NuSVC', 'SGDClassifier', 'MLPClassifier', 'AdaBoostClassifier', 'GaussianNB']
# =======Choice 247=======
# ['SGDClassifier', 'PolyKernelSVM', 'NuSVC', 'DecisionTreeClassifier', 'GaussianNB', 'RbfKernelSVM', 'GradientBoostingClassifier', 'XGBClassifier', 'AdaBoostClassifier', 'BaggingClassifier']
# =======Choice 248=======
# ['BaggingClassifier', 'AdaBoostClassifier', 'XGBClassifier', 'ExtraTreesClassifier', 'GaussianNB', 'QuadraticDiscriminantAnalysis', 'MLPClassifier', 'RbfKernelSVM', 'SGDClassifier', 'RidgeClassifier', 'LinearSVM', 'RandomForestClassifier']
# =======Choice 249=======
# ['LinearSVM', 'AdaBoostClassifier', 'KNN', 'QuadraticDiscriminantAnalysis', 'LogisticRegression', 'PolyKernelSVM', 'XGBClassifier', 'DecisionTreeClassifier', 'NuSVC', 'SGDClassifier', 'MLPClassifier', 'RbfKernelSVM', 'GradientBoostingClassifier', 'BaggingClassifier', 'RandomForestClassifier', 'GaussianNB', 'ExtraTreesClassifier']
# =======Choice 250=======
# ['AdaBoostClassifier', 'RbfKernelSVM', 'GradientBoostingClassifier', 'ExtraTreesClassifier', 'PassiveAggressiveClassifier', 'NuSVC', 'QuadraticDiscriminantAnalysis', 'LinearDiscriminantAnalysis', 'SGDClassifier', 'KNN', 'RidgeClassifier', 'MLPClassifier', 'LogisticRegression', 'RandomForestClassifier', 'BaggingClassifier', 'DecisionTreeClassifier', 'PolyKernelSVM', 'LinearSVM']
# =======Choice 251=======
# ['PolyKernelSVM', 'LinearSVM', 'XGBClassifier', 'LogisticRegression', 'QuadraticDiscriminantAnalysis', 'BaggingClassifier', 'RbfKernelSVM', 'GaussianNB', 'DecisionTreeClassifier', 'MLPClassifier', 'LinearDiscriminantAnalysis', 'ExtraTreesClassifier', 'AdaBoostClassifier', 'RandomForestClassifier', 'NuSVC', 'PassiveAggressiveClassifier', 'SGDClassifier', 'GradientBoostingClassifier']
# =======Choice 252=======
# ['DecisionTreeClassifier', 'RidgeClassifier', 'ExtraTreesClassifier', 'NuSVC', 'GaussianNB', 'GradientBoostingClassifier', 'XGBClassifier', 'PolyKernelSVM', 'SGDClassifier', 'AdaBoostClassifier', 'LogisticRegression', 'LinearSVM', 'BaggingClassifier', 'RandomForestClassifier', 'QuadraticDiscriminantAnalysis', 'KNN', 'PassiveAggressiveClassifier', 'LinearDiscriminantAnalysis']
# =======Choice 253=======
# ['QuadraticDiscriminantAnalysis', 'PolyKernelSVM', 'DecisionTreeClassifier']
# =======Choice 254=======
# ['KNN', 'BaggingClassifier', 'PolyKernelSVM', 'NuSVC', 'PassiveAggressiveClassifier', 'RbfKernelSVM', 'SGDClassifier', 'AdaBoostClassifier', 'XGBClassifier', 'GaussianNB', 'DecisionTreeClassifier', 'LinearSVM', 'RandomForestClassifier', 'QuadraticDiscriminantAnalysis', 'GradientBoostingClassifier']
# =======Choice 255=======
# ['NuSVC', 'KNN', 'LinearDiscriminantAnalysis', 'MLPClassifier', 'PassiveAggressiveClassifier', 'ExtraTreesClassifier', 'SGDClassifier', 'PolyKernelSVM', 'DecisionTreeClassifier', 'XGBClassifier', 'LogisticRegression', 'GaussianNB', 'GradientBoostingClassifier']
# =======Choice 256=======
# ['GradientBoostingClassifier', 'PolyKernelSVM', 'LogisticRegression', 'RbfKernelSVM', 'XGBClassifier', 'KNN', 'ExtraTreesClassifier']
# =======Choice 257=======
# ['LogisticRegression', 'GaussianNB', 'BaggingClassifier', 'NuSVC', 'LinearSVM']
# =======Choice 258=======
# ['SGDClassifier', 'BaggingClassifier', 'ExtraTreesClassifier', 'QuadraticDiscriminantAnalysis', 'KNN', 'RbfKernelSVM', 'DecisionTreeClassifier', 'AdaBoostClassifier', 'PolyKernelSVM', 'LinearDiscriminantAnalysis', 'XGBClassifier', 'PassiveAggressiveClassifier', 'RandomForestClassifier', 'GradientBoostingClassifier', 'LogisticRegression', 'LinearSVM', 'NuSVC']
# =======Choice 259=======
# ['PassiveAggressiveClassifier', 'QuadraticDiscriminantAnalysis', 'BaggingClassifier', 'LinearDiscriminantAnalysis', 'NuSVC', 'RidgeClassifier', 'ExtraTreesClassifier', 'KNN', 'LogisticRegression', 'DecisionTreeClassifier', 'AdaBoostClassifier', 'GradientBoostingClassifier', 'XGBClassifier', 'GaussianNB', 'PolyKernelSVM', 'LinearSVM', 'RbfKernelSVM', 'RandomForestClassifier']
# =======Choice 260=======
# ['PassiveAggressiveClassifier', 'GradientBoostingClassifier', 'DecisionTreeClassifier', 'XGBClassifier', 'RandomForestClassifier', 'LinearDiscriminantAnalysis', 'RidgeClassifier', 'PolyKernelSVM', 'QuadraticDiscriminantAnalysis', 'GaussianNB', 'BaggingClassifier', 'LinearSVM', 'MLPClassifier', 'ExtraTreesClassifier', 'NuSVC', 'AdaBoostClassifier']
# =======Choice 261=======
# ['RbfKernelSVM', 'GaussianNB', 'LinearDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'GradientBoostingClassifier', 'BaggingClassifier', 'QuadraticDiscriminantAnalysis', 'ExtraTreesClassifier', 'DecisionTreeClassifier', 'RidgeClassifier', 'SGDClassifier']
# =======Choice 262=======
# ['PolyKernelSVM', 'GradientBoostingClassifier', 'RidgeClassifier', 'AdaBoostClassifier', 'RandomForestClassifier', 'XGBClassifier', 'LinearSVM', 'ExtraTreesClassifier', 'PassiveAggressiveClassifier', 'MLPClassifier', 'BaggingClassifier', 'KNN', 'QuadraticDiscriminantAnalysis']
# =======Choice 263=======
# ['QuadraticDiscriminantAnalysis', 'PolyKernelSVM', 'MLPClassifier', 'LogisticRegression', 'DecisionTreeClassifier', 'BaggingClassifier', 'NuSVC', 'LinearDiscriminantAnalysis', 'GradientBoostingClassifier', 'AdaBoostClassifier', 'SGDClassifier', 'PassiveAggressiveClassifier', 'RidgeClassifier', 'RandomForestClassifier', 'ExtraTreesClassifier']
# =======Choice 264=======
# ['BaggingClassifier', 'GradientBoostingClassifier', 'KNN', 'XGBClassifier', 'MLPClassifier', 'RbfKernelSVM', 'NuSVC', 'DecisionTreeClassifier', 'RandomForestClassifier', 'RidgeClassifier', 'PassiveAggressiveClassifier', 'QuadraticDiscriminantAnalysis', 'GaussianNB', 'PolyKernelSVM']
# =======Choice 265=======
# ['LogisticRegression', 'SGDClassifier', 'RbfKernelSVM', 'BaggingClassifier', 'GaussianNB', 'RidgeClassifier', 'DecisionTreeClassifier', 'LinearSVM', 'PolyKernelSVM', 'NuSVC', 'ExtraTreesClassifier', 'RandomForestClassifier', 'AdaBoostClassifier', 'KNN', 'XGBClassifier', 'GradientBoostingClassifier', 'LinearDiscriminantAnalysis', 'MLPClassifier', 'PassiveAggressiveClassifier']
# =======Choice 266=======
# ['PassiveAggressiveClassifier', 'DecisionTreeClassifier', 'SGDClassifier', 'KNN', 'RidgeClassifier', 'LinearDiscriminantAnalysis', 'NuSVC', 'ExtraTreesClassifier', 'BaggingClassifier', 'MLPClassifier', 'LogisticRegression']
# =======Choice 267=======
# ['PolyKernelSVM', 'DecisionTreeClassifier', 'ExtraTreesClassifier', 'GaussianNB', 'RbfKernelSVM', 'AdaBoostClassifier', 'XGBClassifier', 'QuadraticDiscriminantAnalysis', 'MLPClassifier', 'LinearSVM', 'RandomForestClassifier', 'GradientBoostingClassifier', 'KNN', 'NuSVC', 'SGDClassifier', 'RidgeClassifier', 'PassiveAggressiveClassifier', 'LinearDiscriminantAnalysis', 'LogisticRegression', 'BaggingClassifier']
# =======Choice 268=======
# ['SGDClassifier', 'BaggingClassifier', 'AdaBoostClassifier', 'RidgeClassifier', 'XGBClassifier', 'QuadraticDiscriminantAnalysis', 'NuSVC', 'GaussianNB', 'PassiveAggressiveClassifier', 'LinearDiscriminantAnalysis', 'PolyKernelSVM', 'LogisticRegression', 'MLPClassifier', 'ExtraTreesClassifier', 'GradientBoostingClassifier', 'LinearSVM', 'DecisionTreeClassifier']
# =======Choice 269=======
# ['LogisticRegression', 'MLPClassifier', 'LinearSVM', 'ExtraTreesClassifier', 'GradientBoostingClassifier', 'XGBClassifier', 'DecisionTreeClassifier', 'PolyKernelSVM', 'SGDClassifier', 'NuSVC']
# =======Choice 270=======
# ['MLPClassifier', 'GradientBoostingClassifier', 'LogisticRegression', 'QuadraticDiscriminantAnalysis', 'GaussianNB', 'NuSVC', 'DecisionTreeClassifier']
# =======Choice 271=======
# ['GradientBoostingClassifier', 'DecisionTreeClassifier', 'RidgeClassifier', 'LogisticRegression', 'NuSVC', 'ExtraTreesClassifier', 'BaggingClassifier']
# =======Choice 272=======
# ['NuSVC', 'RidgeClassifier', 'AdaBoostClassifier']
# =======Choice 273=======
# ['KNN', 'BaggingClassifier', 'AdaBoostClassifier', 'GaussianNB', 'XGBClassifier', 'PolyKernelSVM']
# =======Choice 274=======
# ['BaggingClassifier', 'GaussianNB', 'RidgeClassifier', 'XGBClassifier', 'LogisticRegression', 'RbfKernelSVM', 'NuSVC', 'MLPClassifier', 'KNN', 'DecisionTreeClassifier', 'PassiveAggressiveClassifier', 'AdaBoostClassifier', 'ExtraTreesClassifier', 'LinearDiscriminantAnalysis', 'SGDClassifier', 'RandomForestClassifier', 'LinearSVM', 'GradientBoostingClassifier', 'PolyKernelSVM', 'QuadraticDiscriminantAnalysis']
# =======Choice 275=======
# ['NuSVC', 'LinearSVM', 'PassiveAggressiveClassifier', 'QuadraticDiscriminantAnalysis', 'MLPClassifier', 'RbfKernelSVM', 'PolyKernelSVM', 'GradientBoostingClassifier']
# =======Choice 276=======
# ['XGBClassifier', 'KNN', 'LogisticRegression', 'RbfKernelSVM', 'GaussianNB', 'SGDClassifier', 'LinearDiscriminantAnalysis', 'NuSVC', 'MLPClassifier', 'BaggingClassifier', 'GradientBoostingClassifier', 'LinearSVM']
# =======Choice 277=======
# ['ExtraTreesClassifier', 'LogisticRegression', 'BaggingClassifier', 'NuSVC', 'AdaBoostClassifier', 'RidgeClassifier', 'MLPClassifier', 'XGBClassifier', 'GradientBoostingClassifier', 'LinearDiscriminantAnalysis', 'RandomForestClassifier', 'GaussianNB', 'LinearSVM', 'KNN', 'SGDClassifier', 'DecisionTreeClassifier', 'QuadraticDiscriminantAnalysis', 'RbfKernelSVM', 'PassiveAggressiveClassifier']
# =======Choice 278=======
# ['RandomForestClassifier', 'GradientBoostingClassifier', 'RbfKernelSVM', 'PassiveAggressiveClassifier', 'QuadraticDiscriminantAnalysis', 'NuSVC', 'XGBClassifier', 'MLPClassifier']
# =======Choice 279=======
# ['RbfKernelSVM', 'SGDClassifier', 'DecisionTreeClassifier', 'RandomForestClassifier', 'GradientBoostingClassifier', 'NuSVC', 'XGBClassifier', 'LinearDiscriminantAnalysis', 'PolyKernelSVM', 'MLPClassifier']
# =======Choice 280=======
# ['LinearSVM', 'SGDClassifier', 'DecisionTreeClassifier', 'RidgeClassifier', 'GaussianNB', 'QuadraticDiscriminantAnalysis', 'LinearDiscriminantAnalysis', 'LogisticRegression', 'RandomForestClassifier', 'NuSVC', 'PassiveAggressiveClassifier', 'GradientBoostingClassifier', 'KNN']
# =======Choice 281=======
# ['AdaBoostClassifier', 'NuSVC', 'GaussianNB', 'LogisticRegression', 'RandomForestClassifier', 'PassiveAggressiveClassifier', 'DecisionTreeClassifier', 'RbfKernelSVM', 'PolyKernelSVM', 'BaggingClassifier', 'KNN', 'RidgeClassifier', 'SGDClassifier', 'QuadraticDiscriminantAnalysis', 'ExtraTreesClassifier', 'LinearDiscriminantAnalysis', 'XGBClassifier', 'MLPClassifier', 'GradientBoostingClassifier', 'LinearSVM']
# =======Choice 282=======
# ['SGDClassifier', 'AdaBoostClassifier', 'PolyKernelSVM', 'GradientBoostingClassifier', 'NuSVC', 'MLPClassifier', 'LogisticRegression', 'BaggingClassifier', 'RbfKernelSVM']
# =======Choice 283=======
# ['RbfKernelSVM', 'RandomForestClassifier', 'SGDClassifier', 'PassiveAggressiveClassifier', 'PolyKernelSVM', 'MLPClassifier', 'NuSVC', 'LogisticRegression', 'RidgeClassifier']
# =======Choice 284=======
# ['LogisticRegression', 'NuSVC', 'RidgeClassifier', 'MLPClassifier', 'GradientBoostingClassifier']
# =======Choice 285=======
# ['RidgeClassifier', 'LinearSVM', 'PassiveAggressiveClassifier', 'KNN']
# =======Choice 286=======
# ['PassiveAggressiveClassifier', 'PolyKernelSVM', 'LinearDiscriminantAnalysis', 'NuSVC', 'KNN', 'QuadraticDiscriminantAnalysis', 'SGDClassifier', 'AdaBoostClassifier', 'MLPClassifier', 'RbfKernelSVM', 'RidgeClassifier', 'DecisionTreeClassifier']
# =======Choice 287=======
# ['MLPClassifier', 'LogisticRegression', 'RandomForestClassifier', 'LinearSVM', 'DecisionTreeClassifier', 'NuSVC', 'PassiveAggressiveClassifier', 'ExtraTreesClassifier']
# =======Choice 288=======
# ['XGBClassifier', 'PolyKernelSVM', 'MLPClassifier', 'LinearDiscriminantAnalysis', 'KNN']
# =======Choice 289=======
# ['PolyKernelSVM', 'XGBClassifier', 'GradientBoostingClassifier', 'KNN', 'NuSVC', 'RidgeClassifier']
# =======Choice 290=======
# ['SGDClassifier', 'PolyKernelSVM', 'QuadraticDiscriminantAnalysis', 'ExtraTreesClassifier', 'DecisionTreeClassifier', 'XGBClassifier', 'GradientBoostingClassifier', 'RandomForestClassifier', 'MLPClassifier', 'BaggingClassifier', 'AdaBoostClassifier', 'GaussianNB', 'KNN', 'PassiveAggressiveClassifier', 'NuSVC', 'LinearSVM', 'LogisticRegression', 'RidgeClassifier']
# =======Choice 291=======
# ['QuadraticDiscriminantAnalysis', 'RbfKernelSVM', 'PolyKernelSVM', 'NuSVC', 'LinearSVM', 'ExtraTreesClassifier', 'SGDClassifier', 'RandomForestClassifier', 'LinearDiscriminantAnalysis', 'BaggingClassifier', 'DecisionTreeClassifier', 'GaussianNB', 'AdaBoostClassifier', 'RidgeClassifier', 'PassiveAggressiveClassifier', 'XGBClassifier', 'GradientBoostingClassifier']
# =======Choice 292=======
# ['ExtraTreesClassifier', 'LinearDiscriminantAnalysis', 'RidgeClassifier', 'RbfKernelSVM', 'LinearSVM']
# =======Choice 293=======
# ['NuSVC', 'PassiveAggressiveClassifier', 'LinearSVM', 'RandomForestClassifier', 'RidgeClassifier']
# =======Choice 294=======
# ['MLPClassifier', 'KNN', 'PassiveAggressiveClassifier', 'ExtraTreesClassifier', 'LogisticRegression', 'XGBClassifier', 'BaggingClassifier', 'SGDClassifier', 'RandomForestClassifier', 'GaussianNB', 'RidgeClassifier', 'GradientBoostingClassifier']
# =======Choice 295=======
# ['ExtraTreesClassifier', 'GradientBoostingClassifier', 'BaggingClassifier']
# =======Choice 296=======
# ['SGDClassifier', 'KNN', 'AdaBoostClassifier', 'DecisionTreeClassifier', 'GaussianNB', 'BaggingClassifier', 'LinearDiscriminantAnalysis']
# =======Choice 297=======
# ['GaussianNB', 'BaggingClassifier', 'SGDClassifier', 'PassiveAggressiveClassifier', 'PolyKernelSVM', 'ExtraTreesClassifier', 'AdaBoostClassifier', 'LinearDiscriminantAnalysis', 'MLPClassifier', 'NuSVC', 'LogisticRegression', 'RidgeClassifier', 'RandomForestClassifier', 'DecisionTreeClassifier', 'XGBClassifier', 'RbfKernelSVM']
# =======Choice 298=======
# ['RidgeClassifier', 'ExtraTreesClassifier', 'KNN', 'AdaBoostClassifier', 'PolyKernelSVM', 'NuSVC', 'RandomForestClassifier']
# =======Choice 299=======
# ['LinearDiscriminantAnalysis', 'PolyKernelSVM', 'NuSVC', 'XGBClassifier', 'QuadraticDiscriminantAnalysis', 'AdaBoostClassifier', 'KNN', 'GradientBoostingClassifier', 'BaggingClassifier', 'DecisionTreeClassifier', 'MLPClassifier', 'RidgeClassifier', 'PassiveAggressiveClassifier', 'LogisticRegression', 'ExtraTreesClassifier', 'LinearSVM']

# %%
def voting_grid():
    result_sets = []
    i = 0
    for clf_choice in clf_choices:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            voting_clf = VotingClassifier(estimators=clf_choice, n_jobs=8)
            print_choices_single(clf_choice, i)
            helpers.train_classif_single(voting_clf, clf_choice[0], class_names, X_train, y_train, X_test, y_test, result_sets)
            i = i + 1

# %%
voting_grid()
# Out:
# =======Choice 0=======
# ['LinearDiscriminantAnalysis', 'AdaBoostClassifier', 'RbfKernelSVM', 'RidgeClassifier', 'SGDClassifier', 'RandomForestClassifier', 'BaggingClassifier', 'PassiveAggressiveClassifier', 'XGBClassifier', 'MLPClassifier', 'KNN', 'LogisticRegression', 'GradientBoostingClassifier', 'LinearSVM', 'NuSVC', 'DecisionTreeClassifier', 'ExtraTreesClassifier', 'PolyKernelSVM']
# [0.98734177 0.98467688 0.99333333 0.98999333 0.99066044]
# Accuracy: 0.989 (+/- 0.006)
# ('LinearDiscriminantAnalysis', LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#               solver='svd', store_covariance=False, tol=0.0001)) :
#  [[1228    4   14]
#  [  12  230    0]
#  [   0    0 1012]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.95      0.97       242
#         STAR       0.99      1.00      0.99      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# =======Choice 1=======
# ['RbfKernelSVM', 'NuSVC', 'PolyKernelSVM', 'KNN', 'GaussianNB', 'DecisionTreeClassifier', 'LinearDiscriminantAnalysis', 'PassiveAggressiveClassifier', 'RidgeClassifier', 'AdaBoostClassifier', 'XGBClassifier', 'LinearSVM', 'RandomForestClassifier', 'LogisticRegression', 'GradientBoostingClassifier', 'ExtraTreesClassifier', 'MLPClassifier', 'QuadraticDiscriminantAnalysis', 'BaggingClassifier']
# [0.98734177 0.9853431  0.99266667 0.98999333 0.99066044]
# Accuracy: 0.989 (+/- 0.005)
# ('RbfKernelSVM', SVC(C=18329.8071083243, cache_size=100, class_weight=None,
#   coef0=0.0007847599703514606, decision_function_shape='ovr', degree=8,
#   gamma=0.004281332398719387, kernel='rbf', max_iter=-1, probability=True,
#   random_state=42, shrinking=True, tol=0.001, verbose=False)) :
#  [[1227    5   14]
#  [  11  231    0]
#  [   0    0 1012]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.98      0.99      1246
#          QSO       0.98      0.95      0.97       242
#         STAR       0.99      1.00      0.99      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# =======Choice 2=======
# ['PassiveAggressiveClassifier', 'LinearSVM', 'GradientBoostingClassifier', 'MLPClassifier', 'RbfKernelSVM', 'LogisticRegression', 'RidgeClassifier', 'GaussianNB', 'SGDClassifier']
# [0.98600933 0.9853431  0.99133333 0.99332889 0.99066044]
# Accuracy: 0.989 (+/- 0.006)
# ('PassiveAggressiveClassifier', PassiveAggressiveClassifier(C=1.0, average=False, class_weight='balanced',
#               early_stopping=True, fit_intercept=True, loss='hinge',
#               max_iter=None, n_iter=None, n_iter_no_change=5, n_jobs=4,
#               random_state=42, shuffle=False, tol=None,
#               validation_fraction=0.1, verbose=0, warm_start=False)) :
#  [[1223    4   19]
#  [  10  232    0]
#  [   4    0 1008]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.98      0.99      1246
#          QSO       0.98      0.96      0.97       242
#         STAR       0.98      1.00      0.99      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.98      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# =======Choice 3=======
# ['LinearDiscriminantAnalysis', 'RbfKernelSVM', 'DecisionTreeClassifier', 'LogisticRegression', 'QuadraticDiscriminantAnalysis', 'KNN', 'LinearSVM', 'GaussianNB', 'NuSVC', 'MLPClassifier', 'PolyKernelSVM', 'SGDClassifier', 'PassiveAggressiveClassifier', 'GradientBoostingClassifier', 'XGBClassifier', 'BaggingClassifier', 'ExtraTreesClassifier', 'RandomForestClassifier', 'AdaBoostClassifier']
# [0.98734177 0.98734177 0.992      0.98999333 0.99066044]
# Accuracy: 0.989 (+/- 0.004)
# ('LinearDiscriminantAnalysis', LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#               solver='svd', store_covariance=False, tol=0.0001)) :
#  [[1230    5   11]
#  [  11  231    0]
#  [   0    0 1012]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.95      0.97       242
#         STAR       0.99      1.00      0.99      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# =======Choice 4=======
# ['XGBClassifier', 'SGDClassifier', 'PassiveAggressiveClassifier', 'AdaBoostClassifier', 'LogisticRegression', 'GaussianNB']
# [0.98800799 0.98800799 0.994      0.98799199 0.99132755]
# Accuracy: 0.990 (+/- 0.005)
# ('XGBClassifier', XGBClassifier(alpha=1.7782794100389228e-08, base_score=0.5, booster='gbtree',
#        colsample_bylevel=1, colsample_bytree=0.9, eta=0.01778279410038923,
#        gamma=0.01, learning_rate=0.1, max_delta_step=0.35938136638046275,
#        max_depth=4, min_child_weight=0.03831186849557289, missing=None,
#        n_estimators=4216, n_jobs=1, nthread=4, objective='multi:softprob',
#        random_state=0, reg_alpha=0, reg_lambda=5.994842503189409,
#        scale_pos_weight=1, seed=42, silent=True, subsample=1.0)) :
#  [[1233    5    8]
#  [  11  231    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.95      0.97       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# =======Choice 5=======
# ['DecisionTreeClassifier', 'RandomForestClassifier', 'GaussianNB', 'RidgeClassifier', 'NuSVC', 'MLPClassifier', 'SGDClassifier', 'LogisticRegression', 'GradientBoostingClassifier', 'QuadraticDiscriminantAnalysis', 'AdaBoostClassifier', 'LinearDiscriminantAnalysis', 'PolyKernelSVM', 'KNN']

# %%
best_indiv = VotingClassifier() # todo

clf_names = ["ExtraTreesClassifier"]
class_names = ["GALAXY", "QSO", "STAR"]

clfs = [best_indiv]
data_sets = []
std_scaled_set = DataSet("Standard Scaled", X_train, y_train, X_test, y_test)
data_sets.append(std_scaled_set)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    helpers.learning_loop_for_sets(clfs, clf_names, class_names, data_sets)
