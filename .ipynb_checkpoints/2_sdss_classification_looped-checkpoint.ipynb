# %% [markdown]
# # Data prep

# %% [markdown]
# ## Import packages

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals
import warnings
import helpers
from helpers import DataSet
import matplotlib as mpl
import os

# Common imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import operator
from collections import OrderedDict

# Imports for ML
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, BaggingClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier, PassiveAggressiveClassifier, RidgeClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import PolynomialFeatures, RobustScaler, Normalizer, MinMaxScaler, StandardScaler, QuantileTransformer, MaxAbsScaler
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, classification_report
from sklearn.pipeline import Pipeline 
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.naive_bayes import GaussianNB, MultinomialNB, ComplementNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
sns.set_style('whitegrid')

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "results"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)

# Helper functioins and structures
# Ignore useless warnings (see SciPy issue #5998)
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %% [markdown]
# ## Load data

# %%
DATA_PATH = "Skyserver_SQL2_27_2018 6_51_39 PM.csv"
RESULTS_FOLDER = "results"

# We load the data. Those that have nothing to do with the features of the objects are ignored.
sdss_data = pd.read_csv(DATA_PATH)

# We have a general look at the features
sdss_data.head(3)
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
#
#      mjd  fiberid
# 0  54922      491
# 1  51615      541
# 2  52023      513

# %% [markdown]
# ## Drop not important features

# %%
print(sdss_data.columns.values)
sdss_data.drop(['objid', 'run', 'rerun', 'camcol', 'field',
                'specobjid', 'fiberid', 'mjd', 'plate'], axis=1, inplace=True)
sdss_data.head(1)
# Out:
# ['objid' 'ra' 'dec' 'u' 'g' 'r' 'i' 'z' 'run' 'rerun' 'camcol' 'field'
#  'specobjid' 'class' 'redshift' 'plate' 'mjd' 'fiberid']
#            ra       dec         u        g         r         i         z  \
# 0  183.531326  0.089693  19.47406  17.0424  15.94699  15.50342  15.22531
#
#   class  redshift
# 0  STAR -0.000009

# %% [markdown]
# ## Split into train/test sets

# %%
X = sdss_data.drop(['class'], axis=1)
y = sdss_data['class']

class_names = ["GALAXY", "QSO", "STAR"]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ## Scale the data

# %%
robust_scaler = RobustScaler()
normalizer = Normalizer()
min_max_scaler = MinMaxScaler()
std_scaler = StandardScaler()
quantile_transformer = QuantileTransformer(output_distribution="normal")
maxabs_scaler = MaxAbsScaler()

X_train_minmax_scaled = min_max_scaler.fit_transform(X_train.astype(np.float64))
X_test_minmax_scaled = min_max_scaler.fit_transform(X_test.astype(np.float64))

X_train_normalized = normalizer.fit_transform(X_train.astype(np.float64))
X_test_normalized = normalizer.fit_transform(X_test.astype(np.float64))

X_train_std_scaled = std_scaler.fit_transform(X_train.astype(np.float64))
X_test_std_scaled = std_scaler.fit_transform(X_test.astype(np.float64))

X_train_rob_scaled = robust_scaler.fit_transform(X_train.astype(np.float64))
X_test_rob_scaled = robust_scaler.fit_transform(X_test.astype(np.float64))

X_train_maxabs_scaled = maxabs_scaler.fit_transform(X_train.astype(np.float64))
X_test_maxabs_scaled = maxabs_scaler.fit_transform(X_test.astype(np.float64))

X_train_q_scaled = quantile_transformer.fit_transform(X_train.astype(np.float64))
X_test_q_scaled = quantile_transformer.fit_transform(X_test.astype(np.float64))

data_sets = []

minmax_set = DataSet("MinMax Scaled", X_train_minmax_scaled, y_train, X_test_minmax_scaled, y_test)
normalized_set = DataSet("Normalized", X_train_normalized, y_train, X_test_normalized, y_test)
std_scaled_set = DataSet("Standard Scaled", X_train_std_scaled, y_train, X_test_std_scaled, y_test)
robust_scaled_set = DataSet("Robust Scaled", X_train_rob_scaled, y_train, X_test_rob_scaled, y_test)
quantile_set = DataSet("Quantile Transformed", X_train_q_scaled, y_train, X_test_q_scaled, y_test)
max_abs_set = DataSet("MaxABS Scaled", X_train_maxabs_scaled, y_train, X_test_maxabs_scaled, y_test)

data_sets.append(minmax_set)
data_sets.append(normalized_set)
data_sets.append(std_scaled_set)
data_sets.append(robust_scaled_set)
data_sets.append(quantile_set)
data_sets.append(max_abs_set)

# %% [markdown]
# # Classification

# %% [markdown]
# ## Prepare result sets

# %%
result_sets = []

# Classfiers
knn_clf = KNeighborsClassifier()
svm_clf = SVC(gamma="auto", random_state=42)
lsvm_clf = LinearSVC(C=10, loss="hinge", random_state=42)
nusvm_clf = NuSVC(nu=0.05, gamma=0.1)
rbf_svm_clf = SVC(kernel="rbf", gamma=0.1, C=1000)
poly_svm_clf = SVC(kernel="poly", gamma="scale", degree=3, coef0=100, C=5)
tree_clf = DecisionTreeClassifier(random_state=42)
rnd_clf = RandomForestClassifier(n_estimators=1000, random_state=42)
log_clf = LogisticRegression(
    solver="liblinear", random_state=42, multi_class='auto')
gb_clf = GradientBoostingClassifier(n_estimators=100, learning_rate = 0.05, 
                                    max_features=2, max_depth = 4, random_state = 42)
# Xgboost parameters
xgb_params = {'learning_rate': 0.05,
              'max_depth': 4,
              'subsample': 0.9,
              'colsample_bytree': 0.9,
              'objective': 'binary:logistic',
              'silent': 1,
              'n_estimators': 100,
              'gamma': 1,
              'min_child_weight': 4,
              # ENABLE GPU COMPUTING BY UNCOMMENTING BELOW
              # 'gpu_id': 0,
              # 'tree_method': 'gpu_hist'
              }
xgb_clf = XGBClassifier(**xgb_params, seed=42)
bag_df_clf = BaggingClassifier(
    DecisionTreeClassifier(
        splitter="random", max_leaf_nodes=16, random_state=42),
    n_estimators=500, max_samples=1.0, bootstrap=True, n_jobs=-1, random_state=42)
ada_clf = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=1), n_estimators=500,
    algorithm="SAMME.R", learning_rate=0.5, random_state=42)
sgd_clf = SGDClassifier(max_iter=500, tol=-np.infty, random_state=42)
mlp_clf = MLPClassifier(random_state=42, max_iter=2000)
xtree_clf = ExtraTreesClassifier(n_estimators=10, random_state=42)
pa_clf = PassiveAggressiveClassifier(max_iter=5000, random_state=0, tol=1e-3)
r_clf = RidgeClassifier()
nb_clf = GaussianNB()
mnb_clf = MultinomialNB()
lda_clf = LinearDiscriminantAnalysis()
qda_clf = QuadraticDiscriminantAnalysis()
v_clf = VotingClassifier(estimators=[
    ("SVC", svm_clf),
    ("NuSVC", nusvm_clf),
    ("RbfSVC", rbf_svm_clf),
    ("PolySVC", poly_svm_clf),
    ("Tree", tree_clf),
    ("RF", rnd_clf),
    ("XGB", xgb_clf),
    ("Bagging", bag_df_clf),
    ("MLP", mlp_clf),
    ("XTrees", xtree_clf),
    ("NaiveBayes", nb_clf),
    ("QDA", qda_clf),
], voting="hard", n_jobs=-1)

# CLF names
clf_names = ["KNN",
             "SVC",
             "LinearSVM",
             "NuSVC", 
             "RbfKernelSVM", 
             "PolyKernelSVM",
             "DecisionTreeClassifier",
             "RandomForestClassifier", 
             "LogisticRegression", 
             "GradientBoostingClassifier", 
             "XGBClassifier", 
             "BaggingClassifier",
             "AdaBoostClassifier",
             "SGDClassifier",
             "MLPClassifier", 
             "ExtraTreesClassifier",
             "PassiveAggressiveClassifier",
             "RidgeClassifier",
             "GaussianNB", 
             "MultinomialNB", 
             "LinearDiscriminantAnalysis",
             "QuadraticDiscriminantAnalysis",
             "VotingClassifier"]

clfs = [knn_clf,
        svm_clf,
        lsvm_clf,
        nusvm_clf,
        rbf_svm_clf, 
        poly_svm_clf,
        tree_clf, 
        rnd_clf, 
        log_clf, 
        gb_clf,
        xgb_clf, 
        bag_df_clf,
        ada_clf,
        sgd_clf,
        mlp_clf, 
        xtree_clf,
        pa_clf,
        r_clf,
        nb_clf,
        mnb_clf,
        lda_clf,
        qda_clf, 
        v_clf]

# %% [markdown]
# ## Run

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    helpers.learining_loop_for_sets(clfs, clf_names, class_names, data_sets)
# Out:
# ==========================================================
# ==========================================================
# Data Set Type:  MinMax Scaled
# KNN
# [0.87674883 0.84410393 0.87       0.84723149 0.85523682]
# Accuracy: 0.859 (+/- 0.025)
# KNN :
#  [[1041    2  203]
#  [  16  208   18]
#  [ 185    2  825]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.84      0.84      0.84      1246
#          QSO       0.98      0.86      0.92       242
#         STAR       0.79      0.82      0.80      1012
#
#    micro avg       0.83      0.83      0.83      2500
#    macro avg       0.87      0.84      0.85      2500
# weighted avg       0.83      0.83      0.83      2500
#
#
#
# SVC
# [0.80279813 0.78880746 0.80733333 0.79786524 0.80253502]
# Accuracy: 0.800 (+/- 0.013)
# SVC :
#  [[1077    0  169]
#  [  21  176   45]
#  [ 316    0  696]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.76      0.86      0.81      1246
#          QSO       1.00      0.73      0.84       242
#         STAR       0.76      0.69      0.72      1012
#
#    micro avg       0.78      0.78      0.78      2500
#    macro avg       0.84      0.76      0.79      2500
# weighted avg       0.79      0.78      0.78      2500
#
#
#
# LinearSVM
# [0.93537642 0.92938041 0.94133333 0.9412942  0.93395597]
# Accuracy: 0.936 (+/- 0.009)
# LinearSVM :
#  [[1086    1  159]
#  [  24  218    0]
#  [  28    0  984]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.95      0.87      0.91      1246
#          QSO       1.00      0.90      0.95       242
#         STAR       0.86      0.97      0.91      1012
#
#    micro avg       0.92      0.92      0.92      2500
#    macro avg       0.94      0.91      0.92      2500
# weighted avg       0.92      0.92      0.92      2500
#
#
#
# NuSVC
# [0.97401732 0.96535643 0.95666667 0.97398266 0.96731154]
# Accuracy: 0.967 (+/- 0.013)
# NuSVC :
#  [[1187    2   57]
#  [  13  229    0]
#  [  38    3  971]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.96      0.95      0.96      1246
#          QSO       0.98      0.95      0.96       242
#         STAR       0.94      0.96      0.95      1012
#
#    micro avg       0.95      0.95      0.95      2500
#    macro avg       0.96      0.95      0.96      2500
# weighted avg       0.95      0.95      0.95      2500
#
#
#
# RbfKernelSVM
# [0.9793471  0.97734843 0.984      0.98932622 0.9826551 ]
# Accuracy: 0.983 (+/- 0.008)
# RbfKernelSVM :
#  [[1196    3   47]
#  [   5  237    0]
#  [   3    1 1008]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.96      0.98      1246
#          QSO       0.98      0.98      0.98       242
#         STAR       0.96      1.00      0.98      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.98      0.98      0.98      2500
# weighted avg       0.98      0.98      0.98      2500
#
#
#
# PolyKernelSVM
# [0.98934044 0.98600933 0.99266667 0.99132755 0.98932622]
# Accuracy: 0.990 (+/- 0.005)
# PolyKernelSVM :
#  [[1227    5   14]
#  [   7  235    0]
#  [   0    2 1010]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.98      0.99      1246
#          QSO       0.97      0.97      0.97       242
#         STAR       0.99      1.00      0.99      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.98      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# DecisionTreeClassifier
# [0.98201199 0.98334444 0.98333333 0.98732488 0.98599066]
# Accuracy: 0.984 (+/- 0.004)
# DecisionTreeClassifier :
#  [[1220   19    7]
#  [  16  226    0]
#  [   4    0 1008]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.98      0.98      1246
#          QSO       0.92      0.93      0.93       242
#         STAR       0.99      1.00      0.99      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.97      0.97      0.97      2500
# weighted avg       0.98      0.98      0.98      2500
#
#
#
# RandomForestClassifier
# [0.98600933 0.9853431  0.99133333 0.98799199 0.98999333]
# Accuracy: 0.988 (+/- 0.005)
# RandomForestClassifier :
#  [[1232    4   10]
#  [  14  228    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.94      0.96       242
#         STAR       0.99      1.00      0.99      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# LogisticRegression
# [0.82411726 0.80213191 0.826      0.81254169 0.8305537 ]
# Accuracy: 0.819 (+/- 0.021)
# LogisticRegression :
#  [[1062    1  183]
#  [  15  191   36]
#  [ 270    0  742]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.79      0.85      0.82      1246
#          QSO       0.99      0.79      0.88       242
#         STAR       0.77      0.73      0.75      1012
#
#    micro avg       0.80      0.80      0.80      2500
#    macro avg       0.85      0.79      0.82      2500
# weighted avg       0.80      0.80      0.80      2500
#
#
#
# GradientBoostingClassifier
# [0.98667555 0.98467688 0.99133333 0.98865911 0.99132755]
# Accuracy: 0.989 (+/- 0.005)
# GradientBoostingClassifier :
#  [[1233    5    8]
#  [  12  230    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.95      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# XGBClassifier
# [0.98867422 0.98401066 0.99133333 0.98865911 0.99332889]
# Accuracy: 0.989 (+/- 0.006)
# XGBClassifier :
#  [[1230    8    8]
#  [  11  231    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.97      0.95      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.98      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# BaggingClassifier
# [0.98201199 0.9793471  0.986      0.98599066 0.98799199]
# Accuracy: 0.984 (+/- 0.006)
# BaggingClassifier :
#  [[1232    4   10]
#  [  13  229    0]
#  [   0    0 1012]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.95      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# AdaBoostClassifier
# [0.67954697 0.93404397 0.68066667 0.82054703 0.74116077]
# Accuracy: 0.771 (+/- 0.193)
# AdaBoostClassifier :
#  [[1223   16    7]
#  [ 125  117    0]
#  [ 151    0  861]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.82      0.98      0.89      1246
#          QSO       0.88      0.48      0.62       242
#         STAR       0.99      0.85      0.92      1012
#
#    micro avg       0.88      0.88      0.88      2500
#    macro avg       0.90      0.77      0.81      2500
# weighted avg       0.89      0.88      0.88      2500
#
#
#
# SGDClassifier
# [0.88007995 0.87741506 0.90333333 0.89326217 0.89392929]
# Accuracy: 0.890 (+/- 0.019)
# SGDClassifier :
#  [[1043    1  202]
#  [  24  217    1]
#  [  51    0  961]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.93      0.84      0.88      1246
#          QSO       1.00      0.90      0.94       242
#         STAR       0.83      0.95      0.88      1012
#
#    micro avg       0.89      0.89      0.89      2500
#    macro avg       0.92      0.89      0.90      2500
# weighted avg       0.90      0.89      0.89      2500
#
#
#
# MLPClassifier
# [0.98134577 0.97401732 0.986      0.98599066 0.9826551 ]
# Accuracy: 0.982 (+/- 0.009)
# MLPClassifier :
#  [[1200    3   43]
#  [  11  231    0]
#  [   2    1 1009]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.96      0.98      1246
#          QSO       0.98      0.95      0.97       242
#         STAR       0.96      1.00      0.98      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.98      0.97      0.97      2500
# weighted avg       0.98      0.98      0.98      2500
# ExtraTreesClassifier
# [0.98134577 0.97468354 0.984      0.98332221 0.98132088]
# Accuracy: 0.981 (+/- 0.007)
# ExtraTreesClassifier :
#  [[1214    4   28]
#  [  15  227    0]
#  [  11    1 1000]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.97      0.98      1246
#          QSO       0.98      0.94      0.96       242
#         STAR       0.97      0.99      0.98      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.98      0.97      0.97      2500
# weighted avg       0.98      0.98      0.98      2500
#
#
#
# PassiveAggressiveClassifier
# [0.92271819 0.93137908 0.94066667 0.78719146 0.94596398]
# Accuracy: 0.906 (+/- 0.119)
# PassiveAggressiveClassifier :
#  [[1091    3  152]
#  [  29  213    0]
#  [  81    0  931]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.91      0.88      0.89      1246
#          QSO       0.99      0.88      0.93       242
#         STAR       0.86      0.92      0.89      1012
#
#    micro avg       0.89      0.89      0.89      2500
#    macro avg       0.92      0.89      0.90      2500
# weighted avg       0.90      0.89      0.89      2500
#
#
#
# RidgeClassifier
# [0.87008661 0.86075949 0.88466667 0.86124083 0.8772515 ]
# Accuracy: 0.871 (+/- 0.018)
# RidgeClassifier :
#  [[1073    1  172]
#  [  25  188   29]
#  [ 199    0  813]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.83      0.86      0.84      1246
#          QSO       0.99      0.78      0.87       242
#         STAR       0.80      0.80      0.80      1012
#
#    micro avg       0.83      0.83      0.83      2500
#    macro avg       0.87      0.81      0.84      2500
# weighted avg       0.83      0.83      0.83      2500
#
#
#
# GaussianNB
# [0.98134577 0.9733511  0.98066667 0.97464977 0.98465644]
# Accuracy: 0.979 (+/- 0.009)
# GaussianNB :
#  [[1218   21    7]
#  [  11  231    0]
#  [   3    7 1002]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.98      0.98      1246
#          QSO       0.89      0.95      0.92       242
#         STAR       0.99      0.99      0.99      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.96      0.97      0.97      2500
# weighted avg       0.98      0.98      0.98      2500
#
#
#
# MultinomialNB
# [0.49966689 0.50099933 0.5        0.50033356 0.50033356]
# Accuracy: 0.500 (+/- 0.001)
# MultinomialNB :
#  [[1246    0    0]
#  [ 241    1    0]
#  [1012    0    0]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.50      1.00      0.67      1246
#          QSO       1.00      0.00      0.01       242
#         STAR       0.00      0.00      0.00      1012
#
#    micro avg       0.50      0.50      0.50      2500
#    macro avg       0.50      0.33      0.22      2500
# weighted avg       0.35      0.50      0.33      2500
#
#
#
# LinearDiscriminantAnalysis
# [0.93537642 0.91672219 0.946      0.9299533  0.92328219]
# Accuracy: 0.930 (+/- 0.020)
# LinearDiscriminantAnalysis :
#  [[1131    0  115]
#  [  45  185   12]
#  [  74    2  936]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.90      0.91      0.91      1246
#          QSO       0.99      0.76      0.86       242
#         STAR       0.88      0.92      0.90      1012
#
#    micro avg       0.90      0.90      0.90      2500
#    macro avg       0.92      0.87      0.89      2500
# weighted avg       0.90      0.90      0.90      2500
#
#
#
# QuadraticDiscriminantAnalysis
# [0.9793471  0.98134577 0.98666667 0.98865911 0.98732488]
# Accuracy: 0.985 (+/- 0.007)
# QuadraticDiscriminantAnalysis :
#  [[1225   15    6]
#  [   5  237    0]
#  [   9    2 1001]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.98      0.99      1246
#          QSO       0.93      0.98      0.96       242
#         STAR       0.99      0.99      0.99      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.97      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# VotingClassifier
# [0.9853431  0.98201199 0.99133333 0.98999333 0.98932622]
# Accuracy: 0.988 (+/- 0.007)
# VotingClassifier :
#  [[1230    4   12]
#  [  11  231    0]
#  [   0    0 1012]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.95      0.97       242
#         STAR       0.99      1.00      0.99      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# By Acc:
# PolyKernelSVM 0.9897340405336477
# XGBClassifier 0.9892012404153661
# GradientBoostingClassifier 0.9885344845634746
# RandomForestClassifier 0.9881342177189115
# VotingClassifier 0.9876015952599684
# QuadraticDiscriminantAnalysis 0.9846687054823876
# DecisionTreeClassifier 0.9844010612152865
# BaggingClassifier 0.9842683498081554
# RbfKernelSVM 0.9825353714379428
# MLPClassifier 0.9820017710230093
# ExtraTreesClassifier 0.9809344818375475
# GaussianNB 0.9789339479113842
# NuSVC 0.9674669227260397
# LinearSVM 0.9362680657783997
# LinearDiscriminantAnalysis 0.9302668182519191
# PassiveAggressiveClassifier 0.9055838744224627
# SGDClassifier 0.8896039595276857
# RidgeClassifier 0.8708010194967495
# KNN 0.858664215406318
# LogisticRegression 0.8190689128306279
# SVC 0.7998678392894101
# AdaBoostClassifier 0.7711930822487773
# MultinomialNB 0.5002666667851852
#
#
# By Precision(avg=micro):
# GradientBoostingClassifier 0.9896
# BaggingClassifier 0.9892
# VotingClassifier 0.9892
# PolyKernelSVM 0.9888
# XGBClassifier 0.9888
# RandomForestClassifier 0.9884
# QuadraticDiscriminantAnalysis 0.9852
# DecisionTreeClassifier 0.9816
# GaussianNB 0.9804
# RbfKernelSVM 0.9764
# ExtraTreesClassifier 0.9764
# MLPClassifier 0.976
# NuSVC 0.9548
# LinearSVM 0.9152
# LinearDiscriminantAnalysis 0.9008
# PassiveAggressiveClassifier 0.894
# SGDClassifier 0.8884
# AdaBoostClassifier 0.8804
# KNN 0.8296
# RidgeClassifier 0.8296
# LogisticRegression 0.798
# SVC 0.7796
# MultinomialNB 0.4988
#
#
# By Recall(avg=micro):
# GradientBoostingClassifier 0.9896
# BaggingClassifier 0.9892
# VotingClassifier 0.9892
# PolyKernelSVM 0.9888
# XGBClassifier 0.9888
# RandomForestClassifier 0.9884
# QuadraticDiscriminantAnalysis 0.9852
# DecisionTreeClassifier 0.9816
# GaussianNB 0.9804
# RbfKernelSVM 0.9764
# ExtraTreesClassifier 0.9764
# MLPClassifier 0.976
# NuSVC 0.9548
# LinearSVM 0.9152
# LinearDiscriminantAnalysis 0.9008
# PassiveAggressiveClassifier 0.894
# SGDClassifier 0.8884
# AdaBoostClassifier 0.8804
# KNN 0.8296
# RidgeClassifier 0.8296
# LogisticRegression 0.798
# SVC 0.7796
# MultinomialNB 0.4988
#
#
# By F1(avg=micro):
# GradientBoostingClassifier 0.9896
# BaggingClassifier 0.9892
# VotingClassifier 0.9892
# PolyKernelSVM 0.9888
# XGBClassifier 0.9888
# RandomForestClassifier 0.9884
# QuadraticDiscriminantAnalysis 0.9852
# DecisionTreeClassifier 0.9816
# GaussianNB 0.9804
# RbfKernelSVM 0.9764
# ExtraTreesClassifier 0.9764
# MLPClassifier 0.976
# NuSVC 0.9548
# LinearSVM 0.9152
# LinearDiscriminantAnalysis 0.9008
# PassiveAggressiveClassifier 0.894
# SGDClassifier 0.8884
# AdaBoostClassifier 0.8804
# KNN 0.8296
# RidgeClassifier 0.8296
# LogisticRegression 0.798
# SVC 0.7796
# MultinomialNB 0.4988
#
#
# By Precision(avg=macro):
# BaggingClassifier 0.987535371715115
# VotingClassifier 0.9874653846346174
# RandomForestClassifier 0.9869784773695196
# GradientBoostingClassifier 0.9868130610887698
# PolyKernelSVM 0.9839099652549884
# XGBClassifier 0.9830048422509329
# RbfKernelSVM 0.9774027361069851
# MLPClassifier 0.9771289895603941
# ExtraTreesClassifier 0.9767477266136607
# QuadraticDiscriminantAnalysis 0.9719377130523926
# DecisionTreeClassifier 0.9664744652032115
# NuSVC 0.9606631770800789
# GaussianNB 0.9578635645285795
# LinearSVM 0.9368773260180959
# LinearDiscriminantAnalysis 0.9248772079155788
# PassiveAggressiveClassifier 0.9180566308453159
# SGDClassifier 0.917976713298386
# AdaBoostClassifier 0.8958373278307564
# RidgeClassifier 0.8745926324856005
# KNN 0.8693384186445766
# LogisticRegression 0.8517742526138815
# SVC 0.8421680629601421
# MultinomialNB 0.4995331465919701
#
#
# By Recall(avg=macro):
# PolyKernelSVM 0.9846164331442121
# QuadraticDiscriminantAnalysis 0.9838717817245151
# VotingClassifier 0.9805681210175593
# XGBClassifier 0.9802387402533959
# GradientBoostingClassifier 0.9796638980033748
# RbfKernelSVM 0.9784192876301061
# BaggingClassifier 0.9783483455597858
# RandomForestClassifier 0.9766415543273029
# GaussianNB 0.9740640405027312
# MLPClassifier 0.9715542965420836
# DecisionTreeClassifier 0.9696883182249794
# ExtraTreesClassifier 0.9668255461433949
# NuSVC 0.9528052109546091
# LinearSVM 0.9149158490544999
# SGDClassifier 0.8944592032148101
# PassiveAggressiveClassifier 0.8919092299094076
# LinearDiscriminantAnalysis 0.8656895501945908
# KNN 0.8367316795948496
# RidgeClassifier 0.8137916287203493
# LogisticRegression 0.791595075735947
# AdaBoostClassifier 0.7719341730644302
# SVC 0.7597952446511314
# MultinomialNB 0.33471074380165294
#
#
# By F1(avg=macro):
# PolyKernelSVM 0.9842439876761961
# VotingClassifier 0.9839343653114244
# GradientBoostingClassifier 0.9831652951802923
# BaggingClassifier 0.9828183616654865
# RandomForestClassifier 0.9816606740623275
# XGBClassifier 0.9816045421943392
# QuadraticDiscriminantAnalysis 0.9777135481140583
# RbfKernelSVM 0.9776731834905982
# MLPClassifier 0.9740910480413717
# ExtraTreesClassifier 0.9716224707955017
# DecisionTreeClassifier 0.9680670191803545
# GaussianNB 0.9655982862309832
# NuSVC 0.9566207481382246
# LinearSVM 0.9233563161946393
# PassiveAggressiveClassifier 0.903539316032998
# SGDClassifier 0.9030510089896328
# LinearDiscriminantAnalysis 0.8902965123898858
# KNN 0.8516218502885421
# RidgeClassifier 0.8396138666448566
# LogisticRegression 0.8171556115182556
# AdaBoostClassifier 0.8103440426823755
# SVC 0.7920417589238445
# MultinomialNB 0.2245503378075202
#
#
# KNN
# {'GALAXY': 0.8375932169545416, 'QSO': 0.9288663265231427, 'STAR': 0.8333479429640018}
#
#
# SVC
# {'GALAXY': 0.7978129696048086, 'QSO': 0.8636363636363636, 'STAR': 0.7719649156360237}
#
#
# LinearSVM
# {'GALAXY': 0.915060890223516, 'QSO': 0.9501917882423558, 'STAR': 0.9327385885502998}
#
#
# NuSVC
# {'GALAXY': 0.9559893093305275, 'QSO': 0.9720333213770688, 'STAR': 0.9605898571975009}
#
#
# RbfKernelSVM
# {'GALAXY': 0.9767460018790592, 'QSO': 0.9887836818950435, 'STAR': 0.9822307046623315}
#
#
# PolyKernelSVM
# {'GALAXY': 0.9895845333456214, 'QSO': 0.983987145795665, 'STAR': 0.994307556632241}
#
#
# DecisionTreeClassifier
# {'GALAXY': 0.9815921315034266, 'QSO': 0.9627348856956716, 'STAR': 0.9956715648773853}
#
#
# RandomForestClassifier
# {'GALAXY': 0.9884011612278909, 'QSO': 0.9701886405727295, 'STAR': 0.9961457137999914}
#
#
# LogisticRegression
# {'GALAXY': 0.8125273602801693, 'QSO': 0.8944066642754138, 'STAR': 0.7930120808364146}
#
#
# GradientBoostingClassifier
# {'GALAXY': 0.9895998935029096, 'QSO': 0.9740994370795483, 'STAR': 0.9968177568107441}
#
#
# XGBClassifier
# {'GALAXY': 0.9887947652583963, 'QSO': 0.9755012480876077, 'STAR': 0.9968177568107441}
#
#
# BaggingClassifier
# {'GALAXY': 0.9891986093937603, 'QSO': 0.9722547562752087, 'STAR': 0.9966397849462366}
#
#
# AdaBoostClassifier
# {'GALAXY': 0.8807226185996143, 'QSO': 0.7381925788198435, 'STAR': 0.9230431063793617}
#
#
# SGDClassifier
# {'GALAXY': 0.8886350196226008, 'QSO': 0.9481256725398766, 'STAR': 0.9065900059501041}
#
#
# MLPClassifier
# {'GALAXY': 0.9763575179009834, 'QSO': 0.9763869876801675, 'STAR': 0.984068861830082}
#
#
# ExtraTreesClassifier
# {'GALAXY': 0.9767920823509232, 'QSO': 0.9679010899721101, 'STAR': 0.9846625440945217}
#
#
# PassiveAggressiveClassifier
# {'GALAXY': 0.8939413139590549, 'QSO': 0.9394183399336794, 'STAR': 0.9089049683369458}
#
#
# RidgeClassifier
# {'GALAXY': 0.8412636545398225, 'QSO': 0.8882083171679758, 'STAR': 0.834139519316588}
#
#
# GaussianNB
# {'GALAXY': 0.9831819077827357, 'QSO': 0.9710725501248088, 'STAR': 0.9927071379999148}
#
#
# MultinomialNB
# {'GALAXY': 0.5003987240829346, 'QSO': 0.5020661157024794, 'STAR': 0.5}
#
#
# LinearDiscriminantAnalysis
# {'GALAXY': 0.9064041615786145, 'QSO': 0.8817885351623979, 'STAR': 0.9197758617025799}
#
#
# QuadraticDiscriminantAnalysis
# {'GALAXY': 0.9859908965467806, 'QSO': 0.9859050282192242, 'STAR': 0.9925490883590463}
#
#
# VotingClassifier
# {'GALAXY': 0.9891934893413309, 'QSO': 0.9763869876801675, 'STAR': 0.9959677419354839}
#
#
# ==========================================================
# ==========================================================
# Data Set Type:  Normalized
# KNN
# [0.80746169 0.80279813 0.80733333 0.79252835 0.81987992]
# Accuracy: 0.806 (+/- 0.018)
# KNN :
#  [[992   5 249]
#  [ 29 180  33]
#  [270  16 726]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.77      0.80      0.78      1246
#          QSO       0.90      0.74      0.81       242
#         STAR       0.72      0.72      0.72      1012
#
#    micro avg       0.76      0.76      0.76      2500
#    macro avg       0.79      0.75      0.77      2500
# weighted avg       0.76      0.76      0.76      2500
#
#
#
# SVC
# [0.50233178 0.50099933 0.506      0.50366911 0.50166778]
# Accuracy: 0.503 (+/- 0.004)
# SVC :
#  [[1244    0    2]
#  [ 242    0    0]
#  [1010    0    2]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.50      1.00      0.66      1246
#          QSO       0.00      0.00      0.00       242
#         STAR       0.50      0.00      0.00      1012
#
#    micro avg       0.50      0.50      0.50      2500
#    macro avg       0.33      0.33      0.22      2500
# weighted avg       0.45      0.50      0.33      2500
#
#
#
# LinearSVM
# [0.55696203 0.55762825 0.56066667 0.56370914 0.56504336]
# Accuracy: 0.561 (+/- 0.006)
# LinearSVM :
#  [[1209    0   37]
#  [ 190   38   14]
#  [ 936    0   76]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.52      0.97      0.68      1246
#          QSO       1.00      0.16      0.27       242
#         STAR       0.60      0.08      0.13      1012
#
#    micro avg       0.53      0.53      0.53      2500
#    macro avg       0.71      0.40      0.36      2500
# weighted avg       0.60      0.53      0.42      2500
#
#
#
# NuSVC
# [0.63824117 0.52898068 0.51733333 0.51300867 0.53835891]
# Accuracy: 0.547 (+/- 0.093)
# NuSVC :
#  [[785 305 156]
#  [104 104  34]
#  [610 253 149]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.52      0.63      0.57      1246
#          QSO       0.16      0.43      0.23       242
#         STAR       0.44      0.15      0.22      1012
#
#    micro avg       0.42      0.42      0.42      2500
#    macro avg       0.37      0.40      0.34      2500
# weighted avg       0.45      0.42      0.40      2500
#
#
#
# RbfKernelSVM
# [0.83277815 0.83810793 0.84666667 0.84389593 0.82721815]
# Accuracy: 0.838 (+/- 0.014)
# RbfKernelSVM :
#  [[1009    0  237]
#  [   8  158   76]
#  [ 264    1  747]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.79      0.81      0.80      1246
#          QSO       0.99      0.65      0.79       242
#         STAR       0.70      0.74      0.72      1012
#
#    micro avg       0.77      0.77      0.77      2500
#    macro avg       0.83      0.73      0.77      2500
# weighted avg       0.77      0.77      0.77      2500
#
#
#
# PolyKernelSVM
# [0.95736176 0.95602931 0.97266667 0.9646431  0.95797198]
# Accuracy: 0.962 (+/- 0.012)
# PolyKernelSVM :
#  [[1142    3  101]
#  [   7  235    0]
#  [  26    3  983]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.97      0.92      0.94      1246
#          QSO       0.98      0.97      0.97       242
#         STAR       0.91      0.97      0.94      1012
#
#    micro avg       0.94      0.94      0.94      2500
#    macro avg       0.95      0.95      0.95      2500
# weighted avg       0.95      0.94      0.94      2500
#
#
#
# DecisionTreeClassifier
# [0.97601599 0.97868088 0.984      0.98332221 0.9826551 ]
# Accuracy: 0.981 (+/- 0.006)
# DecisionTreeClassifier :
#  [[1220   18    8]
#  [  20  222    0]
#  [   6    0 1006]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.98      0.98      1246
#          QSO       0.93      0.92      0.92       242
#         STAR       0.99      0.99      0.99      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.97      0.96      0.96      2500
# weighted avg       0.98      0.98      0.98      2500
#
#
#
# RandomForestClassifier
# [0.98467688 0.98334444 0.99       0.98799199 0.99066044]
# Accuracy: 0.987 (+/- 0.006)
# RandomForestClassifier :
#  [[1235    3    8]
#  [  21  221    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.99      0.99      1246
#          QSO       0.99      0.91      0.95       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.97      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# LogisticRegression
# [0.50832778 0.50566289 0.516      0.50767178 0.50967312]
# Accuracy: 0.509 (+/- 0.007)
# LogisticRegression :
#  [[1204    0   42]
#  [ 237    0    5]
#  [ 948    0   64]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.50      0.97      0.66      1246
#          QSO       0.00      0.00      0.00       242
#         STAR       0.58      0.06      0.11      1012
#
#    micro avg       0.51      0.51      0.51      2500
#    macro avg       0.36      0.34      0.26      2500
# weighted avg       0.48      0.51      0.38      2500
#
#
#
# GradientBoostingClassifier
# [0.98467688 0.98334444 0.98933333 0.98732488 0.99199466]
# Accuracy: 0.987 (+/- 0.006)
# GradientBoostingClassifier :
#  [[1234    4    8]
#  [  19  223    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.99      0.99      1246
#          QSO       0.98      0.92      0.95       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.97      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# XGBClassifier
# [0.98800799 0.98600933 0.99333333 0.98732488 0.99466311]
# Accuracy: 0.990 (+/- 0.007)
# XGBClassifier :
#  [[1231    7    8]
#  [  16  226    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.97      0.93      0.95       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.98      0.97      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# BaggingClassifier
# [0.9853431  0.98401066 0.98733333 0.98732488 0.98732488]
# Accuracy: 0.986 (+/- 0.003)
# BaggingClassifier :
#  [[1235    3    8]
#  [  18  224    0]
#  [   0    0 1012]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.99      0.93      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.97      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# AdaBoostClassifier
# [0.91605596 0.91672219 0.91466667 0.91661107 0.8478986 ]
# Accuracy: 0.902 (+/- 0.055)
# AdaBoostClassifier :
#  [[1228   10    8]
#  [ 191   51    0]
#  [  26    0  986]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.85      0.99      0.91      1246
#          QSO       0.84      0.21      0.34       242
#         STAR       0.99      0.97      0.98      1012
#
#    micro avg       0.91      0.91      0.91      2500
#    macro avg       0.89      0.72      0.74      2500
# weighted avg       0.91      0.91      0.89      2500
#
#
#
# SGDClassifier
# [0.51099267 0.50632911 0.516      0.50700467 0.51100734]
# Accuracy: 0.510 (+/- 0.007)
# SGDClassifier :
#  [[1191    0   55]
#  [ 194    1   47]
#  [ 861    0  151]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.53      0.96      0.68      1246
#          QSO       1.00      0.00      0.01       242
#         STAR       0.60      0.15      0.24      1012
#
#    micro avg       0.54      0.54      0.54      2500
#    macro avg       0.71      0.37      0.31      2500
# weighted avg       0.60      0.54      0.44      2500
# MLPClassifier
# [0.96335776 0.96402398 0.976      0.92194797 0.84589726]
# Accuracy: 0.934 (+/- 0.096)
# MLPClassifier :
#  [[1134    0  112]
#  [ 148   88    6]
#  [ 588    0  424]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.61      0.91      0.73      1246
#          QSO       1.00      0.36      0.53       242
#         STAR       0.78      0.42      0.55      1012
#
#    micro avg       0.66      0.66      0.66      2500
#    macro avg       0.80      0.56      0.60      2500
# weighted avg       0.72      0.66      0.64      2500
#
#
#
# ExtraTreesClassifier
# [0.96135909 0.96402398 0.97333333 0.97464977 0.97731821]
# Accuracy: 0.970 (+/- 0.013)
# ExtraTreesClassifier :
#  [[1209    6   31]
#  [  22  219    1]
#  [  32    0  980]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.96      0.97      0.96      1246
#          QSO       0.97      0.90      0.94       242
#         STAR       0.97      0.97      0.97      1012
#
#    micro avg       0.96      0.96      0.96      2500
#    macro avg       0.97      0.95      0.96      2500
# weighted avg       0.96      0.96      0.96      2500
#
#
#
# PassiveAggressiveClassifier
# [0.56828781 0.74417055 0.60066667 0.7191461  0.70313542]
# Accuracy: 0.667 (+/- 0.139)
# PassiveAggressiveClassifier :
#  [[523   1 722]
#  [ 95   7 140]
#  [396   3 613]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.52      0.42      0.46      1246
#          QSO       0.64      0.03      0.06       242
#         STAR       0.42      0.61      0.49      1012
#
#    micro avg       0.46      0.46      0.46      2500
#    macro avg       0.52      0.35      0.34      2500
# weighted avg       0.49      0.46      0.44      2500
#
#
#
# RidgeClassifier
# [0.54230513 0.53830779 0.552      0.53502335 0.54503002]
# Accuracy: 0.543 (+/- 0.012)
# RidgeClassifier :
#  [[1204    0   42]
#  [ 223    0   19]
#  [ 936    0   76]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.51      0.97      0.67      1246
#          QSO       0.00      0.00      0.00       242
#         STAR       0.55      0.08      0.13      1012
#
#    micro avg       0.51      0.51      0.51      2500
#    macro avg       0.35      0.35      0.27      2500
# weighted avg       0.48      0.51      0.39      2500
#
#
#
# GaussianNB
# [0.97068621 0.95403065 0.96933333 0.96531021 0.96731154]
# Accuracy: 0.965 (+/- 0.012)
# GaussianNB :
#  [[1232    7    7]
#  [  16  226    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.97      0.93      0.95       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.98      0.97      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# Something bad had happened... Could not proceed for the:  MultinomialNB
#
# LinearDiscriminantAnalysis
# [0.92804797 0.91672219 0.94733333 0.93195464 0.9239493 ]
# Accuracy: 0.930 (+/- 0.020)
# LinearDiscriminantAnalysis :
#  [[1143    0  103]
#  [  44  184   14]
#  [  83    1  928]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.90      0.92      0.91      1246
#          QSO       0.99      0.76      0.86       242
#         STAR       0.89      0.92      0.90      1012
#
#    micro avg       0.90      0.90      0.90      2500
#    macro avg       0.93      0.86      0.89      2500
# weighted avg       0.90      0.90      0.90      2500
#
#
#
# QuadraticDiscriminantAnalysis
# [0.97734843 0.97801466 0.984      0.98665777 0.98599066]
# Accuracy: 0.982 (+/- 0.008)
# QuadraticDiscriminantAnalysis :
#  [[1228   12    6]
#  [   7  235    0]
#  [  11    2  999]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.94      0.97      0.96       242
#         STAR       0.99      0.99      0.99      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.97      0.98      0.98      2500
# weighted avg       0.98      0.98      0.98      2500
#
#
#
# VotingClassifier
# [0.98467688 0.98334444 0.99133333 0.98599066 0.98799199]
# Accuracy: 0.987 (+/- 0.006)
# VotingClassifier :
#  [[1237    2    7]
#  [  19  223    0]
#  [   2    0 1010]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.99      0.99      1246
#          QSO       0.99      0.92      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.97      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# By Acc:
# XGBClassifier 0.9898677294226944
# GradientBoostingClassifier 0.9873348397636326
# RandomForestClassifier 0.9873347508154449
# VotingClassifier 0.9866674615114643
# BaggingClassifier 0.9862673728003137
# QuadraticDiscriminantAnalysis 0.9824023047121354
# DecisionTreeClassifier 0.9809348373932611
# ExtraTreesClassifier 0.9701368779867607
# GaussianNB 0.965334387318987
# PolyKernelSVM 0.9617345632005465
# MLPClassifier 0.9342453951312868
# LinearDiscriminantAnalysis 0.9296014845043634
# AdaBoostClassifier 0.9023908975366952
# RbfKernelSVM 0.8377333637333468
# KNN 0.8060002864593866
# PassiveAggressiveClassifier 0.6670813097546562
# LinearSVM 0.5608018882971355
# NuSVC 0.547184552763505
# RidgeClassifier 0.5425332587258928
# SGDClassifier 0.5102667586963372
# LogisticRegression 0.5094671138964951
# SVC 0.5029336007704892
#
#
# By Precision(avg=micro):
# BaggingClassifier 0.9884
# VotingClassifier 0.988
# GaussianNB 0.9876
# GradientBoostingClassifier 0.9872
# XGBClassifier 0.9872
# RandomForestClassifier 0.9868
# QuadraticDiscriminantAnalysis 0.9848
# DecisionTreeClassifier 0.9792
# ExtraTreesClassifier 0.9632
# PolyKernelSVM 0.944
# AdaBoostClassifier 0.906
# LinearDiscriminantAnalysis 0.902
# RbfKernelSVM 0.7656
# KNN 0.7592
# MLPClassifier 0.6584
# SGDClassifier 0.5372
# LinearSVM 0.5292
# RidgeClassifier 0.512
# LogisticRegression 0.5072
# SVC 0.4984
# PassiveAggressiveClassifier 0.4572
# NuSVC 0.4152
#
#
# By Recall(avg=micro):
# BaggingClassifier 0.9884
# VotingClassifier 0.988
# GaussianNB 0.9876
# GradientBoostingClassifier 0.9872
# XGBClassifier 0.9872
# RandomForestClassifier 0.9868
# QuadraticDiscriminantAnalysis 0.9848
# DecisionTreeClassifier 0.9792
# ExtraTreesClassifier 0.9632
# PolyKernelSVM 0.944
# AdaBoostClassifier 0.906
# LinearDiscriminantAnalysis 0.902
# RbfKernelSVM 0.7656
# KNN 0.7592
# MLPClassifier 0.6584
# SGDClassifier 0.5372
# LinearSVM 0.5292
# RidgeClassifier 0.512
# LogisticRegression 0.5072
# SVC 0.4984
# PassiveAggressiveClassifier 0.4572
# NuSVC 0.4152
#
#
# By F1(avg=micro):
# BaggingClassifier 0.9884
# VotingClassifier 0.988
# GaussianNB 0.9876
# GradientBoostingClassifier 0.9872
# XGBClassifier 0.9872
# RandomForestClassifier 0.9868
# QuadraticDiscriminantAnalysis 0.9848
# DecisionTreeClassifier 0.9792
# ExtraTreesClassifier 0.9632
# PolyKernelSVM 0.944
# AdaBoostClassifier 0.906
# LinearDiscriminantAnalysis 0.902
# RbfKernelSVM 0.7656
# KNN 0.7592
# MLPClassifier 0.6584
# SGDClassifier 0.5372
# LinearSVM 0.5292
# RidgeClassifier 0.512
# LogisticRegression 0.5072
# SVC 0.4984
# PassiveAggressiveClassifier 0.4572
# NuSVC 0.41520000000000007
#
#
# By Precision(avg=macro):
# VotingClassifier 0.9891783193917499
# BaggingClassifier 0.9881918269896167
# RandomForestClassifier 0.9870847732812145
# GradientBoostingClassifier 0.9861930190523459
# GaussianNB 0.9831566549787523
# XGBClassifier 0.9828281508407137
# QuadraticDiscriminantAnalysis 0.9744529077395003
# ExtraTreesClassifier 0.966319145185199
# DecisionTreeClassifier 0.9654145599910509
# PolyKernelSVM 0.9512817321075127
# LinearDiscriminantAnalysis 0.9275442907021855
# AdaBoostClassifier 0.8926147578838127
# RbfKernelSVM 0.8286978529941722
# MLPClassifier 0.7962349783925647
# KNN 0.7947190250290358
# SGDClassifier 0.7090379969895243
# LinearSVM 0.705399405374114
# PassiveAggressiveClassifier 0.5225786498015963
# NuSVC 0.3734367254846655
# LogisticRegression 0.3601843786021266
# RidgeClassifier 0.3547554399588959
# SVC 0.3327991452991453
#
#
# By Recall(avg=macro):
# QuadraticDiscriminantAnalysis 0.9812607674778479
# GaussianNB 0.9738867333906637
# XGBClassifier 0.9736192106512309
# BaggingClassifier 0.9722638614364866
# VotingClassifier 0.970762734918706
# GradientBoostingClassifier 0.9702895474645707
# RandomForestClassifier 0.9678022492673645
# DecisionTreeClassifier 0.9635199148233745
# PolyKernelSVM 0.9529837196600086
# ExtraTreesClassifier 0.9478810334164066
# LinearDiscriminantAnalysis 0.8648873664861586
# KNN 0.7524468765975184
# RbfKernelSVM 0.7336087289122774
# AdaBoostClassifier 0.7235352913729253
# MLPClassifier 0.5642403517342452
# NuSVC 0.4023337730203653
# LinearSVM 0.40080952784687746
# SGDClassifier 0.36973348852151533
# PassiveAggressiveClassifier 0.35146667443376595
# RidgeClassifier 0.3471303163535699
# LogisticRegression 0.34317774718360944
# SVC 0.3334570493827944
#
#
# By F1(avg=macro):
# BaggingClassifier 0.9798940769554187
# VotingClassifier 0.9795385355470511
# GaussianNB 0.9784044036565049
# XGBClassifier 0.9781056129465701
# GradientBoostingClassifier 0.9779093912165276
# QuadraticDiscriminantAnalysis 0.9777879946822775
# RandomForestClassifier 0.976960786822899
# DecisionTreeClassifier 0.9644616280773392
# ExtraTreesClassifier 0.956670505172613
# PolyKernelSVM 0.9514912662217648
# LinearDiscriminantAnalysis 0.8908988781435525
# KNN 0.7711596598959615
# RbfKernelSVM 0.769215927354169
# AdaBoostClassifier 0.7441187933391907
# MLPClassifier 0.6022927016508531
# LinearSVM 0.3600364496955593
# NuSVC 0.34087161462158555
# PassiveAggressiveClassifier 0.3370437455057084
# SGDClassifier 0.3096987382443165
# RidgeClassifier 0.2665032612357512
# LogisticRegression 0.25880960925796864
# SVC 0.22294069868738345
#
#
# KNN
# {'GALAXY': 0.7788553354786352, 'QSO': 0.867250693585342, 'STAR': 0.7639375876577841}
#
#
# SVC
# {'GALAXY': 0.4999948799475707, 'QSO': 0.5, 'STAR': 0.5003160992817375}
#
#
# LinearSVM
# {'GALAXY': 0.5361891705771068, 'QSO': 0.5785123966942148, 'STAR': 0.5204123103404309}
#
#
# NuSVC
# {'GALAXY': 0.530319030466872, 'QSO': 0.5913153598957609, 'STAR': 0.5097725147690084}
#
#
# RbfKernelSVM
# {'GALAXY': 0.7964427155734076, 'QSO': 0.8262248460935956, 'STAR': 0.7638964150622636}
#
#
# PolyKernelSVM
# {'GALAXY': 0.9451085579116331, 'QSO': 0.9842085806938049, 'STAR': 0.9517337647158826}
#
#
# DecisionTreeClassifier
# {'GALAXY': 0.9791997870058189, 'QSO': 0.9546918577838942, 'STAR': 0.9943474010795189}
#
#
# RandomForestClassifier
# {'GALAXY': 0.9868139449747966, 'QSO': 0.955947265553514, 'STAR': 0.9968177568107441}
#
#
# LogisticRegression
# {'GALAXY': 0.5106580291382184, 'QSO': 0.5, 'STAR': 0.5158275426069956}
#
#
# GradientBoostingClassifier
# {'GALAXY': 0.9872101090315164, 'QSO': 0.9598580620603329, 'STAR': 0.9968177568107441}
#
#
# XGBClassifier
# {'GALAXY': 0.9872024289528725, 'QSO': 0.965392104473351, 'STAR': 0.9968177568107441}
#
#
# BaggingClassifier
# {'GALAXY': 0.9884088413065351, 'QSO': 0.9621456126609521, 'STAR': 0.9973118279569892}
#
#
# AdaBoostClassifier
# {'GALAXY': 0.9062537600385028, 'QSO': 0.6031575518450468, 'STAR': 0.9844659781546177}
#
#
# SGDClassifier
# {'GALAXY': 0.557275466500777, 'QSO': 0.5020661157024794, 'STAR': 0.5403305495346168}
#
#
# MLPClassifier
# {'GALAXY': 0.6615952547354085, 'QSO': 0.6818181818181819, 'STAR': 0.6698356283734965}
#
#
# ExtraTreesClassifier
# {'GALAXY': 0.9636213874830079, 'QSO': 0.9511507294541355, 'STAR': 0.9734370351481151}
#
#
# PassiveAggressiveClassifier
# {'GALAXY': 0.514098064364179, 'QSO': 0.5135770703247956, 'STAR': 0.5132150750138127}
#
#
# RidgeClassifier
# {'GALAXY': 0.5210248552945183, 'QSO': 0.5, 'STAR': 0.5170520952866675}
#
#
# GaussianNB
# {'GALAXY': 0.9876037130620217, 'QSO': 0.965392104473351, 'STAR': 0.9971537783161205}
#
#
# LinearDiscriminantAnalysis
# {'GALAXY': 0.908029778224929, 'QSO': 0.8799438543580584, 'STAR': 0.9191835075863828}
#
#
# QuadraticDiscriminantAnalysis
# {'GALAXY': 0.9855998525424902, 'QSO': 0.9824371015086854, 'STAR': 0.9915609460665561}
#
#
# VotingClassifier
# {'GALAXY': 0.9880152372760297, 'QSO': 0.9603009318566127, 'STAR': 0.9966597071698754}
#
#
# ==========================================================
# ==========================================================
# Data Set Type:  Standard Scaled
# KNN
# [0.90206529 0.88607595 0.908      0.8945964  0.89793195]
# Accuracy: 0.898 (+/- 0.015)
# KNN :
#  [[1060    2  184]
#  [  12  218   12]
#  [ 155    4  853]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.86      0.85      0.86      1246
#          QSO       0.97      0.90      0.94       242
#         STAR       0.81      0.84      0.83      1012
#
#    micro avg       0.85      0.85      0.85      2500
#    macro avg       0.88      0.86      0.87      2500
# weighted avg       0.85      0.85      0.85      2500
#
#
#
# SVC
# [0.9586942  0.95003331 0.966      0.9646431  0.96197465]
# Accuracy: 0.960 (+/- 0.011)
# SVC :
#  [[1106    3  137]
#  [  16  224    2]
#  [  24    1  987]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.97      0.89      0.92      1246
#          QSO       0.98      0.93      0.95       242
#         STAR       0.88      0.98      0.92      1012
#
#    micro avg       0.93      0.93      0.93      2500
#    macro avg       0.94      0.93      0.93      2500
# weighted avg       0.93      0.93      0.93      2500
#
#
#
# LinearSVM
# [0.96868754 0.96668887 0.97933333 0.97598399 0.96997999]
# Accuracy: 0.972 (+/- 0.010)
# LinearSVM :
#  [[1195    3   48]
#  [  28  214    0]
#  [  12    1  999]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.97      0.96      0.96      1246
#          QSO       0.98      0.88      0.93       242
#         STAR       0.95      0.99      0.97      1012
#
#    micro avg       0.96      0.96      0.96      2500
#    macro avg       0.97      0.94      0.95      2500
# weighted avg       0.96      0.96      0.96      2500
#
#
#
# NuSVC
# [0.98001332 0.97534977 0.98733333 0.98732488 0.98732488]
# Accuracy: 0.983 (+/- 0.010)
# NuSVC :
#  [[1219    3   24]
#  [  16  225    1]
#  [   6    1 1005]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.98      0.98      1246
#          QSO       0.98      0.93      0.96       242
#         STAR       0.98      0.99      0.98      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.98      0.97      0.97      2500
# weighted avg       0.98      0.98      0.98      2500
#
#
#
# RbfKernelSVM
# [0.98401066 0.98067955 0.98933333 0.98532355 0.98599066]
# Accuracy: 0.985 (+/- 0.006)
# RbfKernelSVM :
#  [[1219    4   23]
#  [  17  224    1]
#  [  11    2  999]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.98      0.98      1246
#          QSO       0.97      0.93      0.95       242
#         STAR       0.98      0.99      0.98      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.98      0.96      0.97      2500
# weighted avg       0.98      0.98      0.98      2500
#
#
#
# PolyKernelSVM
# [0.99000666 0.98734177 0.99266667 0.99132755 0.98999333]
# Accuracy: 0.990 (+/- 0.004)
# PolyKernelSVM :
#  [[1233    5    8]
#  [  14  228    0]
#  [   2    2 1008]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.97      0.94      0.96       242
#         STAR       0.99      1.00      0.99      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.98      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# DecisionTreeClassifier
# [0.98600933 0.98600933 0.98866667 0.98198799 0.98732488]
# Accuracy: 0.986 (+/- 0.004)
# DecisionTreeClassifier :
#  [[1220   19    7]
#  [  16  226    0]
#  [   4    0 1008]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.98      0.98      1246
#          QSO       0.92      0.93      0.93       242
#         STAR       0.99      1.00      0.99      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.97      0.97      0.97      2500
# weighted avg       0.98      0.98      0.98      2500
#
#
#
# RandomForestClassifier
# [0.9853431  0.9853431  0.99133333 0.98799199 0.98999333]
# Accuracy: 0.988 (+/- 0.005)
# RandomForestClassifier :
#  [[1232    4   10]
#  [  14  228    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.94      0.96       242
#         STAR       0.99      1.00      0.99      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# LogisticRegression
# [0.94470353 0.94603598 0.96066667 0.95263509 0.94796531]
# Accuracy: 0.950 (+/- 0.012)
# LogisticRegression :
#  [[1128    3  115]
#  [  25  217    0]
#  [  34    0  978]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.95      0.91      0.93      1246
#          QSO       0.99      0.90      0.94       242
#         STAR       0.89      0.97      0.93      1012
#
#    micro avg       0.93      0.93      0.93      2500
#    macro avg       0.94      0.92      0.93      2500
# weighted avg       0.93      0.93      0.93      2500
#
#
#
# GradientBoostingClassifier
# [0.98667555 0.98467688 0.99133333 0.98865911 0.99066044]
# Accuracy: 0.988 (+/- 0.005)
# GradientBoostingClassifier :
#  [[1233    5    8]
#  [  12  230    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.95      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# XGBClassifier
# [0.98867422 0.98401066 0.99133333 0.98865911 0.99332889]
# Accuracy: 0.989 (+/- 0.006)
# XGBClassifier :
#  [[1230    8    8]
#  [  11  231    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.97      0.95      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.98      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# BaggingClassifier
# [0.98201199 0.9793471  0.986      0.98599066 0.98799199]
# Accuracy: 0.984 (+/- 0.006)
# BaggingClassifier :
#  [[1232    4   10]
#  [  13  229    0]
#  [   0    0 1012]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.95      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# AdaBoostClassifier
# [0.67954697 0.93404397 0.66266667 0.82054703 0.74116077]
# Accuracy: 0.768 (+/- 0.200)
# AdaBoostClassifier :
#  [[1223   16    7]
#  [ 125  117    0]
#  [ 151    0  861]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.82      0.98      0.89      1246
#          QSO       0.88      0.48      0.62       242
#         STAR       0.99      0.85      0.92      1012
#
#    micro avg       0.88      0.88      0.88      2500
#    macro avg       0.90      0.77      0.81      2500
# weighted avg       0.89      0.88      0.88      2500
#
#
#
# SGDClassifier
# [0.96602265 0.96002665 0.972      0.97398266 0.96664443]
# Accuracy: 0.968 (+/- 0.010)
# SGDClassifier :
#  [[1185    3   58]
#  [  30  212    0]
#  [  13    1  998]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.96      0.95      0.96      1246
#          QSO       0.98      0.88      0.93       242
#         STAR       0.95      0.99      0.97      1012
#
#    micro avg       0.96      0.96      0.96      2500
#    macro avg       0.96      0.94      0.95      2500
# ...
#         STAR       0.99      1.00      0.99      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.97      0.97      0.97      2500
# weighted avg       0.98      0.98      0.98      2500
#
#
#
# RandomForestClassifier
# [0.98600933 0.9853431  0.99133333 0.98799199 0.98999333]
# Accuracy: 0.988 (+/- 0.005)
# RandomForestClassifier :
#  [[1232    4   10]
#  [  14  228    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.94      0.96       242
#         STAR       0.99      1.00      0.99      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# LogisticRegression
# [0.81012658 0.79013991 0.81333333 0.80386925 0.8072048 ]
# Accuracy: 0.805 (+/- 0.016)
# LogisticRegression :
#  [[1097    1  148]
#  [  19  189   34]
#  [ 417    0  595]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.72      0.88      0.79      1246
#          QSO       0.99      0.78      0.88       242
#         STAR       0.77      0.59      0.67      1012
#
#    micro avg       0.75      0.75      0.75      2500
#    macro avg       0.83      0.75      0.78      2500
# weighted avg       0.76      0.75      0.75      2500
#
#
#
# GradientBoostingClassifier
# [0.98667555 0.98467688 0.99133333 0.98865911 0.99132755]
# Accuracy: 0.989 (+/- 0.005)
# GradientBoostingClassifier :
#  [[1233    5    8]
#  [  12  230    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.95      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# XGBClassifier
# [0.98867422 0.98401066 0.99133333 0.98865911 0.99332889]
# Accuracy: 0.989 (+/- 0.006)
# XGBClassifier :
#  [[1230    8    8]
#  [  11  231    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.97      0.95      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.98      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
# BaggingClassifier
# [0.98201199 0.9793471  0.986      0.98599066 0.98799199]
# Accuracy: 0.984 (+/- 0.006)
# BaggingClassifier :
#  [[1232    4   10]
#  [  13  229    0]
#  [   0    0 1012]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.95      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# AdaBoostClassifier
# [0.67954697 0.93404397 0.68066667 0.82054703 0.74116077]
# Accuracy: 0.771 (+/- 0.193)
# AdaBoostClassifier :
#  [[1223   16    7]
#  [ 125  117    0]
#  [ 151    0  861]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.82      0.98      0.89      1246
#          QSO       0.88      0.48      0.62       242
#         STAR       0.99      0.85      0.92      1012
#
#    micro avg       0.88      0.88      0.88      2500
#    macro avg       0.90      0.77      0.81      2500
# weighted avg       0.89      0.88      0.88      2500
#
#
#
# SGDClassifier
# [0.84810127 0.83744171 0.85666667 0.84923282 0.85056704]
# Accuracy: 0.848 (+/- 0.012)
# SGDClassifier :
#  [[998   3 245]
#  [ 12 226   4]
#  [ 80   0 932]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.92      0.80      0.85      1246
#          QSO       0.99      0.93      0.96       242
#         STAR       0.79      0.92      0.85      1012
#
#    micro avg       0.86      0.86      0.86      2500
#    macro avg       0.90      0.89      0.89      2500
# weighted avg       0.87      0.86      0.86      2500
#
#
#
# MLPClassifier
# [0.98334444 0.97868088 0.98333333 0.98799199 0.98465644]
# Accuracy: 0.984 (+/- 0.006)
# MLPClassifier :
#  [[1191    3   52]
#  [  15  227    0]
#  [   0    0 1012]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.96      0.97      1246
#          QSO       0.99      0.94      0.96       242
#         STAR       0.95      1.00      0.97      1012
#
#    micro avg       0.97      0.97      0.97      2500
#    macro avg       0.98      0.96      0.97      2500
# weighted avg       0.97      0.97      0.97      2500
#
#
#
# ExtraTreesClassifier
# [0.98134577 0.97468354 0.984      0.98332221 0.98132088]
# Accuracy: 0.981 (+/- 0.007)
# ExtraTreesClassifier :
#  [[1214    4   28]
#  [  15  227    0]
#  [  11    1 1000]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.97      0.98      1246
#          QSO       0.98      0.94      0.96       242
#         STAR       0.97      0.99      0.98      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.98      0.97      0.97      2500
# weighted avg       0.98      0.98      0.98      2500
#
#
#
# PassiveAggressiveClassifier
# [0.88207861 0.64690207 0.80933333 0.94996664 0.91727819]
# Accuracy: 0.841 (+/- 0.216)
# PassiveAggressiveClassifier :
#  [[896  20 330]
#  [ 15 227   0]
#  [ 44   0 968]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.94      0.72      0.81      1246
#          QSO       0.92      0.94      0.93       242
#         STAR       0.75      0.96      0.84      1012
#
#    micro avg       0.84      0.84      0.84      2500
#    macro avg       0.87      0.87      0.86      2500
# weighted avg       0.86      0.84      0.83      2500
#
#
#
# RidgeClassifier
# [0.81678881 0.80146569 0.82266667 0.80920614 0.82655103]
# Accuracy: 0.815 (+/- 0.018)
# RidgeClassifier :
#  [[1060    1  185]
#  [  12  185   45]
#  [ 274    0  738]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.79      0.85      0.82      1246
#          QSO       0.99      0.76      0.86       242
#         STAR       0.76      0.73      0.75      1012
#
#    micro avg       0.79      0.79      0.79      2500
#    macro avg       0.85      0.78      0.81      2500
# weighted avg       0.80      0.79      0.79      2500
#
#
#
# GaussianNB
# [0.98134577 0.9733511  0.98066667 0.97464977 0.98465644]
# Accuracy: 0.979 (+/- 0.009)
# GaussianNB :
#  [[1218   21    7]
#  [  11  231    0]
#  [   3    7 1002]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.98      0.98      1246
#          QSO       0.89      0.95      0.92       242
#         STAR       0.99      0.99      0.99      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.96      0.97      0.97      2500
# weighted avg       0.98      0.98      0.98      2500
#
#
#
# Something bad had happened... Could not proceed for the:  MultinomialNB
#
# LinearDiscriminantAnalysis
# [0.93537642 0.91672219 0.946      0.9299533  0.92328219]
# Accuracy: 0.930 (+/- 0.020)
# LinearDiscriminantAnalysis :
#  [[1131    0  115]
#  [  45  185   12]
#  [  74    2  936]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.90      0.91      0.91      1246
#          QSO       0.99      0.76      0.86       242
#         STAR       0.88      0.92      0.90      1012
#
#    micro avg       0.90      0.90      0.90      2500
#    macro avg       0.92      0.87      0.89      2500
# weighted avg       0.90      0.90      0.90      2500
#
#
#
# QuadraticDiscriminantAnalysis
# [0.9793471  0.98134577 0.98666667 0.98865911 0.98732488]
# Accuracy: 0.985 (+/- 0.007)
# QuadraticDiscriminantAnalysis :
#  [[1225   15    6]
#  [   5  237    0]
#  [   9    2 1001]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.98      0.99      1246
#          QSO       0.93      0.98      0.96       242
#         STAR       0.99      0.99      0.99      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.97      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# VotingClassifier
# [0.9853431  0.98334444 0.98933333 0.98999333 0.99066044]
# Accuracy: 0.988 (+/- 0.006)
# VotingClassifier :
#  [[1234    4    8]
#  [  13  229    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.98      0.95      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500
#
#
#
# By Acc:
# PolyKernelSVM 0.9897342184300231
# XGBClassifier 0.9892012404153661
# GradientBoostingClassifier 0.9885344845634746
# RandomForestClassifier 0.9881342177189115
# VotingClassifier 0.9877349288303388
# QuadraticDiscriminantAnalysis 0.9846687054823876
# DecisionTreeClassifier 0.9844010612152865
# BaggingClassifier 0.9842683498081554
# MLPClassifier 0.9836014164154443
# ExtraTreesClassifier 0.9809344818375475
# RbfKernelSVM 0.9808023931862488
# GaussianNB 0.9789339479113842
# NuSVC 0.9524046052761209
# LinearDiscriminantAnalysis 0.9302668182519191
# LinearSVM 0.9229342833189408
# KNN 0.8808016456896203
# SGDClassifier 0.8484019009193634
# PassiveAggressiveClassifier 0.8411117685533787
# RidgeClassifier 0.8153356670232595
# LogisticRegression 0.8049347743413812
# AdaBoostClassifier 0.7711930822487773
# SVC 0.7709357400899586
#
#
# By Precision(avg=micro):
# PolyKernelSVM 0.9904
# GradientBoostingClassifier 0.9896
# VotingClassifier 0.9896
# BaggingClassifier 0.9892
# XGBClassifier 0.9888
# RandomForestClassifier 0.9884
# QuadraticDiscriminantAnalysis 0.9852
# DecisionTreeClassifier 0.9816
# GaussianNB 0.9804
# ExtraTreesClassifier 0.9764
# RbfKernelSVM 0.976
# MLPClassifier 0.972
# NuSVC 0.9228
# LinearDiscriminantAnalysis 0.9008
# LinearSVM 0.8936
# AdaBoostClassifier 0.8804
# SGDClassifier 0.8624
# KNN 0.8592
# PassiveAggressiveClassifier 0.8364
# RidgeClassifier 0.7932
# LogisticRegression 0.7524
# SVC 0.5688
#
#
# By Recall(avg=micro):
# PolyKernelSVM 0.9904
# GradientBoostingClassifier 0.9896
# VotingClassifier 0.9896
# BaggingClassifier 0.9892
# XGBClassifier 0.9888
# RandomForestClassifier 0.9884
# QuadraticDiscriminantAnalysis 0.9852
# DecisionTreeClassifier 0.9816
# GaussianNB 0.9804
# ExtraTreesClassifier 0.9764
# RbfKernelSVM 0.976
# MLPClassifier 0.972
# NuSVC 0.9228
# LinearDiscriminantAnalysis 0.9008
# LinearSVM 0.8936
# AdaBoostClassifier 0.8804
# SGDClassifier 0.8624
# KNN 0.8592
# PassiveAggressiveClassifier 0.8364
# RidgeClassifier 0.7932
# LogisticRegression 0.7524
# SVC 0.5688
#
#
# By F1(avg=micro):
# PolyKernelSVM 0.9904
# GradientBoostingClassifier 0.9896
# VotingClassifier 0.9896
# BaggingClassifier 0.9892
# XGBClassifier 0.9888
# RandomForestClassifier 0.9884
# QuadraticDiscriminantAnalysis 0.9852
# DecisionTreeClassifier 0.9816
# GaussianNB 0.9804
# ExtraTreesClassifier 0.9764
# RbfKernelSVM 0.976
# MLPClassifier 0.972
# NuSVC 0.9228
# LinearDiscriminantAnalysis 0.9008
# LinearSVM 0.8936
# AdaBoostClassifier 0.8804
# SGDClassifier 0.8624
# KNN 0.8592000000000001
# PassiveAggressiveClassifier 0.8364
# RidgeClassifier 0.7932
# LogisticRegression 0.7524
# SVC 0.5688
#
#
# By Precision(avg=macro):
# PolyKernelSVM 0.9893266048662935
# VotingClassifier 0.9879212783855579
# BaggingClassifier 0.987535371715115
# RandomForestClassifier 0.9869784773695196
# GradientBoostingClassifier 0.9868130610887698
# XGBClassifier 0.9830048422509329
# RbfKernelSVM 0.9782456559763085
# ExtraTreesClassifier 0.9767477266136607
# MLPClassifier 0.9752155101142431
# QuadraticDiscriminantAnalysis 0.9719377130523926
# DecisionTreeClassifier 0.9664744652032115
# GaussianNB 0.9578635645285795
# NuSVC 0.9414157448572716
# LinearDiscriminantAnalysis 0.9248772079155788
# LinearSVM 0.9196678204221961
# SGDClassifier 0.8972192069812368
# AdaBoostClassifier 0.8958373278307564
# KNN 0.89349003953775
# PassiveAggressiveClassifier 0.8676703157444455
# RidgeClassifier 0.8481796412267059
# LogisticRegression 0.8253643178661202
# SVC 0.7898363479758829
#
#
# By Recall(avg=macro):
# PolyKernelSVM 0.9869201278802913
# QuadraticDiscriminantAnalysis 0.9838717817245151
# XGBClassifier 0.9802387402533959
# GradientBoostingClassifier 0.9796638980033748
# VotingClassifier 0.9785540102744882
# BaggingClassifier 0.9783483455597858
# RandomForestClassifier 0.9766415543273029
# GaussianNB 0.9740640405027312
# RbfKernelSVM 0.9737122139751264
# DecisionTreeClassifier 0.9696883182249794
# ExtraTreesClassifier 0.9668255461433949
# MLPClassifier 0.9646250923063997
# NuSVC 0.9215274481406737
# LinearSVM 0.9073074081401122
# SGDClassifier 0.88526533199447
# PassiveAggressiveClassifier 0.8712131305505201
# KNN 0.8690535308868125
# LinearDiscriminantAnalysis 0.8656895501945908
# RidgeClassifier 0.7814780443905106
# AdaBoostClassifier 0.7719341730644302
# LogisticRegression 0.7497845783474419
# SVC 0.5716273149656815
#
#
# By F1(avg=macro):
# PolyKernelSVM 0.9880850048690072
# GradientBoostingClassifier 0.9831652951802923
# VotingClassifier 0.9831180638814452
# BaggingClassifier 0.9828183616654865
# RandomForestClassifier 0.9816606740623275
# XGBClassifier 0.9816045421943392
# QuadraticDiscriminantAnalysis 0.9777135481140583
# RbfKernelSVM 0.9757431646774632
# ExtraTreesClassifier 0.9716224707955017
# MLPClassifier 0.9694227044141323
# DecisionTreeClassifier 0.9680670191803545
# GaussianNB 0.9655982862309832
# NuSVC 0.930987915323188
# LinearSVM 0.9115295281893064
# LinearDiscriminantAnalysis 0.8902965123898858
# SGDClassifier 0.8880298507389447
# KNN 0.8803562264371858
# PassiveAggressiveClassifier 0.8602319902660239
# AdaBoostClassifier 0.8103440426823755
# RidgeClassifier 0.8092805871102859
# LogisticRegression 0.7765562330886316
# SVC 0.5128703374214282
#
#
# KNN
# {'GALAXY': 0.8627742748085742, 'QSO': 0.9479042376417367, 'STAR': 0.8646935696374687}
#
#
# SVC
# {'GALAXY': 0.5701728785702765, 'QSO': 0.8553719008264462, 'STAR': 0.502134334225849}
#
#
# LinearSVM
# {'GALAXY': 0.8934555489848216, 'QSO': 0.9664992789640507, 'STAR': 0.907025638573675}
#
#
# NuSVC
# {'GALAXY': 0.9228388898702323, 'QSO': 0.9603009318566127, 'STAR': 0.9275056844744782}
#
#
# RbfKernelSVM
# {'GALAXY': 0.9759562337918342, 'QSO': 0.980740653983266, 'STAR': 0.9832387691784606}
#
#
# PolyKernelSVM
# {'GALAXY': 0.9903845415377054, 'QSO': 0.9869390010907041, 'STAR': 0.9949596774193548}
#
#
# DecisionTreeClassifier
# {'GALAXY': 0.9815921315034266, 'QSO': 0.9627348856956716, 'STAR': 0.9956715648773853}
#
#
# RandomForestClassifier
# {'GALAXY': 0.9884011612278909, 'QSO': 0.9701886405727295, 'STAR': 0.9961457137999914}
#
#
# LogisticRegression
# {'GALAXY': 0.766364967577268, 'QSO': 0.890274432870455, 'STAR': 0.7328164180373157}
#
#
# GradientBoostingClassifier
# {'GALAXY': 0.9895998935029096, 'QSO': 0.9740994370795483, 'STAR': 0.9968177568107441}
#
#
# XGBClassifier
# {'GALAXY': 0.9887947652583963, 'QSO': 0.9755012480876077, 'STAR': 0.9968177568107441}
#
#
# BaggingClassifier
# {'GALAXY': 0.9891986093937603, 'QSO': 0.9722547562752087, 'STAR': 0.9966397849462366}
#
#
# AdaBoostClassifier
# {'GALAXY': 0.8807226185996143, 'QSO': 0.7381925788198435, 'STAR': 0.9230431063793617}
#
#
# SGDClassifier
# {'GALAXY': 0.8637989253009952, 'QSO': 0.9662778440659108, 'STAR': 0.8768049534616856}
#
#
# MLPClassifier
# {'GALAXY': 0.9719485127527706, 'QSO': 0.96834395976839, 'STAR': 0.9825268817204301}
#
#
# ExtraTreesClassifier
# {'GALAXY': 0.9767920823509232, 'QSO': 0.9679010899721101, 'STAR': 0.9846625440945217}
#
#
# PassiveAggressiveClassifier
# {'GALAXY': 0.8360258409046109, 'QSO': 0.9645795665000111, 'STAR': 0.8673737727910238}
#
#
# RidgeClassifier
# {'GALAXY': 0.8113260679789361, 'QSO': 0.8820099700605377, 'STAR': 0.7873395596922946}
#
#
# GaussianNB
# {'GALAXY': 0.9831819077827357, 'QSO': 0.9710725501248088, 'STAR': 0.9927071379999148}
#
#
# LinearDiscriminantAnalysis
# {'GALAXY': 0.9064041615786145, 'QSO': 0.8817885351623979, 'STAR': 0.9197758617025799}
#
#
# QuadraticDiscriminantAnalysis
# {'GALAXY': 0.9859908965467806, 'QSO': 0.9859050282192242, 'STAR': 0.9925490883590463}
#
#
# VotingClassifier
# {'GALAXY': 0.989602453529124, 'QSO': 0.9722547562752087, 'STAR': 0.9968177568107441}
