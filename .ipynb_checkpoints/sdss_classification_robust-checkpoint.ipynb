# %% [markdown]
# # Data prep

# %% [markdown]
# ## Import packages

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals
import warnings
import helpers
import matplotlib as mpl
import os

# Common imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import operator
from collections import OrderedDict

# Imports for ML
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, BaggingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier, PassiveAggressiveClassifier, RidgeClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, MinMaxScaler, Normalizer
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, classification_report
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.naive_bayes import GaussianNB, MultinomialNB, ComplementNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
sns.set_style('whitegrid')

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "results"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)

# Helper functioins and structures
# Ignore useless warnings (see SciPy issue #5998)
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %% [markdown]
# ## Load data

# %%
DATA_PATH = "Skyserver_SQL2_27_2018 6_51_39 PM.csv"
RESULTS_FOLDER = "results"

# We load the data. Those that have nothing to do with the features of the objects are ignored.
sdss_data = pd.read_csv(DATA_PATH)

# We have a general look at the features
sdss_data.head(3)
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
#
#      mjd  fiberid
# 0  54922      491
# 1  51615      541
# 2  52023      513

# %% [markdown]
# ## Drop not important features

# %%
print(sdss_data.columns.values)
sdss_data.drop(['objid', 'run', 'rerun', 'camcol', 'field',
                'specobjid', 'fiberid', 'mjd', 'plate'], axis=1, inplace=True)
sdss_data.head(1)
# Out:
# ['objid' 'ra' 'dec' 'u' 'g' 'r' 'i' 'z' 'run' 'rerun' 'camcol' 'field'
#  'specobjid' 'class' 'redshift' 'plate' 'mjd' 'fiberid']
#            ra       dec         u        g         r         i         z  \
# 0  183.531326  0.089693  19.47406  17.0424  15.94699  15.50342  15.22531
#
#   class  redshift
# 0  STAR -0.000009

# %% [markdown]
# ## Split into train/test sets

# %%
X = sdss_data.drop(['class'], axis=1)
y = sdss_data['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ## Define helper methods

# %%
def cv_learn(clf, X_train, y_train, X_test, y_test,
             cv_size=5, scoring_type="accuracy", average_type="macro"):
    # 5xCV
    y_scores = cross_val_score(clf, X_train, y_train,
                               cv=cv_size, scoring=scoring_type)
    # Test Prediction
    pred = cross_val_predict(clf, X_test, y_test, cv=cv_size)

    # Conf. Matrix
    matrix = confusion_matrix(y_test, pred)

    # CLF. Report
    report_str = classification_report(y_test, pred)
    report_dict = classification_report(y_test, pred, output_dict=True)

    return (y_scores, pred, matrix, report_str, report_dict)


def print_cv_scores(scores):
    print("Accuracy: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))


def print_conf_matrix(clf_name, matrix):
    print(clf_name, ":\n", matrix)


def plot_confusion_matrix(clf_name, class_names, cm, figsize):
    df_cm = pd.DataFrame(cm, index=[i for i in class_names],
                         columns=[i for i in class_names])
    plt.figure(figsize=figsize)
    sns.heatmap(df_cm, annot=True, fmt="d", cmap="jet").set_title(
        "Confusion Matrix for: " + str(clf_name))


def print_learning_results_multiple(classifs, class_names, scores, matrices, reports):
    for item in zip(classifs, scores, matrices, reports):
        print(item[0])
        print(item[1])
        print_cv_scores(item[1])
        print_conf_matrix(item[0], item[2])
        # Plot non-normalized confusion matrix
        plot_confusion_matrix(item[0], class_names, item[2], (10, 7))
        print(item[3])
        print("\n")


def print_learning_results_single(clf, class_names, scores, matrix, report):
    print(clf)
    print(scores)
    print_cv_scores(scores)
    print_conf_matrix(clf, matrix)
    # Plot non-normalized confusion matrix
    plot_confusion_matrix(clf, class_names, matrix, (10, 7))
    print(report)
    print("\n")


class_names = ["GALAXY", "QSO", "STAR"]


class ResultSet:
    def __init__(self, clf_name, scores, predictions, matrix, report_str, report_dict):
        self.classifier_name = clf_name
        self.scores = scores
        self.predictions = predictions
        self.matrix = matrix
        self.report_str = report_str
        self.report_dict = report_dict


def print_kv_arr(ordered_by, arr):
    print(ordered_by)
    for kv in arr:
        print(kv[0], kv[1])
    print("\n")


def roc_auc_score_multiclass(actual_class, pred_class, average="macro"):
    # creating a set of all the unique classes using the actual class list
    unique_class = set(actual_class)
    roc_auc_dict = {}
    for per_class in unique_class:
        # creating a list of all the classes except the current class
        other_class = [x for x in unique_class if x != per_class]

        # marking the current class as 1 and all other classes as 0
        new_actual_class = [0 if x in other_class else 1 for x in actual_class]
        new_pred_class = [0 if x in other_class else 1 for x in pred_class]

        # using the sklearn metrics method to calculate the roc_auc_score
        roc_auc = roc_auc_score(
            new_actual_class, new_pred_class, average=average)
        roc_auc_dict[per_class] = roc_auc

    return roc_auc_dict


def order_results(result_sets):
    by_acc = {}
    by_prec_micro = {}
    by_recall_micro = {}
    by_f1_micro = {}

    by_acc_macro = {}
    by_prec_macro = {}
    by_recall_macro = {}
    by_f1_macro = {}

    for result_set in result_sets:
        by_acc[result_set.classifier_name] = result_set.scores.mean()

        micro_results = result_set.report_dict["micro avg"]
        macro_results = result_set.report_dict["macro avg"]

        by_prec_micro[result_set.classifier_name] = micro_results["precision"]
        by_prec_macro[result_set.classifier_name] = macro_results["precision"]

        by_recall_micro[result_set.classifier_name] = micro_results["recall"]
        by_recall_macro[result_set.classifier_name] = macro_results["recall"]

        by_f1_micro[result_set.classifier_name] = micro_results["f1-score"]
        by_f1_macro[result_set.classifier_name] = macro_results["f1-score"]

    sorted_acc = sorted(by_acc.items(), key=lambda kv: kv[1], reverse=True)

    sorted_prec_micro = sorted(by_prec_micro.items(), key=lambda kv: kv[1], reverse=True)
    sorted_recall_micro = sorted(by_recall_micro.items(), key=lambda kv: kv[1], reverse=True)
    sorted_f1_micro = sorted(by_f1_micro.items(), key=lambda kv: kv[1], reverse=True)

    sorted_prec_macro = sorted(by_prec_macro.items(), key=lambda kv: kv[1], reverse=True)
    sorted_recall_macro = sorted(by_recall_macro.items(), key=lambda kv: kv[1], reverse=True)
    sorted_f1_macro = sorted(by_f1_macro.items(), key=lambda kv: kv[1], reverse=True)

    print_kv_arr("By Acc:", sorted_acc)
    print_kv_arr("By Precision(avg=micro):", sorted_prec_micro)
    print_kv_arr("By Recall(avg=micro):", sorted_recall_micro)
    print_kv_arr("By F1(avg=micro):", sorted_f1_micro)
    print_kv_arr("By Precision(avg=macro):", sorted_prec_macro)
    print_kv_arr("By Recall(avg=macro):", sorted_recall_macro)
    print_kv_arr("By F1(avg=macro):", sorted_f1_macro)


def do_stuff(clf, clf_name, class_names, X_train, y_train, X_test, y_test, result_sets):
    scores, predictions, matrix, report_str, report_dict = cv_learn(
        clf, X_train, y_train, X_test, y_test)

    # append results for later use
    result_sets.append(
        ResultSet(clf_name, scores, predictions, matrix, report_str, report_dict))

    # print results
    print_learning_results_single(
        clf_name, class_names, scores, matrix, report_str)


def print_roc_auc_scores(result_sets, y_true):
    for result_set in result_sets:
        print(result_set.classifier_name)
        # assuming your already have a list of actual_class and predicted_class
        score = roc_auc_score_multiclass(y_true, result_set.predictions)
        print(score)
        print("\n")

# %% [markdown]
# ## Scale the data

# %%
std_scaler = StandardScaler()
min_max_scaler = MinMaxScaler()
normalizer = Normalizer()

X_train_norm = normalizer.fit_transform(X_train)
X_test_norm = normalizer.fit_transform(X_test)

#X_train_min_max = min_max_scaler.fit_transform(X_train_norm)
#X_test_min_max = min_max_scaler.fit_transform(X_test_norm)

X_train_scaled = std_scaler.fit_transform(X_train.astype(np.float64))
X_test_scaled = std_scaler.fit_transform(X_test.astype(np.float64))

#X_train_min_max_scaled = std_scaler.fit_transform(X_train_min_max.astype(np.float64))
#X_test_min_max_scaled = std_scaler.fit_transform(X_test_min_max.astype(np.float64))

X_train_norm_scaled = std_scaler.fit_transform(X_train_norm.astype(np.float64))
X_test_norm_scaled = std_scaler.fit_transform(X_test_norm.astype(np.float64))

# %% [markdown]
# # Classification

# %% [markdown]
# ## Prepare result sets

# %%
result_sets = []

# %% [markdown]
# ## KNN

# %%
knn_clf = KNeighborsClassifier()
do_stuff(knn_clf, "KNN", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# KNN
# [0.97001999 0.96469021 0.96933333 0.96797865 0.97131421]
# Accuracy: 0.969 (+/- 0.005)
# KNN :
#  [[1142    2  102]
#  [  24  217    1]
#  [  24    0  988]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.96      0.92      0.94      1246
#          QSO       0.99      0.90      0.94       242
#         STAR       0.91      0.98      0.94      1012
#
#    micro avg       0.94      0.94      0.94      2500
#    macro avg       0.95      0.93      0.94      2500
# weighted avg       0.94      0.94      0.94      2500

# %% [markdown]
# ## SVC

# %%
svm_clf = SVC(gamma="auto", random_state=42)
do_stuff(svm_clf, "SVC", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# SVC
# [0.95736176 0.94603598 0.94333333 0.9533022  0.94929953]
# Accuracy: 0.950 (+/- 0.010)
# SVC :
#  [[1100    2  144]
#  [  34  207    1]
#  [   4    0 1008]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.97      0.88      0.92      1246
#          QSO       0.99      0.86      0.92       242
#         STAR       0.87      1.00      0.93      1012
#
#    micro avg       0.93      0.93      0.93      2500
#    macro avg       0.94      0.91      0.92      2500
# weighted avg       0.93      0.93      0.93      2500

# %% [markdown]
# ## Linear SVM

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    lsvm_clf = LinearSVC(C=10, loss="hinge", random_state=42)
    do_stuff(lsvm_clf, "LinearSVC", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# LinearSVC
# [0.9673551  0.96535643 0.97466667 0.97598399 0.96864576]
# Accuracy: 0.970 (+/- 0.008)
# LinearSVC :
#  [[1193   10   43]
#  [  22  220    0]
#  [  15    1  996]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.97      0.96      0.96      1246
#          QSO       0.95      0.91      0.93       242
#         STAR       0.96      0.98      0.97      1012
#
#    micro avg       0.96      0.96      0.96      2500
#    macro avg       0.96      0.95      0.96      2500
# weighted avg       0.96      0.96      0.96      2500

# %% [markdown]
# ## Nu-SVM

# %%
nusvm_clf = NuSVC(nu=0.05, gamma=0.1)
do_stuff(nusvm_clf, "NuSVC", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# NuSVC
# [0.98401066 0.97601599 0.98266667 0.98465644 0.98532355]
# Accuracy: 0.983 (+/- 0.007)
# NuSVC :
#  [[1221    2   23]
#  [  25  217    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.98      0.98      1246
#          QSO       0.99      0.90      0.94       242
#         STAR       0.98      1.00      0.99      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.98      0.96      0.97      2500
# weighted avg       0.98      0.98      0.98      2500

# %% [markdown]
# ## RBF Kernel - SVM

# %%
rbf_svm_clf = SVC(kernel="rbf", gamma=0.1, C=1000)
do_stuff(rbf_svm_clf, "RbfKernelSVM", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# RbfKernelSVM
# [0.98800799 0.98401066 0.98933333 0.99266177 0.98999333]
# Accuracy: 0.989 (+/- 0.006)
# RbfKernelSVM :
#  [[1224    3   19]
#  [  14  228    0]
#  [   2    0 1010]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.98      0.98      1246
#          QSO       0.99      0.94      0.96       242
#         STAR       0.98      1.00      0.99      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.99      0.97      0.98      2500
# weighted avg       0.98      0.98      0.98      2500

# %% [markdown]
# ## Poly Kernel SVM

# %%
poly_svm_clf = SVC(kernel="poly", gamma="scale", degree=3, coef0=100, C=5)
do_stuff(poly_svm_clf, "PolyKernelSVM", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# PolyKernelSVM
# [0.98867422 0.98734177 0.994      0.99066044 0.98799199]
# Accuracy: 0.990 (+/- 0.005)
# PolyKernelSVM :
#  [[1233    7    6]
#  [  11  231    0]
#  [   3    0 1009]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.97      0.95      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.98      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500

# %% [markdown]
# ## Decision Tree

# %%
tree_clf = DecisionTreeClassifier(random_state=42)
do_stuff(tree_clf, "DecisionTree", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# DecisionTree
# [0.98001332 0.98067955 0.984      0.98465644 0.98465644]
# Accuracy: 0.983 (+/- 0.004)
# DecisionTree :
#  [[1220   18    8]
#  [  20  222    0]
#  [   5    0 1007]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.98      0.98      1246
#          QSO       0.93      0.92      0.92       242
#         STAR       0.99      1.00      0.99      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.97      0.96      0.96      2500
# weighted avg       0.98      0.98      0.98      2500

# %% [markdown]
# ## Random Forest

# %%
rnd_clf = RandomForestClassifier(n_estimators=1000, random_state=42)
do_stuff(rnd_clf, "RandomForest", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# RandomForest
# [0.98467688 0.98334444 0.98933333 0.98799199 0.99066044]
# Accuracy: 0.987 (+/- 0.006)
# RandomForest :
#  [[1235    3    8]
#  [  21  221    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.99      0.99      1246
#          QSO       0.99      0.91      0.95       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.97      0.98      2500
# weighted avg       0.99      0.99      0.99      2500

# %% [markdown]
# ## Logistic Regression

# %%
log_clf = LogisticRegression(
    solver="liblinear", random_state=42, multi_class='auto')
do_stuff(log_clf, "LogisticRegression", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# LogisticRegression
# [0.94470353 0.94536975 0.94866667 0.94663109 0.93995997]
# Accuracy: 0.945 (+/- 0.006)
# LogisticRegression :
#  [[1147    3   96]
#  [  21  221    0]
#  [  39    0  973]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.95      0.92      0.94      1246
#          QSO       0.99      0.91      0.95       242
#         STAR       0.91      0.96      0.94      1012
#
#    micro avg       0.94      0.94      0.94      2500
#    macro avg       0.95      0.93      0.94      2500
# weighted avg       0.94      0.94      0.94      2500

# %% [markdown]
# ## Gradient Boosting

# %%
# Xgboost parameters
xgb_params = {'learning_rate': 0.05,
              'max_depth': 4,
              'subsample': 0.9,
              'colsample_bytree': 0.9,
              'objective': 'binary:logistic',
              'silent': 1,
              'n_estimators': 100,
              'gamma': 1,
              'min_child_weight': 4,
              # ENABLE GPU COMPUTING BY UNCOMMENTING BELOW
              # 'gpu_id': 0,
              # 'tree_method': 'gpu_hist'
              }
xgb_clf = XGBClassifier(**xgb_params, seed=42)
do_stuff(xgb_clf, "XGB", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# XGB
# [0.98800799 0.98600933 0.99333333 0.98732488 0.99466311]
# Accuracy: 0.990 (+/- 0.007)
# XGB :
#  [[1231    7    8]
#  [  16  226    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.97      0.93      0.95       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.98      0.97      0.98      2500
# weighted avg       0.99      0.99      0.99      2500

# %% [markdown]
# ## Bagging Classifier (DecisionTreeClassifier)

# %%
bag_df_clf = BaggingClassifier(
    DecisionTreeClassifier(splitter="random", max_leaf_nodes=16, random_state=42),
    n_estimators=500, max_samples=1.0, bootstrap=True, n_jobs=-1, random_state=42)
do_stuff(bag_df_clf, "BaggingCLF(DecisionTreeClassifier)", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# BaggingCLF(DecisionTreeClassifier)
# [0.9853431  0.98401066 0.98733333 0.98732488 0.98732488]
# Accuracy: 0.986 (+/- 0.003)
# BaggingCLF(DecisionTreeClassifier) :
#  [[1235    3    8]
#  [  18  224    0]
#  [   0    0 1012]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.99      0.93      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.97      0.98      2500
# weighted avg       0.99      0.99      0.99      2500

# %% [markdown]
# ## Ada Boost

# %%
ada_clf = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=1), n_estimators=500,
    algorithm="SAMME.R", learning_rate=0.5, random_state=42)
do_stuff(ada_clf, "AdaBoost(DecisionTreeClassifier)", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# AdaBoost(DecisionTreeClassifier)
# [0.739507   0.91672219 0.91866667 0.87658439 0.84656438]
# Accuracy: 0.860 (+/- 0.132)
# AdaBoost(DecisionTreeClassifier) :
#  [[1228   10    8]
#  [ 191   51    0]
#  [  26    0  986]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.85      0.99      0.91      1246
#          QSO       0.84      0.21      0.34       242
#         STAR       0.99      0.97      0.98      1012
#
#    micro avg       0.91      0.91      0.91      2500
#    macro avg       0.89      0.72      0.74      2500
# weighted avg       0.91      0.91      0.89      2500

# %% [markdown]
# ## SGD

# %%
sgd_clf = SGDClassifier(max_iter=500, tol=-np.infty, random_state=42)
do_stuff(sgd_clf, "SGDClassifier", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# SGDClassifier
# [0.96269154 0.95936043 0.96866667 0.96597732 0.96731154]
# Accuracy: 0.965 (+/- 0.007)
# SGDClassifier :
#  [[1175    8   63]
#  [  19  223    0]
#  [  19    0  993]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.97      0.94      0.96      1246
#          QSO       0.97      0.92      0.94       242
#         STAR       0.94      0.98      0.96      1012
#
#    micro avg       0.96      0.96      0.96      2500
#    macro avg       0.96      0.95      0.95      2500
# weighted avg       0.96      0.96      0.96      2500

# %% [markdown]
# ## MLP

# %%
mlp_clf = MLPClassifier(random_state=42, max_iter=2000)
do_stuff(mlp_clf, "MLP", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# MLP
# [0.98334444 0.97734843 0.98466667 0.98799199 0.98532355]
# Accuracy: 0.984 (+/- 0.007)
# MLP :
#  [[1213    3   30]
#  [  14  228    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.97      0.98      1246
#          QSO       0.99      0.94      0.96       242
#         STAR       0.97      1.00      0.98      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.98      0.97      0.98      2500
# weighted avg       0.98      0.98      0.98      2500

# %% [markdown]
# ## Extra Trees

# %%
xtree_clf = ExtraTreesClassifier(n_estimators=10, random_state=42)
do_stuff(xtree_clf, "XTrees", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# XTrees
# [0.96202532 0.96602265 0.97066667 0.97398266 0.97731821]
# Accuracy: 0.970 (+/- 0.011)
# XTrees :
#  [[1209    6   31]
#  [  23  218    1]
#  [  33    0  979]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.96      0.97      0.96      1246
#          QSO       0.97      0.90      0.94       242
#         STAR       0.97      0.97      0.97      1012
#
#    micro avg       0.96      0.96      0.96      2500
#    macro avg       0.97      0.95      0.96      2500
# weighted avg       0.96      0.96      0.96      2500

# %% [markdown]
# ## Passive Aggressive Classifier

# %%
pa_clf = PassiveAggressiveClassifier(max_iter=5000, random_state=0, tol=1e-3)
do_stuff(pa_clf, "PassiveAggressiveClassifier", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# PassiveAggressiveClassifier
# [0.9673551  0.93804131 0.962      0.9706471  0.94062708]
# Accuracy: 0.956 (+/- 0.027)
# PassiveAggressiveClassifier :
#  [[1169   17   60]
#  [  23  219    0]
#  [  52    1  959]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.94      0.94      0.94      1246
#          QSO       0.92      0.90      0.91       242
#         STAR       0.94      0.95      0.94      1012
#
#    micro avg       0.94      0.94      0.94      2500
#    macro avg       0.93      0.93      0.93      2500
# weighted avg       0.94      0.94      0.94      2500

# %% [markdown]
# ## Ridge Classifier

# %%
r_clf = RidgeClassifier()
do_stuff(r_clf, "RidgeClassifier", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# RidgeClassifier
# [0.88007995 0.88540973 0.888      0.88592395 0.88192128]
# Accuracy: 0.884 (+/- 0.006)
# RidgeClassifier :
#  [[1093    1  152]
#  [  30  184   28]
#  [ 208    0  804]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.82      0.88      0.85      1246
#          QSO       0.99      0.76      0.86       242
#         STAR       0.82      0.79      0.81      1012
#
#    micro avg       0.83      0.83      0.83      2500
#    macro avg       0.88      0.81      0.84      2500
# weighted avg       0.84      0.83      0.83      2500

# %% [markdown]
# ## Naive Bayes

# %%
nb_clf = GaussianNB()
do_stuff(nb_clf, "NaiveBayes", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# NaiveBayes
# [0.97001999 0.95069953 0.96933333 0.96330887 0.96731154]
# Accuracy: 0.964 (+/- 0.014)
# NaiveBayes :
#  [[1233    7    6]
#  [  16  226    0]
#  [   6    0 1006]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.99      0.99      1246
#          QSO       0.97      0.93      0.95       242
#         STAR       0.99      0.99      0.99      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.98      0.97      0.98      2500
# weighted avg       0.99      0.99      0.99      2500

# %% [markdown]
# ## Multinomial Naive Bayes

# %%
mnb_clf = MultinomialNB()
do_stuff(r_clf, "MultinomialNaiveBayes", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# MultinomialNaiveBayes
# [0.88007995 0.88540973 0.888      0.88592395 0.88192128]
# Accuracy: 0.884 (+/- 0.006)
# MultinomialNaiveBayes :
#  [[1093    1  152]
#  [  30  184   28]
#  [ 208    0  804]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.82      0.88      0.85      1246
#          QSO       0.99      0.76      0.86       242
#         STAR       0.82      0.79      0.81      1012
#
#    micro avg       0.83      0.83      0.83      2500
#    macro avg       0.88      0.81      0.84      2500
# weighted avg       0.84      0.83      0.83      2500

# %% [markdown]
# ## LDA

# %%
lda_clf = LinearDiscriminantAnalysis()
do_stuff(lda_clf, "LDA", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# LDA
# [0.92804797 0.91672219 0.94733333 0.93195464 0.9239493 ]
# Accuracy: 0.930 (+/- 0.020)
# LDA :
#  [[1143    0  103]
#  [  44  184   14]
#  [  83    1  928]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.90      0.92      0.91      1246
#          QSO       0.99      0.76      0.86       242
#         STAR       0.89      0.92      0.90      1012
#
#    micro avg       0.90      0.90      0.90      2500
#    macro avg       0.93      0.86      0.89      2500
# weighted avg       0.90      0.90      0.90      2500

# %% [markdown]
# ## QDA

# %%
qda_clf = QuadraticDiscriminantAnalysis()
do_stuff(qda_clf, "QDA", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# QDA
# [0.97734843 0.97801466 0.984      0.98665777 0.98599066]
# Accuracy: 0.982 (+/- 0.008)
# QDA :
#  [[1228   12    6]
#  [   7  235    0]
#  [  11    2  999]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.99      0.99      0.99      1246
#          QSO       0.94      0.97      0.96       242
#         STAR       0.99      0.99      0.99      1012
#
#    micro avg       0.98      0.98      0.98      2500
#    macro avg       0.97      0.98      0.98      2500
# weighted avg       0.98      0.98      0.98      2500

# %% [markdown]
# ## Voting Classifier

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    v_clf = VotingClassifier(estimators=[
        ("NuSVC", nusvm_clf),
        ("RbfSVC", rbf_svm_clf),
        ("PolySVC", poly_svm_clf),
        ("Tree", tree_clf),
        ("RF", rnd_clf),
        ("XGB", xgb_clf),
        ("Bagging", bag_df_clf),
        ("MLP", mlp_clf),
        ("XTrees", xtree_clf),
        ("NaiveBayes", nb_clf),
        ("QDA", qda_clf),
    ], voting="hard", n_jobs=-1)
    do_stuff(v_clf, "VotingClassifier", class_names, X_train_norm_scaled, y_train, X_test_norm_scaled, y_test, result_sets)
# Out:
# VotingClassifier
# [0.98467688 0.98334444 0.99       0.98732488 0.99132755]
# Accuracy: 0.987 (+/- 0.006)
# VotingClassifier :
#  [[1236    2    8]
#  [  18  224    0]
#  [   1    0 1011]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.99      0.99      1246
#          QSO       0.99      0.93      0.96       242
#         STAR       0.99      1.00      1.00      1012
#
#    micro avg       0.99      0.99      0.99      2500
#    macro avg       0.99      0.97      0.98      2500
# weighted avg       0.99      0.99      0.99      2500

# %% [markdown]
# # Results

# %% [markdown]
# ## Ordered results

# %%
order_results(result_sets)
# Out:
# By Acc:
# XGB 0.9898677294226944
# PolyKernelSVM 0.9897336848594154
# RbfKernelSVM 0.988801418193223
# VotingClassifier 0.9873347508154448
# RandomForest 0.9872014174821114
# BaggingCLF(DecisionTreeClassifier) 0.9862673728003137
# MLP 0.9837350163563036
# DecisionTree 0.9828011493338442
# NuSVC 0.9825346604450343
# QDA 0.9824023047121354
# LinearSVC 0.9704015890970027
# XTrees 0.970003100386563
# KNN 0.9686672776891605
# SGDClassifier 0.9648014982525177
# NaiveBayes 0.9641346534524387
# PassiveAggressiveClassifier 0.9557341170373853
# SVC 0.9498665605332862
# LogisticRegression 0.9450662023701639
# LDA 0.9296014845043634
# RidgeClassifier 0.8842669807408804
# MultinomialNaiveBayes 0.8842669807408804
# AdaBoost(DecisionTreeClassifier) 0.859608922611373
#
#
# By Precision(avg=micro):
# PolyKernelSVM 0.9892
# BaggingCLF(DecisionTreeClassifier) 0.9884
# VotingClassifier 0.9884
# XGB 0.9872
# RandomForest 0.9868
# NaiveBayes 0.986
# RbfKernelSVM 0.9848
# QDA 0.9848
# MLP 0.9808
# NuSVC 0.9796
# DecisionTree 0.9796
# LinearSVC 0.9636
# XTrees 0.9624
# SGDClassifier 0.9564
# KNN 0.9388
# PassiveAggressiveClassifier 0.9388
# LogisticRegression 0.9364
# SVC 0.926
# AdaBoost(DecisionTreeClassifier) 0.906
# LDA 0.902
# RidgeClassifier 0.8324
# MultinomialNaiveBayes 0.8324
#
#
# By Recall(avg=micro):
# PolyKernelSVM 0.9892
# BaggingCLF(DecisionTreeClassifier) 0.9884
# VotingClassifier 0.9884
# XGB 0.9872
# RandomForest 0.9868
# NaiveBayes 0.986
# RbfKernelSVM 0.9848
# QDA 0.9848
# MLP 0.9808
# NuSVC 0.9796
# DecisionTree 0.9796
# LinearSVC 0.9636
# XTrees 0.9624
# SGDClassifier 0.9564
# KNN 0.9388
# PassiveAggressiveClassifier 0.9388
# LogisticRegression 0.9364
# SVC 0.926
# AdaBoost(DecisionTreeClassifier) 0.906
# LDA 0.902
# RidgeClassifier 0.8324
# MultinomialNaiveBayes 0.8324
#
#
# By F1(avg=micro):
# PolyKernelSVM 0.9892
# BaggingCLF(DecisionTreeClassifier) 0.9884
# VotingClassifier 0.9884
# XGB 0.9872
# RandomForest 0.9868
# NaiveBayes 0.986
# RbfKernelSVM 0.9848
# QDA 0.9848
# MLP 0.9808
# NuSVC 0.9796
# DecisionTree 0.9796
# LinearSVC 0.9636
# XTrees 0.9624
# SGDClassifier 0.9564
# KNN 0.9388
# PassiveAggressiveClassifier 0.9388
# LogisticRegression 0.9364
# SVC 0.926
# AdaBoost(DecisionTreeClassifier) 0.906
# LDA 0.902
# RidgeClassifier 0.8324
# MultinomialNaiveBayes 0.8324
#
#
# By Precision(avg=macro):
# VotingClassifier 0.9893867220318907
# BaggingCLF(DecisionTreeClassifier) 0.9881918269896167
# RandomForest 0.9870847732812145
# RbfKernelSVM 0.9852150775126418
# PolyKernelSVM 0.9844833201925517
# XGB 0.9828281508407137
# NuSVC 0.9825912753597899
# NaiveBayes 0.9821661157706787
# MLP 0.9819931864985324
# QDA 0.9744529077395003
# XTrees 0.9657645603797714
# DecisionTree 0.9656793017719482
# LinearSVC 0.9603045678469985
# SGDClassifier 0.9581271955808229
# KNN 0.9520408820627222
# LogisticRegression 0.949031187759363
# SVC 0.9437599388385115
# PassiveAggressiveClassifier 0.9349599959034681
# LDA 0.9275442907021855
# AdaBoost(DecisionTreeClassifier) 0.8926147578838127
# RidgeClassifier 0.8776182809039087
# MultinomialNaiveBayes 0.8776182809039087
#
#
# By Recall(avg=macro):
# QDA 0.9812607674778479
# PolyKernelSVM 0.9803825469433677
# RbfKernelSVM 0.9741719916476766
# XGB 0.9736192106512309
# NaiveBayes 0.9725073523092798
# BaggingCLF(DecisionTreeClassifier) 0.9722638614364866
# VotingClassifier 0.972202003411756
# MLP 0.9715586222780787
# RandomForest 0.9678022492673645
# DecisionTree 0.9638492955875378
# NuSVC 0.9585472890420262
# LinearSVC 0.9502481722804146
# SGDClassifier 0.9485768520830918
# XTrees 0.9461742421839238
# LogisticRegression 0.9317437791590654
# PassiveAggressiveClassifier 0.9302631277916618
# KNN 0.9298372350510734
# SVC 0.9114147905949656
# LDA 0.8648873664861586
# RidgeClassifier 0.8106680147582576
# MultinomialNaiveBayes 0.8106680147582576
# AdaBoost(DecisionTreeClassifier) 0.7235352913729253
#
#
# By F1(avg=macro):
# PolyKernelSVM 0.9824098719631543
# VotingClassifier 0.9804127602621203
# BaggingCLF(DecisionTreeClassifier) 0.9798940769554187
# RbfKernelSVM 0.9794948410925329
# XGB 0.9781056129465701
# QDA 0.9777879946822775
# NaiveBayes 0.9772185637914585
# RandomForest 0.976960786822899
# MLP 0.9765191880828641
# NuSVC 0.9697480615394417
# DecisionTree 0.9647582338471118
# XTrees 0.9554849271003342
# LinearSVC 0.9550390509442316
# SGDClassifier 0.9529795826215949
# LogisticRegression 0.9396022024062418
# KNN 0.939548126125565
# PassiveAggressiveClassifier 0.9325744055980388
# SVC 0.9239855699124706
# LDA 0.8908988781435525
# RidgeClassifier 0.8385703687374034
# MultinomialNaiveBayes 0.8385703687374034
# AdaBoost(DecisionTreeClassifier) 0.7441187933391907

# %% [markdown]
# Best ACC: PolyKernelSVM 0.9902671963261614
#
# Best Recall(micro): VotingClassifier 0.9908
#
# Best Precision(micro):VotingClassifier 0.9908
#
# Best F1(micro): VotingClassifier 0.9908
#
# Best Recall(macro): VotingClassifier 0.9887303025998198
#
# Best Precision(macro): QDA 0.9838717817245151
#
# Best F1(macro):VotingClassifier 0.98568122764447

# %% [markdown]
# ## ROC AUC scores

# %%
print_roc_auc_scores(result_sets, y_test)
# Out:
# KNN
# {'QSO': 0.9479042376417367, 'GALAXY': 0.9391276966676139, 'STAR': 0.9535320774363552}
#
#
# SVC
# {'QSO': 0.9272430806169432, 'GALAXY': 0.9262610049126904, 'STAR': 0.94930059713545}
#
#
# LinearSVC
# {'QSO': 0.9521096706659152, 'GALAXY': 0.9639791511465078, 'STAR': 0.9776459369288962}
#
#
# NuSVC
# {'QSO': 0.9479042376417367, 'GALAXY': 0.9796010711149681, 'STAR': 0.9917774342300989}
#
#
# RbfKernelSVM
# {'QSO': 0.9704100754708693, 'GALAXY': 0.9847921642717622, 'STAR': 0.9926274491053593}
#
#
# PolyKernelSVM
# {'QSO': 0.9757226829857476, 'GALAXY': 0.9892011694199749, 'STAR': 0.9965016575290069}
#
#
# DecisionTree
# {'QSO': 0.9546918577838942, 'GALAXY': 0.9795985110887535, 'STAR': 0.9948414722257639}
#
#
# RandomForest
# {'QSO': 0.955947265553514, 'GALAXY': 0.9868139449747966, 'STAR': 0.9968177568107441}
#
#
# LogisticRegression
# {'QSO': 0.955947265553514, 'GALAXY': 0.9363494282181449, 'STAR': 0.9484731607803136}
#
#
# XGB
# {'QSO': 0.965392104473351, 'GALAXY': 0.9872024289528725, 'STAR': 0.9968177568107441}
#
#
# BaggingCLF(DecisionTreeClassifier)
# {'QSO': 0.9621456126609521, 'GALAXY': 0.9884088413065351, 'STAR': 0.9973118279569892}
#
#
# AdaBoost(DecisionTreeClassifier)
# {'QSO': 0.6031575518450468, 'GALAXY': 0.9062537600385028, 'STAR': 0.9844659781546177}
#
#
# SGDClassifier
# {'QSO': 0.9589723224677731, 'GALAXY': 0.9563573130988862, 'STAR': 0.9694432933826341}
#
#
# MLP
# {'QSO': 0.9704100754708693, 'GALAXY': 0.9807767631540547, 'STAR': 0.9894252836924646}
#
#
# XTrees
# {'QSO': 0.9490846137516562, 'GALAXY': 0.9628239393171387, 'STAR': 0.9729429640018701}
#
#
# PassiveAggressiveClassifier
# {'QSO': 0.9484935106764562, 'GALAXY': 0.9391968173754098, 'STAR': 0.9536529389264312}
#
#
# RidgeClassifier
# {'QSO': 0.8799438543580584, 'GALAXY': 0.8437071995617235, 'STAR': 0.8367493306132856}
#
#
# NaiveBayes
# {'QSO': 0.965392104473351, 'GALAXY': 0.9860113767564979, 'STAR': 0.9950194440902717}
#
#
# MultinomialNaiveBayes
# {'QSO': 0.8799438543580584, 'GALAXY': 0.8437071995617235, 'STAR': 0.8367493306132856}
#
#
# LDA
# {'QSO': 0.8799438543580584, 'GALAXY': 0.908029778224929, 'STAR': 0.9191835075863828}
#
#
# QDA
# {'QSO': 0.9824371015086854, 'GALAXY': 0.9855998525424902, 'STAR': 0.9915609460665561}
#
#
# VotingClassifier
# {'QSO': 0.962367047559092, 'GALAXY': 0.9884114013327496, 'STAR': 0.9968177568107441}
