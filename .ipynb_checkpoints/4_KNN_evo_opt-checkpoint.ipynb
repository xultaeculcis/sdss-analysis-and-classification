# %% [markdown]
# # Genetic optimization of KNN classifier for the SDSS data

# %% [markdown]
# ## Load data

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals
import warnings
import helpers
from helpers import DataSet
import matplotlib as mpl
import os
import random

# Common imports
import pandas as pd
import numpy as np
import seaborn as sns

# Imports for ML
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, BaggingClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier, PassiveAggressiveClassifier, RidgeClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import RobustScaler, StandardScaler, MaxAbsScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.decomposition import PCA

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
sns.set_style('whitegrid')

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "results"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)

# Helper functioins and structures
# Ignore useless warnings (see SciPy issue #5998)
warnings.filterwarnings(action="ignore", message="^internal gelsd")

DATA_PATH = "Skyserver_SQL2_27_2018 6_51_39 PM.csv"
RESULTS_FOLDER = "results"

# We load the data. Those that have nothing to do with the features of the objects are ignored.
sdss_data = pd.read_csv(DATA_PATH)

# We have a general look at the features
sdss_data.head(3)

print(sdss_data.columns.values)
sdss_data.drop(['objid', 'run', 'rerun', 'camcol', 'field',
                'specobjid', 'fiberid', 'mjd', 'plate'], axis=1, inplace=True)
sdss_data.head(1)

sdss_df_fe = sdss_data

# Principal Component Analysis
pca = PCA(n_components=3)
ugriz = pca.fit_transform(sdss_df_fe[['u', 'g', 'r', 'i', 'z']])

# update dataframe 
sdss_df_fe = pd.concat((sdss_df_fe, pd.DataFrame(ugriz)), axis=1)
sdss_df_fe.rename({0: 'PCA_1', 1: 'PCA_2', 2: 'PCA_3'}, axis=1, inplace = True)
sdss_df_fe.drop(['u', 'g', 'r', 'i', 'z'], axis=1, inplace=True)
sdss_df_fe.head()

X = sdss_data.drop(['class'], axis=1)
y = sdss_data['class']

class_names = ["GALAXY", "QSO", "STAR"]

std_scaler = StandardScaler()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

X_test = std_scaler.fit_transform(X_test.astype(np.float64))
X_train = std_scaler.fit_transform(X_train.astype(np.float64))
# Out:
# ['objid' 'ra' 'dec' 'u' 'g' 'r' 'i' 'z' 'run' 'rerun' 'camcol' 'field'
#  'specobjid' 'class' 'redshift' 'plate' 'mjd' 'fiberid']

# %% [markdown]
# ## Optimize

# %%
from evolutionary_search import EvolutionaryAlgorithmSearchCV

paramgrid = {
    "n_neighbors": np.arange(1,12,step=2,dtype=int),
    "weights": ['uniform', 'distance'],
    "algorithm": ["auto", "ball_tree", "kd_tree", "brute"],
    "leaf_size": np.unique(np.logspace(0,2,base=10,num=20,dtype=int)),
    "p": [1,2],
    "metric": ["euclidean","manhattan","chebyshev","minkowski"],
    "n_jobs": [4]
}

random.seed(1)

cv = EvolutionaryAlgorithmSearchCV(estimator=KNeighborsClassifier(),
                                   params=paramgrid,
                                   scoring="accuracy",
                                   cv=StratifiedKFold(n_splits=5),
                                   verbose=3,
                                   population_size=50,
                                   gene_mutation_prob=0.10,
                                   gene_crossover_prob=0.5,
                                   tournament_size=3,
                                   generations_number=50,
                                   n_jobs=8,
                                   error_score=0.0)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    result = cv.fit(X_train, y_train)
# Out:
# Types [1, 1, 1, 1, 1, 1, 1] and maxint [5, 1, 3, 16, 1, 3, 0] detected
# /home/ljosfer/anaconda3/envs/deep/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /home/ljosfer/anaconda3/envs/deep/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# [CV] n_neighbors=3, weights=uniform, algorithm=kd_tree, leaf_size=4, p=2, metric=minkowski, n_jobs=4
# [CV] n_neighbors=5, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=euclidean, n_jobs=4
# [CV] n_neighbors=11, weights=uniform, algorithm=ball_tree, leaf_size=61, p=2, metric=manhattan, n_jobs=4
# [CV] n_neighbors=5, weights=uniform, algorithm=brute, leaf_size=100, p=1, metric=manhattan, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=manhattan, n_jobs=4
# [CV] n_neighbors=7, weights=uniform, algorithm=brute, leaf_size=14, p=1, metric=euclidean, n_jobs=4
# [CV] n_neighbors=7, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=euclidean, n_jobs=4
# [CV] n_neighbors=7, weights=uniform, algorithm=kd_tree, leaf_size=29, p=1, metric=minkowski, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=manhattan, n_jobs=4, score=0.9320453031312458, total=   0.0s
# [CV]  n_neighbors=7, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=euclidean, n_jobs=4, score=0.9027315123251166, total=   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=euclidean, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=uniform, algorithm=kd_tree, leaf_size=4, p=2, metric=minkowski, n_jobs=4, score=0.9100599600266489, total=   0.1s
# [CV]  n_neighbors=5, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=euclidean, n_jobs=4, score=0.90473017988008, total=   0.1s
# [CV] n_neighbors=3, weights=uniform, algorithm=kd_tree, leaf_size=4, p=2, metric=minkowski, n_jobs=4
# --- Evolve in 6528 possible combinations ---
# [CV] n_neighbors=5, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=euclidean, n_jobs=4
# [CV]  n_neighbors=7, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=euclidean, n_jobs=4, score=0.8880746169220519, total=   0.1s
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=manhattan, n_jobs=4, score=0.9147235176548968, total=   0.1s
# [CV] n_neighbors=7, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=euclidean, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=7, weights=uniform, algorithm=kd_tree, leaf_size=29, p=1, metric=minkowski, n_jobs=4, score=0.9093937375083277, total=   0.2s
# [CV] n_neighbors=7, weights=uniform, algorithm=kd_tree, leaf_size=29, p=1, metric=minkowski, n_jobs=4
# [CV]  n_neighbors=11, weights=uniform, algorithm=ball_tree, leaf_size=61, p=2, metric=manhattan, n_jobs=4, score=0.9087275149900067, total=   0.2s
# [CV] n_neighbors=11, weights=uniform, algorithm=ball_tree, leaf_size=61, p=2, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=uniform, algorithm=kd_tree, leaf_size=4, p=2, metric=minkowski, n_jobs=4, score=0.8987341772151899, total=   0.1s
# [CV] n_neighbors=3, weights=uniform, algorithm=kd_tree, leaf_size=4, p=2, metric=minkowski, n_jobs=4
# [CV]  n_neighbors=7, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=euclidean, n_jobs=4, score=0.9126666666666666, total=   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=euclidean, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=manhattan, n_jobs=4, score=0.932, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=5, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=euclidean, n_jobs=4, score=0.893404397068621, total=   0.1s
# [CV] n_neighbors=5, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=euclidean, n_jobs=4
# [CV]  n_neighbors=7, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=euclidean, n_jobs=4, score=0.8945963975983989, total=   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=euclidean, n_jobs=4
# [CV]  n_neighbors=7, weights=uniform, algorithm=kd_tree, leaf_size=29, p=1, metric=minkowski, n_jobs=4, score=0.9067288474350433, total=   0.1s
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.0s
# [CV] n_neighbors=7, weights=uniform, algorithm=kd_tree, leaf_size=29, p=1, metric=minkowski, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=uniform, algorithm=kd_tree, leaf_size=4, p=2, metric=minkowski, n_jobs=4, score=0.9106666666666666, total=   0.1s
# [CV] n_neighbors=3, weights=uniform, algorithm=kd_tree, leaf_size=4, p=2, metric=minkowski, n_jobs=4
# [CV]  n_neighbors=5, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=euclidean, n_jobs=4, score=0.9126666666666666, total=   0.1s
# [CV] n_neighbors=5, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=euclidean, n_jobs=4
# [CV]  n_neighbors=7, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=euclidean, n_jobs=4, score=0.8979319546364243, total=   0.0s
# [CV]  n_neighbors=5, weights=uniform, algorithm=brute, leaf_size=100, p=1, metric=manhattan, n_jobs=4, score=0.91672218520986, total=   0.3s
# [CV] n_neighbors=5, weights=uniform, algorithm=brute, leaf_size=100, p=1, metric=manhattan, n_jobs=4
# [CV] n_neighbors=11, weights=uniform, algorithm=ball_tree, leaf_size=3, p=2, metric=euclidean, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=23, p=2, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.0s
# [CV] n_neighbors=5, weights=distance, algorithm=brute, leaf_size=2, p=2, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=7, weights=uniform, algorithm=brute, leaf_size=14, p=1, metric=euclidean, n_jobs=4, score=0.899400399733511, total=   0.3s
# [CV] n_neighbors=7, weights=uniform, algorithm=brute, leaf_size=14, p=1, metric=euclidean, n_jobs=4
# [CV]  n_neighbors=3, weights=uniform, algorithm=kd_tree, leaf_size=4, p=2, metric=minkowski, n_jobs=4, score=0.9092728485657104, total=   0.1s
# [CV] n_neighbors=3, weights=uniform, algorithm=kd_tree, leaf_size=4, p=2, metric=minkowski, n_jobs=4
# [CV]  n_neighbors=11, weights=uniform, algorithm=ball_tree, leaf_size=61, p=2, metric=manhattan, n_jobs=4, score=0.8974017321785477, total=   0.1s
# [CV] n_neighbors=11, weights=uniform, algorithm=ball_tree, leaf_size=61, p=2, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=7, weights=uniform, algorithm=kd_tree, leaf_size=29, p=1, metric=minkowski, n_jobs=4, score=0.9253333333333333, total=   0.1s
# [CV] n_neighbors=7, weights=uniform, algorithm=kd_tree, leaf_size=29, p=1, metric=minkowski, n_jobs=4
# [CV]  n_neighbors=5, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=euclidean, n_jobs=4, score=0.9006004002668445, total=   0.1s
# [CV] n_neighbors=5, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=euclidean, n_jobs=4
# [CV]  n_neighbors=3, weights=uniform, algorithm=kd_tree, leaf_size=4, p=2, metric=minkowski, n_jobs=4, score=0.8999332888592395, total=   0.1s
# [CV]  n_neighbors=11, weights=uniform, algorithm=ball_tree, leaf_size=3, p=2, metric=euclidean, n_jobs=4, score=0.8867421718854097, total=   0.1s
# [CV] n_neighbors=11, weights=uniform, algorithm=ball_tree, leaf_size=3, p=2, metric=euclidean, n_jobs=4
# [CV] n_neighbors=11, weights=distance, algorithm=ball_tree, leaf_size=4, p=2, metric=euclidean, n_jobs=4
# [CV]  n_neighbors=5, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=euclidean, n_jobs=4, score=0.9006004002668445, total=   0.1s
# [CV] n_neighbors=9, weights=uniform, algorithm=brute, leaf_size=100, p=2, metric=chebyshev, n_jobs=4
# [CV]  n_neighbors=11, weights=uniform, algorithm=ball_tree, leaf_size=61, p=2, metric=manhattan, n_jobs=4, score=0.916, total=   0.2s
# [CV] n_neighbors=11, weights=uniform, algorithm=ball_tree, leaf_size=61, p=2, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=7, weights=uniform, algorithm=kd_tree, leaf_size=29, p=1, metric=minkowski, n_jobs=4, score=0.9119412941961308, total=   0.1s
# [CV] n_neighbors=7, weights=uniform, algorithm=kd_tree, leaf_size=29, p=1, metric=minkowski, n_jobs=4
# [CV]  n_neighbors=5, weights=distance, algorithm=brute, leaf_size=2, p=2, metric=manhattan, n_jobs=4, score=0.9220519653564291, total=   0.2s
# [CV] n_neighbors=5, weights=distance, algorithm=brute, leaf_size=2, p=2, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=11, weights=distance, algorithm=ball_tree, leaf_size=4, p=2, metric=euclidean, n_jobs=4, score=0.8980679546968687, total=   0.1s
# [CV] n_neighbors=11, weights=distance, algorithm=ball_tree, leaf_size=4, p=2, metric=euclidean, n_jobs=4
# [CV]  n_neighbors=5, weights=uniform, algorithm=brute, leaf_size=100, p=1, metric=manhattan, n_jobs=4, score=0.9100599600266489, total=   0.3s
# [CV] n_neighbors=5, weights=uniform, algorithm=brute, leaf_size=100, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=11, weights=uniform, algorithm=ball_tree, leaf_size=3, p=2, metric=euclidean, n_jobs=4, score=0.8607594936708861, total=   0.1s
# [CV] n_neighbors=11, weights=uniform, algorithm=ball_tree, leaf_size=3, p=2, metric=euclidean, n_jobs=4
# [CV]  n_neighbors=7, weights=uniform, algorithm=brute, leaf_size=14, p=1, metric=euclidean, n_jobs=4, score=0.8767488341105929, total=   0.3s
# [CV] n_neighbors=7, weights=uniform, algorithm=brute, leaf_size=14, p=1, metric=euclidean, n_jobs=4
# [CV]  n_neighbors=7, weights=uniform, algorithm=kd_tree
metric=manhattan, n_jobs=4
# [CV]  n_neighbors=11, weights=uniform, algorithm=auto, leaf_size=5, p=1, metric=manhattan, n_jobs=4, score=0.9087275149900067, total=   0.2s
# [CV] n_neighbors=11, weights=uniform, algorithm=auto, leaf_size=5, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=9, weights=distance, algorithm=ball_tree, leaf_size=78, p=1, metric=minkowski, n_jobs=4, score=0.914609739826551, total=   0.2s
# [CV] n_neighbors=9, weights=distance, algorithm=ball_tree, leaf_size=78, p=1, metric=minkowski, n_jobs=4
# [CV]  n_neighbors=7, weights=uniform, algorithm=brute, leaf_size=5, p=1, metric=chebyshev, n_jobs=4, score=0.875250166777852, total=   0.3s
# [CV] n_neighbors=9, weights=distance, algorithm=auto, leaf_size=11, p=1, metric=chebyshev, n_jobs=4
# [CV]  n_neighbors=5, weights=uniform, algorithm=brute, leaf_size=5, p=1, metric=chebyshev, n_jobs=4, score=0.8812541694462975, total=   0.3s
# [CV]  n_neighbors=9, weights=distance, algorithm=auto, leaf_size=11, p=1, metric=chebyshev, n_jobs=4, score=0.8840772818121253, total=   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=auto, leaf_size=11, p=1, metric=chebyshev, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=minkowski, n_jobs=4
# [CV]  n_neighbors=5, weights=distance, algorithm=brute, leaf_size=37, p=2, metric=minkowski, n_jobs=4, score=0.90473017988008, total=   0.3s
# [CV] n_neighbors=5, weights=distance, algorithm=brute, leaf_size=37, p=2, metric=minkowski, n_jobs=4
# [CV]  n_neighbors=9, weights=distance, algorithm=auto, leaf_size=11, p=1, metric=chebyshev, n_jobs=4, score=0.8674217188540972, total=   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=auto, leaf_size=11, p=1, metric=chebyshev, n_jobs=4
# [CV]  n_neighbors=9, weights=distance, algorithm=auto, leaf_size=11, p=1, metric=chebyshev, n_jobs=4, score=0.892, total=   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=auto, leaf_size=11, p=1, metric=chebyshev, n_jobs=4
# ...
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.932, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.1s
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=2, p=1, metric=manhattan, n_jobs=4, score=0.9320453031312458, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=2, p=1, metric=manhattan, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9320453031312458, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9147235176548968, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9147235176548968, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=2, p=1, metric=manhattan, n_jobs=4, score=0.9147235176548968, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=2, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9320453031312458, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.0s
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9320453031312458, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.932, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.1s
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.932, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=2, p=1, metric=manhattan, n_jobs=4, score=0.932, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=2, p=1, metric=manhattan, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.1s
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9320453031312458, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9147235176548968, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9147235176548968, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9147235176548968, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=2, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=2, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9320453031312458, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.932, total=   0.0s
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9320453031312458, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.932, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.932, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.0s
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9147235176548968, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=2, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.1s
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9147235176548968, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9320453031312458, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.932, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.0s
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9320453031312458, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.932, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9147235176548968, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9320453031312458, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9147235176548968, total=   0.1s
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9320453031312458, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.932, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.1s
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.0s
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9147235176548968, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.932, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9147235176548968, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.1s
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.932, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.0s
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.932, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.0s
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9266177451634423, total=   0.1s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=6, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.0s
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, leaf_size=14, p=1, metric=manhattan, n_jobs=4, score=0.9192795196797865, total=   0.0s
# 50 	25    	0.924869	0.921733	0.924933	0.000448
# Best individual is: {'n_neighbors': 3, 'weights': 'distance', 'algorithm': 'auto', 'leaf_size': 23, 'p': 2, 'metric': 'manhattan', 'n_jobs': 4}
# with fitness: 0.9249333333333334

# %%
best_indiv = KNeighborsClassifier(n_neighbors=3,
                                  weights='distance', 
                                  algorithm='auto',
                                  leaf_size=23, 
                                  p=2,
                                  metric='manhattan', 
                                  n_jobs=4)

clf_names = ["KNeighborsClassifier"]
class_names = ["GALAXY", "QSO", "STAR"]

clfs = [best_indiv]
data_sets = []
std_scaled_set = DataSet("Standard Scaled", X_train, y_train, X_test, y_test)
data_sets.append(std_scaled_set)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    helpers.learning_loop_for_sets(clfs, clf_names, class_names, data_sets)
# Out:
# ==========================================================
# ==========================================================
# Data Set Type:  Standard Scaled
# KNeighborsClassifier
# [0.9320453  0.91472352 0.932      0.92661775 0.91927952]
# Accuracy: 0.925 (+/- 0.014)
# KNeighborsClassifier :
#  [[1086    2  158]
#  [  13  216   13]
#  [ 107    1  904]]
#               precision    recall  f1-score   support
#
#       GALAXY       0.90      0.87      0.89      1246
#          QSO       0.99      0.89      0.94       242
#         STAR       0.84      0.89      0.87      1012
#
#    micro avg       0.88      0.88      0.88      2500
#    macro avg       0.91      0.89      0.90      2500
# weighted avg       0.88      0.88      0.88      2500
#
#
#
# By Acc:
# KNeighborsClassifier 0.9249332171258743
#
#
# By Precision(avg=micro):
# KNeighborsClassifier 0.8824
#
#
# By Recall(avg=micro):
# KNeighborsClassifier 0.8824
#
#
# By F1(avg=micro):
# KNeighborsClassifier 0.8824
#
#
# By Precision(avg=macro):
# KNeighborsClassifier 0.9092430382863214
#
#
# By Recall(avg=macro):
# KNeighborsClassifier 0.8858105669847909
#
#
# By F1(avg=macro):
# KNeighborsClassifier 0.8964053548882
#
#
# KNeighborsClassifier
# {'GALAXY': 0.8879476525839625, 'STAR': 0.8891806387861788, 'QSO': 0.9456166870411175}
